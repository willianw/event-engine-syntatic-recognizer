# %%
import re, pdb

# %% [markdown]
# A map of all event engines.

# %% [markdown]
# # Classes

# %%
class Queue:
    def __init__(self):
        self.list = []

    def empty(self):
        return len(self.list) == 0

    def put(self, item):
        self.list.append(item)

    def get(self):
        item = self.list[0]
        self.list = self.list[1:]
        return item

# %%
class Event:
      def __init__(self, type='', parameters={}):
        self.type = type
        self.parameters = parameters

# %%
class Engine:
    def __init__(self, routines, trigger=None, items=dict()):
        self.routines = routines
        self.items = items
        
    def list_event(self, event):
        print(event.type, event.parameters)

    def list_events(self, n=10):
        for i, event in enumerate(self.queue.list[:n]):
            print("{}. ".format(i+1), event.type, event.parameters)

    def fetch_event(self, debug=False):
        event = self.queue.get()
        generated_events = self.routines[event.type](**{**self.items, **event.parameters})
        for generated_event in generated_events:
            if debug:
                self.list_event(generated_event)
            self.manage_event(generated_event)

    def fetch_exhaustive(self, debug=False):
        while not self.queue.empty():
            self.fetch_event(debug)

    def fetch_and_list(self):
        self.fetch_event()
        self.list_events()

# %% [markdown]
# # Other Data Structure

# %% [markdown]
# # Functions

# %% [markdown]
# ## Abstraction Level 1

# %%
class StartingEngine(Engine):
    def __init__(self, trigger, *args):
        super().__init__(*args)
        self.queue = Queue()
        if trigger:
            self.queue.put(trigger)
        self.output = Queue()
    def manage_event(self, event):
        if event.type != 'ClassifiedChar':
            self.queue.put(event)
        else:
            self.output.put(event)

# %%
def get_lines(filename):
    try:
        with open(filename, 'r') as f:
            for line in f.readlines():
                yield Event("Line", {'line': line})
    except FileNotFoundError:
        return None

# %% [markdown]
# ## Abstraction Level 2

# %%
def get_chars(line):
    list_lines = list(line)
    for char in list_lines:
        yield Event("Char", {'char': char})

# %% [markdown]
# ## Abstraction Levels 3, 4 and 5

# %%
def classify_chars(char):
    _type = 'descartavel' if char in [' ', '\t'] else 'util' if char != '\n' else 'controle'
    if re.match(r'[a-zA-Z]', char):
        _class = 'letra'
    elif re.match(r'[0-9]', char):
        _class = 'digito'
    elif char in [' ', '\t']:
        char = 'espaco'
        _class = 'delimitador'
    elif char == '\n':
        char = '\n'
        _class = 'especial'
    else:
        _class = 'especial'
    yield Event("ClassifiedChar", {'char': char, 'char_type': _type, 'char_class': _class})

# %% [markdown]
# ## Abstraction Level 6

# %%
# %run 'MetaRecognizer.ipynb'
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
mr = MetaRecognizer('grammar.txt', 'fsm/')
mr.determinizeAll()
reserved_words = mr.getSymbols()

states = {
    'A': {'next': {'letra': 'B','digito': 'C', 'especial': 'D', 'controle': 'E'}, 'final': False},
    'B': {'next': {'letra': 'B','digito': 'B'}, 'final': True, 'type':'letter'},
    'C': {'next': {'digito': 'C'}, 'final': True, 'type':'digit'},
    'D': {'next': {'especial': 'D'}, 'final': True, 'type':'especial'},
    'E': {'next': {'letra': 'E', 'digito': 'E', 'especial': 'E'}, 'final': True, 'type': 'remark'},
}

class LexicalEngine(Engine):
    def __init__(self, queue, *args):
        super().__init__(*args)
        self.queue = queue
        self.output = Queue()
        self.state = 'A'
        self.token = ''
        self.remark = False

    def manage_event(self, event):
        self.output.put(event)
                
    def lexical_analysis(self, char, char_type, char_class):
        state = self.state
        token = self.token
        if char_class in states[state]['next'].keys():
            self.state = states[state]['next'][char_class]
            self.token = token + char
        else:
            if states[state]['final']:
                if char_type in ['descartavel']:
                    self.state = 'A'
                    self.token = ''
                else:
                    self.state = states['A']['next'][char_class]
                    self.token = char
                token_type = token if token in reserved_words else states[state]['type'] 
                token_type = token if token_type == 'symbol' else token_type
                yield Event("Token", {'token': token_type, 'value': token})
            else:
                if state != 'A':
                    raise SyntaxError("Invalid token: {}".format(token))

# %% [markdown]
# ## Abstraction Level 7

# %%
mr.fsms['Int'].dfa.accepting_states
# Out:
# ['B', 'C']

# %%
class SyntaticalEngine(Engine):
    def __init__(self, queue, mr, *args):
        super().__init__(*args)
        self.queue = queue
        self.output = Queue()
        self.mr = mr
        self.stack = [('A', list(mr.fsms.values())[0].dfa.name, [], [])]
        
    def manage_event(self, event):
        self.output.put(event)
                
    def syntatical_analysis(self, token, value):
        state, machine, tokens, backtrackingOptions = self.stack[-1]
        paths = list(self.mr.fsms[machine].dfa.transitions[state].keys())
        nt = list(filter(lambda x: x.startswith(':'), paths))
        print("{}({})".format(token, value), state, machine, backtrackingOptions, self.mr.fsms[machine].dfa.transitions)
        print("is '{}' in {}".format(value, paths))
        if token in paths:
            print("\tNormal transition")
            self.stack[-1] = (
                self.mr.fsms[machine].dfa.transitions[state][token],
                machine,
                tokens+[{'token': token, 'value': value}],
                []
            )
        else:
            self.queue.list = [Event("Token", {'token': token, 'value': value})] + self.queue.list
            if nt:
                if not backtrackingOptions:
                    backtrackingOptions = nt
                    self.stack[-1] = (state, machine, tokens, backtrackingOptions)
                print("Trying machine "+backtrackingOptions[0])
                self.stack.append(('A', backtrackingOptions[0][1:], [], []))
            else:
                if state in mr.fsms[machine].dfa.accepting_states:
                    if len(self.stack) == 0:
                        raise SyntaxError('Pilha vazia. Erro no token {}'.format(tokens))
                    else:
                        self.stack = self.stack[:-1]
                        self.stack[-1] = tuple(list(self.stack[-1])[:-1] + [self.stack[-1][-1][1:]]) # remove bt trial
                        print("Found token '{}': {}".format(machine, tokens))
                        self.queue.list = [Event("Token", {'token': ':'+machine, 'value': tokens})] + self.queue.list#[1:]
                        yield Event("SyntaticalToken", {'type': machine, 'tokens': tokens})
                else:
                    print("Backtracking...")
                    returningTokens = [Event("Token", {'token': token, 'value': value}) for token, value in tokens]
                    self.queue.list = returningTokens + self.queue.list
                    while self.stack:
                        self.stack = self.stack[:-1]
                        backtrackingOptions = self.stack[-1][3][1:]
                        if backtrackingOptions:
                            self.stack[-1] = tuple(list(self.stack[-1])[:-1] + [backtrackingOptions])
                            break
                    else:
                        raise SyntaxError(
                            'Parou em estado de rejeição. Estados de aceitação: {}'.format(
                                mr.fsms[machine].dfa.accepting_states
                            ))

# %% [markdown]
# # Testing

# %% [markdown]
# ## Instantiation

# %%
starting = StartingEngine(
    Event('File', {'filename': 'bubblesort.bs'}),
    {
        'File': get_lines,
        'Line': get_chars,
        'Char': classify_chars,
    }
)

# %%
lexical = LexicalEngine(starting.output, {})
lexical.routines = {
    'ClassifiedChar': lexical.lexical_analysis,
}

# %%
syntatical = SyntaticalEngine(lexical.output, mr, {})
syntatical.routines = {
    'Token': syntatical.syntatical_analysis,
}

# %% [markdown]
# ## Running

# %%
starting.list_events()
# Out:
# 1.  File {'filename': 'bubblesort.bs'}

# %%
starting.fetch_exhaustive(debug=True)
# Out:
# Line {'line': '10 LET N = 10 \n'}
# Line {'line': '20 DATA 53, 77, 82, 12, 38, 90, 16, 72, 55, 62 \n'}
# Line {'line': '30 DIM Z(10) \n'}
# Line {'line': '35 DIM S(1000) \n'}
# Line {'line': '36 LET P = 1 \n'}
# Line {'line': '40 FOR I = 1 TO N \n'}
# Line {'line': '50 READ Z(I) \n'}
# Line {'line': '60 NEXT I \n'}
# Line {'line': '1000 FOR I = 1 TO N \n'}
# Line {'line': '1500 FOR J = I TO N \n'}
# Line {'line': '1510 IF Z(I) <= Z(J) THEN 1800 \n'}
# Line {'line': '1520 LET T = Z(J) \n'}
# Line {'line': '1530 LET Z(J) = Z(I) \n'}
# Line {'line': '1540 LET Z(I) = T \n'}
# Line {'line': '1800 NEXT J \n'}
# Line {'line': '1810 NEXT I \n'}
# Line {'line': '9000 FOR I = 1 TO 10 \n'}
# Line {'line': '9000 PRINT Z(I) \n'}
# Line {'line': '9000 NEXT I '}
# Char {'char': '1'}
# Char {'char': '0'}
# Char {'char': ' '}
# Char {'char': 'L'}
# Char {'char': 'E'}
# Char {'char': 'T'}
# Char {'char': ' '}
# Char {'char': 'N'}
# Char {'char': ' '}
# Char {'char': '='}
# Char {'char': ' '}
# Char {'char': '1'}
# Char {'char': '0'}
# Char {'char': ' '}
# Char {'char': '\n'}
# Char {'char': '2'}
# Char {'char': '0'}
# Char {'char': ' '}
# Char {'char': 'D'}
# Char {'char': 'A'}
# Char {'char': 'T'}
# Char {'char': 'A'}
# Char {'char': ' '}
# Char {'char': '5'}
# Char {'char': '3'}
# Char {'char': ','}
# Char {'char': ' '}
# Char {'char': '7'}
# Char {'char': '7'}
# Char {'char': ','}
# Char {'char': ' '}
# Char {'char': '8'}
# Char {'char': '2'}
# Char {'char': ','}
# Char {'char': ' '}
# Char {'char': '1'}
# Char {'char': '2'}
# Char {'char': ','}
# Char {'char': ' '}
# Char {'char': '3'}
# Char {'char': '8'}
# Char {'char': ','}
# Char {'char': ' '}
# Char {'char': '9'}
# Char {'char': '0'}
# Char {'char': ','}
# Char {'char': ' '}
# Char {'char': '1'}
# Char {'char': '6'}
# Char {'char': ','}
# Char {'char': ' '}
# Char {'char': '7'}
# Char {'char': '2'}
# Char {'char': ','}
# Char {'char': ' '}
# Char {'char': '5'}
# Char {'char': '5'}
# Char {'char': ','}
# Char {'char': ' '}
# Char {'char': '6'}
# Char {'char': '2'}
# Char {'char': ' '}
# Char {'char': '\n'}
# Char {'char': '3'}
# Char {'char': '0'}
# Char {'char': ' '}
# Char {'char': 'D'}
# Char {'char': 'I'}
# Char {'char': 'M'}
# Char {'char': ' '}
# Char {'char': 'Z'}
# Char {'char': '('}
# Char {'char': '1'}
# Char {'char': '0'}
# Char {'char': ')'}
# Char {'char': ' '}
# Char {'char': '\n'}
# Char {'char': '3'}
# Char {'char': '5'}
# Char {'char': ' '}
# Char {'char': 'D'}
# Char {'char': 'I'}
# Char {'char': 'M'}
# Char {'char': ' '}
# Char {'char': 'S'}
# Char {'char': '('}
# Char {'char': '1'}
# Char {'char': '0'}
# Char {'char': '0'}
# Char {'char': '0'}
# Char {'char': ')'}
# Char {'char': ' '}
# Char {'char': '\n'}
# Char {'char': '3'}
# Char {'char': '6'}
# Char {'char': ' '}
# Char {'char': 'L'}
# Char {'char': 'E'}
# Char {'char': 'T'}
# Char {'char': ' '}
# Char {'char': 'P'}
# Char {'char': ' '}
# Char {'char': '='}
# Char {'char': ' '}
# Char {'char': '1'}
# Char {'char': ' '}
# Char {'char': '\n'}
# Char {'char': '4'}
# Char {'char': '0'}
# Char {'char': ' '}
# Char {'char': 'F'}
# Char {'char': 'O'}
# Char {'char': 'R'}
# Char {'char': ' '}
# Char {'char': 'I'}
# Char {'char': ' '}
# Char {'char': '='}
# Char {'char': ' '}
# Char {'char': '1'}
# Char {'char': ' '}
# Char {'char': 'T'}
# Char {'char': 'O'}
# Char {'char': ' '}
# Char {'char': 'N'}
# Char {'char': ' '}
# Char {'char': '\n'}
# Char {'char': '5'}
# Char {'char': '0'}
# Char {'char': ' '}
# Char {'char': 'R'}
# Char {'char': 'E'}
# Char {'char': 'A'}
# Char {'char': 'D'}
# Char {'char': ' '}
# Char {'char': 'Z'}
# Char {'char': '('}
# Char {'char': 'I'}
# Char {'char': ')'}
# Char {'char': ' '}
# Char {'char': '\n'}
# Char {'char': '6'}
# Char {'char': '0'}
# Char {'char': ' '}
# Char {'char': 'N'}
# Char {'char': 'E'}
# Char {'char': 'X'}
# Char {'char': 'T'}
# Char {'char': ' '}
# Char {'char': 'I'}
# Char {'char': ' '}
# Char {'char': '\n'}
# Char {'char': '1'}
# Char {'char': '0'}
# Char {'char': '0'}
# Char {'char': '0'}
# Char {'char': ' '}
# Char {'char': 'F'}
# Char {'char': 'O'}
# Char {'char': 'R'}
# Char {'char': ' '}
# Char {'char': 'I'}
# Char {'char': ' '}
# Char {'char': '='}
# Char {'char': ' '}
# Char {'char': '1'}
# Char {'char': ' '}
# Char {'char': 'T'}
# Char {'char': 'O'}
# Char {'char': ' '}
# Char {'char': 'N'}
# Char {'char': ' '}
# Char {'char': '\n'}
# Char {'char': '1'}
# Char {'char': '5'}
# Char {'char': '0'}
# Char {'char': '0'}
# Char {'char': ' '}
# Char {'char': 'F'}
# Char {'char': 'O'}
# Char {'char': 'R'}
# Char {'char': ' '}
# Char {'char': 'J'}
# Char {'char': ' '}
# Char {'char': '='}
# Char {'char': ' '}
# Char {'char': 'I'}
# Char {'char': ' '}
# Char {'char': 'T'}
# Char {'char': 'O'}
# Char {'char': ' '}
# Char {'char': 'N'}
# Char {'char': ' '}
# Char {'char': '\n'}
# Char {'char': '1'}
# Char {'char': '5'}
# Char {'char': '1'}
# Char {'char': '0'}
# Char {'char': ' '}
# Char {'char': 'I'}
# Char {'char': 'F'}
# Char {'char': ' '}
# Char {'char': 'Z'}
# Char {'char': '('}
# Char {'char': 'I'}
# Char {'char': ')'}
# Char {'char': ' '}
# Char {'char': '<'}
# Char {'char': '='}
# Char {'char': ' '}
# Char {'char': 'Z'}
# Char {'char': '('}
# Char {'char': 'J'}
# Char {'char': ')'}
# Char {'char': ' '}
# Char {'char': 'T'}
# Char {'char': 'H'}
# Char {'char': 'E'}
# Char {'char': 'N'}
# Char {'char': ' '}
# Char {'char': '1'}
# Char {'char': '8'}
# Char {'char': '0'}
# Char {'char': '0'}
# Char {'char': ' '}
# Char {'char': '\n'}
# Char {'char': '1'}
# Char {'char': '5'}
# Char {'char': '2'}
# Char {'char': '0'}
# Char {'char': ' '}
# Char {'char': 'L'}
# Char {'char': 'E'}
# Char {'char': 'T'}
# Char {'char': ' '}
# Char {'char': 'T'}
# Char {'char': ' '}
# Char {'char': '='}
# Char {'char': ' '}
# Char {'char': 'Z'}
# Char {'char': '('}
# Char {'char': 'J'}
# Char {'char': ')'}
# Char {'char': ' '}
# Char {'char': '\n'}
# Char {'char': '1'}
# Char {'char': '5'}
# Char {'char': '3'}
# Char {'char': '0'}
# Char {'char': ' '}
# Char {'char': 'L'}
# Char {'char': 'E'}
# Char {'char': 'T'}
# Char {'char': ' '}
# Char {'char': 'Z'}
# Char {'char': '('}
# Char {'char': 'J'}
# Char {'char': ')'}
# Char {'char': ' '}
# Char {'char': '='}
# Char {'char': ' '}
# Char {'char': 'Z'}
# Char {'char': '('}
# Char {'char': 'I'}
# Char {'char': ')'}
# Char {'char': ' '}
# Char {'char': '\n'}
# Char {'char': '1'}
# Char {'char': '5'}
# Char {'char': '4'}
# Char {'char': '0'}
# Char {'char': ' '}
# Char {'char': 'L'}
# Char {'char': 'E'}
# Char {'char': 'T'}
# Char {'char': ' '}
# Char {'char': 'Z'}
# Char {'char': '('}
# Char {'char': 'I'}
# Char {'char': ')'}
# Char {'char': ' '}
# Char {'char': '='}
# Char {'char': ' '}
# Char {'char': 'T'}
# Char {'char': ' '}
# Char {'char': '\n'}
# Char {'char': '1'}
# Char {'char': '8'}
# Char {'char': '0'}
# Char {'char': '0'}
# Char {'char': ' '}
# Char {'char': 'N'}
# Char {'char': 'E'}
# Char {'char': 'X'}
# Char {'char': 'T'}
# Char {'char': ' '}
# Char {'char': 'J'}
# Char {'char': ' '}
# Char {'char': '\n'}
# Char {'char': '1'}
# Char {'char': '8'}
# Char {'char': '1'}
# Char {'char': '0'}
# Char {'char': ' '}
# Char {'char': 'N'}
# Char {'char': 'E'}
# Char {'char': 'X'}
# Char {'char': 'T'}
# Char {'char': ' '}
# Char {'char': 'I'}
# Char {'char': ' '}
# Char {'char': '\n'}
# Char {'char': '9'}
# Char {'char': '0'}
# Char {'char': '0'}
# Char {'char': '0'}
# Char {'char': ' '}
# Char {'char': 'F'}
# Char {'char': 'O'}
# Char {'char': 'R'}
# Char {'char': ' '}
# Char {'char': 'I'}
# Char {'char': ' '}
# Char {'char': '='}
# Char {'char': ' '}
# Char {'char': '1'}
# Char {'char': ' '}
# Char {'char': 'T'}
# Char {'char': 'O'}
# Char {'char': ' '}
# Char {'char': '1'}
# Char {'char': '0'}
# Char {'char': ' '}
# Char {'char': '\n'}
# Char {'char': '9'}
# Char {'char': '0'}
# Char {'char': '0'}
# Char {'char': '0'}
# Char {'char': ' '}
# Char {'char': 'P'}
# Char {'char': 'R'}
# Char {'char': 'I'}
# Char {'char': 'N'}
# Char {'char': 'T'}
# Char {'char': ' '}
# Char {'char': 'Z'}
# Char {'char': '('}
# Char {'char': 'I'}
# Char {'char': ')'}
# Char {'char': ' '}
# Char {'char': '\n'}
# Char {'char': '9'}
# Char {'char': '0'}
# Char {'char': '0'}
# Char {'char': '0'}
# Char {'char': ' '}
# Char {'char': 'N'}
# Char {'char': 'E'}
# Char {'char': 'X'}
# Char {'char': 'T'}
# Char {'char': ' '}
# Char {'char': 'I'}
# Char {'char': ' '}
# ClassifiedChar {'char': '1', 'char_type': 'util', 'char_class': 'digito'}
# ClassifiedChar {'char': '0', 'char_type': 'util', 'char_class': 'digito'}
# ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# ClassifiedChar {'char': 'L', 'char_type': 'util', 'char_class': 'letra'}
# ClassifiedChar {'char': 'E', 'char_type': 'util', 'char_class': 'letra'}
# ClassifiedChar {'char': 'T', 'char_type': 'util', 'char_class': 'letra'}
# ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# ClassifiedChar {'char': 'N', 'char_type': 'util', 'char_class': 'letra'}
# ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# ClassifiedChar {'char': '=', 'char_type': 'util', 'char_class': 'especial'}
# ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# ClassifiedChar {'char': '1', 'char_type': 'util', 'char_class': 'digito'}
# ClassifiedChar {'char': '0', 'char_type': 'util', 'char_class': 'digito'}
# ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# ClassifiedChar {'char': '\n', 'char_type': 'controle', 'char_class': 'especial'}
# ClassifiedChar {'char': '2', 'char_type': 'util', 'char_class': 'digito'}
# ClassifiedChar {'char': '0', 'char_type': 'util', 'char_class': 'digito'}
# ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# ClassifiedChar {'char': 'D', 'char_type': 'util', 'char_class': 'letra'}
# ClassifiedChar {'char': 'A', 'char_type': 'util', 'char_class': 'letra'}
# ClassifiedChar {'char': 'T', 'char_type': 'util', 'char_class': 'letra'}
# ClassifiedChar {'char': 'A', 'char_type': 'util', 'char_class': 'letra'}
# ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# ClassifiedChar {'char': '5', 'char_type': 'util', 'char_class': 'digito'}
# ClassifiedChar {'char': '3', 'char_type': 'util', 'char_class': 'digito'}
# ClassifiedChar {'char': ',', 'char_type': 'util', 'char_class': 'especial'}
# ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# ClassifiedChar {'char': '7', 'char_type': 'util', 'char_class': 'digito'}
# ClassifiedChar {'char': '7', 'char_type': 'util', 'char_class': 'digito'}
# ClassifiedChar {'char': ',', 'char_type': 'util', 'char_class': 'especial'}
# ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# ClassifiedChar {'char': '8', 'char_type': 'util', 'char_class': 'digito'}
# ClassifiedChar {'char': '2', 'char_type': 'util', 'char_class': 'digito'}
# ClassifiedChar {'char': ',', 'char_type': 'util', 'char_class': 'especial'}
# ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# ClassifiedChar {'char': '1', 'char_type': 'util', 'char_class': 'digito'}
# ClassifiedChar {'char': '2', 'char_type': 'util', 'char_class': 'digito'}
# ClassifiedChar {'char': ',', 'char_type': 'util', 'char_class': 'especial'}
# ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# ClassifiedChar {'char': '3', 'char_type': 'util', 'char_class': 'digito'}
# ClassifiedChar {'char': '8', 'char_type': 'util', 'char_class': 'digito'}
# ClassifiedChar {'char': ',', 'char_type': 'util', 'char_class': 'especial'}
# ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# ClassifiedChar {'char': '9', 'char_type': 'util', 'char_class': 'digito'}
# ClassifiedChar {'char': '0', 'char_type': 'util', 'char_class': 'digito'}
# ClassifiedChar {'char': ',', 'char_type': 'util', 'char_class': 'especial'}
# ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# ClassifiedChar {'char': '1', 'char_type': 'util', 'char_class': 'digito'}
# ClassifiedChar {'char': '6', 'char_type': 'util', 'char_class': 'digito'}
# ClassifiedChar {'char': ',', 'char_type': 'util', 'char_class': 'especial'}
# ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# ClassifiedChar {'char': '7', 'char_type': 'util', 'char_class': 'digito'}
# ClassifiedChar {'char': '2', 'char_type': 'util', 'char_class': 'digito'}
# ClassifiedChar {'char': ',', 'char_type': 'util', 'char_class': 'especial'}
# ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# ClassifiedChar {'char': '5', 'char_type': 'util', 'char_class': 'digito'}
# ClassifiedChar {'char': '5', 'char_type': 'util', 'char_class': 'digito'}
# ClassifiedChar {'char': ',', 'char_type': 'util', 'char_class': 'especial'}
# ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# ClassifiedChar {'char': '6', 'char_type': 'util', 'char_class': 'digito'}
# ClassifiedChar {'char': '2', 'char_type': 'util', 'char_class': 'digito'}
# ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# ClassifiedChar {'char': '\n', 'char_type': 'controle', 'char_class': 'especial'}
# ClassifiedChar {'char': '3', 'char_type': 'util', 'char_class': 'digito'}
# ClassifiedChar {'char': '0', 'char_type': 'util', 'char_class': 'digito'}
# ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# ClassifiedChar {'char': 'D', 'char_type': 'util', 'char_class': 'letra'}
# ClassifiedChar {'char': 'I', 'char_type': 'util', 'char_class': 'letra'}
# ClassifiedChar {'char': 'M', 'char_type': 'util', 'char_class': 'letra'}
# ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# ClassifiedChar {'char': 'Z', 'char_type': 'util', 'char_class': 'letra'}
# ClassifiedChar {'char': '(', 'char_type': 'util', 'char_class': 'especial'}
# ClassifiedChar {'char': '1', 'char_type': 'util', 'char_class': 'digito'}
# ClassifiedChar {'char': '0', 'char_type': 'util', 'char_class': 'digito'}
# ClassifiedChar {'char': ')', 'char_type': 'util', 'char_class': 'especial'}
# ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# ClassifiedChar {'char': '\n', 'char_type': 'controle', 'char_class': 'especial'}
# ClassifiedChar {'char': '3', 'char_type': 'util', 'char_class': 'digito'}
# ClassifiedChar {'char': '5', 'char_type': 'util', 'char_class': 'digito'}
# ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# ClassifiedChar {'char': 'D', 'char_type': 'util', 'char_class': 'letra'}
# ClassifiedChar {'char': 'I', 'char_type': 'util', 'char_class': 'letra'}
# ClassifiedChar {'char': 'M', 'char_type': 'util', 'char_class': 'letra'}
# ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# ClassifiedChar {'char': 'S', 'char_type': 'util', 'char_class': 'letra'}
# ClassifiedChar {'char': '(', 'char_type': 'util', 'char_class': 'especial'}
# ClassifiedChar {'char': '1', 'char_type': 'util', 'char_class': 'digito'}
# ClassifiedChar {'char': '0', 'char_type': 'util', 'char_class': 'digito'}
# ClassifiedChar {'char': '0', 'char_type': 'util', 'char_class': 'digito'}
# ClassifiedChar {'char': '0', 'char_type': 'util', 'char_class': 'digito'}
# ClassifiedChar {'char': ')', 'char_type': 'util', 'char_class': 'especial'}
# ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# ClassifiedChar {'char': '\n', 'char_type': 'controle', 'char_class': 'especial'}
# ClassifiedChar {'char': '3', 'char_type': 'util', 'char_class': 'digito'}
# ClassifiedChar {'char': '6', 'char_type': 'util', 'char_class': 'digito'}
# ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# ClassifiedChar {'char': 'L', 'char_type': 'util', 'char_class': 'letra'}
# ClassifiedChar {'char': 'E', 'char_type': 'util', 'char_class': 'letra'}
# ClassifiedChar {'char': 'T', 'char_type': 'util', 'char_class': 'letra'}
# ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# ClassifiedChar {'char': 'P', 'char_type': 'util', 'char_class': 'letra'}
# ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# ClassifiedChar {'char': '=', 'char_type': 'util', 'char_class': 'especial'}
# ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# ClassifiedChar {'char': '1', 'char_type': 'util', 'char_class': 'digito'}
# ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# ClassifiedChar {'char': '\n', 'char_type': 'controle', 'char_class': 'especial'}
# ClassifiedChar {'char': '4', 'char_type': 'util', 'char_class': 'digito'}
# ClassifiedChar {'char': '0', 'char_type': 'util', 'char_class': 'digito'}
# ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# ClassifiedChar {'char': 'F', 'char_type': 'util', 'char_class': 'letra'}
# ClassifiedChar {'char': 'O', 'char_type': 'util', 'char_class': 'letra'}
# ClassifiedChar {'char': 'R', 'char_type': 'util', 'char_class': 'letra'}
# ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# ClassifiedChar {'char': 'I', 'char_type': 'util', 'char_class': 'letra'}
# ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# ClassifiedChar {'char': '=', 'char_type': 'util', 'char_class': 'especial'}
# ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# ClassifiedChar {'char': '1', 'char_type': 'util', 'char_class': 'digito'}
# ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# ClassifiedChar {'char': 'T', 'char_type': 'util', 'char_class': 'letra'}
# ClassifiedChar {'char': 'O', 'char_type': 'util', 'char_class': 'letra'}
# ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# ClassifiedChar {'char': 'N', 'char_type': 'util', 'char_class': 'letra'}
# ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# ClassifiedChar {'char': '\n', 'char_type': 'controle', 'char_class': 'especial'}
# ClassifiedChar {'char': '5', 'char_type': 'util', 'char_class': 'digito'}
# ClassifiedChar {'char': '0', 'char_type': 'util', 'char_class': 'digito'}
# ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# ClassifiedChar {'char': 'R', 'char_type': 'util', 'char_class': 'letra'}
# ClassifiedChar {'char': 'E', 'char_type': 'util', 'char_class': 'letra'}
# ClassifiedChar {'char': 'A', 'char_type': 'util', 'char_class': 'letra'}
# ClassifiedChar {'char': 'D', 'char_type': 'util', 'char_class': 'letra'}
# ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# ClassifiedChar {'char': 'Z', 'char_type': 'util', 'char_class': 'letra'}
# ClassifiedChar {'char': '(', 'char_type': 'util', 'char_class': 'especial'}
# ClassifiedChar {'char': 'I', 'char_type': 'util', 'char_class': 'letra'}
# ClassifiedChar {'char': ')', 'char_type': 'util', 'char_class': 'especial'}
# ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# ClassifiedChar {'char': '\n', 'char_type': 'controle', 'char_class': 'especial'}
# ClassifiedChar {'char': '6', 'char_type': 'util', 'char_class': 'digito'}
# ClassifiedChar {'char': '0', 'char_type': 'util', 'char_class': 'digito'}
# ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# ClassifiedChar {'char': 'N', 'char_type': 'util', 'char_class': 'letra'}
# ClassifiedChar {'char': 'E', 'char_type': 'util', 'char_class': 'letra'}
# ClassifiedChar {'char': 'X', 'char_type': 'util', 'char_class': 'letra'}
# ClassifiedChar {'char': 'T', 'char_type': 'util', 'char_class': 'letra'}
# ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# ClassifiedChar {'char': 'I', 'char_type': 'util', 'char_class': 'letra'}
# ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# ClassifiedChar {'char': '\n', 'char_type': 'controle', 'char_class': 'especial'}
# ClassifiedChar {'char': '1', 'char_type': 'util', 'char_class': 'digito'}
# ClassifiedChar {'char': '0', 'char_type': 'util', 'char_class': 'digito'}
# ClassifiedChar {'char': '0', 'char_type': 'util', 'char_class': 'digito'}
# ClassifiedChar {'char': '0', 'char_type': 'util', 'char_class': 'digito'}
# ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# ClassifiedChar {'char': 'F', 'char_type': 'util', 'char_class': 'letra'}
# ClassifiedChar {'char': 'O', 'char_type': 'util', 'char_class': 'letra'}
# ClassifiedChar {'char': 'R', 'char_type': 'util', 'char_class': 'letra'}
# ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# ClassifiedChar {'char': 'I', 'char_type': 'util', 'char_class': 'letra'}
# ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# ClassifiedChar {'char': '=', 'char_type': 'util', 'char_class': 'especial'}
# ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# ClassifiedChar {'char': '1', 'char_type': 'util', 'char_class': 'digito'}
# ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# ClassifiedChar {'char': 'T', 'char_type': 'util', 'char_class': 'letra'}
# ClassifiedChar {'char': 'O', 'char_type': 'util', 'char_class': 'letra'}
# ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# ClassifiedChar {'char': 'N', 'char_type': 'util', 'char_class': 'letra'}
# ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# ClassifiedChar {'char': '\n', 'char_type': 'controle', 'char_class': 'especial'}
# ClassifiedChar {'char': '1', 'char_type': 'util', 'char_class': 'digito'}
# ClassifiedChar {'char': '5', 'char_type': 'util', 'char_class': 'digito'}
# ClassifiedChar {'char': '0', 'char_type': 'util', 'char_class': 'digito'}
# ClassifiedChar {'char': '0', 'char_type': 'util', 'char_class': 'digito'}
# ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# ClassifiedChar {'char': 'F', 'char_type': 'util', 'char_class': 'letra'}
# ClassifiedChar {'char': 'O', 'char_type': 'util', 'char_class': 'letra'}
# ClassifiedChar {'char': 'R', 'char_type': 'util', 'char_class': 'letra'}
# ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# ClassifiedChar {'char': 'J', 'char_type': 'util', 'char_class': 'letra'}
# ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# ClassifiedChar {'char': '=', 'char_type': 'util', 'char_class': 'especial'}
# ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# ClassifiedChar {'char': 'I', 'char_type': 'util', 'char_class': 'letra'}
# ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# ClassifiedChar {'char': 'T', 'char_type': 'util', 'char_class': 'letra'}
# ClassifiedChar {'char': 'O', 'char_type': 'util', 'char_class': 'letra'}
# ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# ClassifiedChar {'char': 'N', 'char_type': 'util', 'char_class': 'letra'}
# ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# ClassifiedChar {'char': '\n', 'char_type': 'controle', 'char_class': 'especial'}
# ClassifiedChar {'char': '1', 'char_type': 'util', 'char_class': 'digito'}
# ClassifiedChar {'char': '5', 'char_type': 'util', 'char_class': 'digito'}
# ClassifiedChar {'char': '1', 'char_type': 'util', 'char_class': 'digito'}
# ClassifiedChar {'char': '0', 'char_type': 'util', 'char_class': 'digito'}
# ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# ClassifiedChar {'char': 'I', 'char_type': 'util', 'char_class': 'letra'}
# ClassifiedChar {'char': 'F', 'char_type': 'util', 'char_class': 'letra'}
# ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# ClassifiedChar {'char': 'Z', 'char_type': 'util', 'char_class': 'letra'}
# ClassifiedChar {'char': '(', 'char_type': 'util', 'char_class': 'especial'}
# ClassifiedChar {'char': 'I', 'char_type': 'util', 'char_class': 'letra'}
# ClassifiedChar {'char': ')', 'char_type': 'util', 'char_class': 'especial'}
# ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# ClassifiedChar {'char': '<', 'char_type': 'util', 'char_class': 'especial'}
# ClassifiedChar {'char': '=', 'char_type': 'util', 'char_class': 'especial'}
# ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# ClassifiedChar {'char': 'Z', 'char_type': 'util', 'char_class': 'letra'}
# ClassifiedChar {'char': '(', 'char_type': 'util', 'char_class': 'especial'}
# ClassifiedChar {'char': 'J', 'char_type': 'util', 'char_class': 'letra'}
# ClassifiedChar {'char': ')', 'char_type': 'util', 'char_class': 'especial'}
# ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# ClassifiedChar {'char': 'T', 'char_type': 'util', 'char_class': 'letra'}
# ClassifiedChar {'char': 'H', 'char_type': 'util', 'char_class': 'letra'}
# ClassifiedChar {'char': 'E', 'char_type': 'util', 'char_class': 'letra'}
# ClassifiedChar {'char': 'N', 'char_type': 'util', 'char_class': 'letra'}
# ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# ClassifiedChar {'char': '1', 'char_type': 'util', 'char_class': 'digito'}
# ClassifiedChar {'char': '8', 'char_type': 'util', 'char_class': 'digito'}
# ClassifiedChar {'char': '0', 'char_type': 'util', 'char_class': 'digito'}
# ClassifiedChar {'char': '0', 'char_type': 'util', 'char_class': 'digito'}
# ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# ClassifiedChar {'char': '\n', 'char_type': 'controle', 'char_class': 'especial'}
# ClassifiedChar {'char': '1', 'char_type': 'util', 'char_class': 'digito'}
# ClassifiedChar {'char': '5', 'char_type': 'util', 'char_class': 'digito'}
# ClassifiedChar {'char': '2', 'char_type': 'util', 'char_class': 'digito'}
# ClassifiedChar {'char': '0', 'char_type': 'util', 'char_class': 'digito'}
# ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# ClassifiedChar {'char': 'L', 'char_type': 'util', 'char_class': 'letra'}
# ClassifiedChar {'char': 'E', 'char_type': 'util', 'char_class': 'letra'}
# ClassifiedChar {'char': 'T', 'char_type': 'util', 'char_class': 'letra'}
# ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# ClassifiedChar {'char': 'T', 'char_type': 'util', 'char_class': 'letra'}
# ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# ClassifiedChar {'char': '=', 'char_type': 'util', 'char_class': 'especial'}
# ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# ClassifiedChar {'char': 'Z', 'char_type': 'util', 'char_class': 'letra'}
# ClassifiedChar {'char': '(', 'char_type': 'util', 'char_class': 'especial'}
# ClassifiedChar {'char': 'J', 'char_type': 'util', 'char_class': 'letra'}
# ClassifiedChar {'char': ')', 'char_type': 'util', 'char_class': 'especial'}
# ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# ClassifiedChar {'char': '\n', 'char_type': 'controle', 'char_class': 'especial'}
# ClassifiedChar {'char': '1', 'char_type': 'util', 'char_class': 'digito'}
# ClassifiedChar {'char': '5', 'char_type': 'util', 'char_class': 'digito'}
# ClassifiedChar {'char': '3', 'char_type': 'util', 'char_class': 'digito'}
# ClassifiedChar {'char': '0', 'char_type': 'util', 'char_class': 'digito'}
# ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# ClassifiedChar {'char': 'L', 'char_type': 'util', 'char_class': 'letra'}
# ClassifiedChar {'char': 'E', 'char_type': 'util', 'char_class': 'letra'}
# ClassifiedChar {'char': 'T', 'char_type': 'util', 'char_class': 'letra'}
# ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# ClassifiedChar {'char': 'Z', 'char_type': 'util', 'char_class': 'letra'}
# ClassifiedChar {'char': '(', 'char_type': 'util', 'char_class': 'especial'}
# ClassifiedChar {'char': 'J', 'char_type': 'util', 'char_class': 'letra'}
# ClassifiedChar {'char': ')', 'char_type': 'util', 'char_class': 'especial'}
# ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# ClassifiedChar {'char': '=', 'char_type': 'util', 'char_class': 'especial'}
# ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# ClassifiedChar {'char': 'Z', 'char_type': 'util', 'char_class': 'letra'}
# ClassifiedChar {'char': '(', 'char_type': 'util', 'char_class': 'especial'}
# ClassifiedChar {'char': 'I', 'char_type': 'util', 'char_class': 'letra'}
# ClassifiedChar {'char': ')', 'char_type': 'util', 'char_class': 'especial'}
# ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# ClassifiedChar {'char': '\n', 'char_type': 'controle', 'char_class': 'especial'}
# ClassifiedChar {'char': '1', 'char_type': 'util', 'char_class': 'digito'}
# ClassifiedChar {'char': '5', 'char_type': 'util', 'char_class': 'digito'}
# ClassifiedChar {'char': '4', 'char_type': 'util', 'char_class': 'digito'}
# ClassifiedChar {'char': '0', 'char_type': 'util', 'char_class': 'digito'}
# ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# ClassifiedChar {'char': 'L', 'char_type': 'util', 'char_class': 'letra'}
# ClassifiedChar {'char': 'E', 'char_type': 'util', 'char_class': 'letra'}
# ClassifiedChar {'char': 'T', 'char_type': 'util', 'char_class': 'letra'}
# ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# ClassifiedChar {'char': 'Z', 'char_type': 'util', 'char_class': 'letra'}
# ClassifiedChar {'char': '(', 'char_type': 'util', 'char_class': 'especial'}
# ClassifiedChar {'char': 'I', 'char_type': 'util', 'char_class': 'letra'}
# ClassifiedChar {'char': ')', 'char_type': 'util', 'char_class': 'especial'}
# ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# ClassifiedChar {'char': '=', 'char_type': 'util', 'char_class': 'especial'}
# ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# ClassifiedChar {'char': 'T', 'char_type': 'util', 'char_class': 'letra'}
# ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# ClassifiedChar {'char': '\n', 'char_type': 'controle', 'char_class': 'especial'}
# ClassifiedChar {'char': '1', 'char_type': 'util', 'char_class': 'digito'}
# ClassifiedChar {'char': '8', 'char_type': 'util', 'char_class': 'digito'}
# ClassifiedChar {'char': '0', 'char_type': 'util', 'char_class': 'digito'}
# ClassifiedChar {'char': '0', 'char_type': 'util', 'char_class': 'digito'}
# ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# ClassifiedChar {'char': 'N', 'char_type': 'util', 'char_class': 'letra'}
# ClassifiedChar {'char': 'E', 'char_type': 'util', 'char_class': 'letra'}
# ClassifiedChar {'char': 'X', 'char_type': 'util', 'char_class': 'letra'}
# ClassifiedChar {'char': 'T', 'char_type': 'util', 'char_class': 'letra'}
# ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# ClassifiedChar {'char': 'J', 'char_type': 'util', 'char_class': 'letra'}
# ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# ClassifiedChar {'char': '\n', 'char_type': 'controle', 'char_class': 'especial'}
# ClassifiedChar {'char': '1', 'char_type': 'util', 'char_class': 'digito'}
# ClassifiedChar {'char': '8', 'char_type': 'util', 'char_class': 'digito'}
# ClassifiedChar {'char': '1', 'char_type': 'util', 'char_class': 'digito'}
# ClassifiedChar {'char': '0', 'char_type': 'util', 'char_class': 'digito'}
# ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# ClassifiedChar {'char': 'N', 'char_type': 'util', 'char_class': 'letra'}
# ClassifiedChar {'char': 'E', 'char_type': 'util', 'char_class': 'letra'}
# ClassifiedChar {'char': 'X', 'char_type': 'util', 'char_class': 'letra'}
# ClassifiedChar {'char': 'T', 'char_type': 'util', 'char_class': 'letra'}
# ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# ClassifiedChar {'char': 'I', 'char_type': 'util', 'char_class': 'letra'}
# ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# ClassifiedChar {'char': '\n', 'char_type': 'controle', 'char_class': 'especial'}
# ClassifiedChar {'char': '9', 'char_type': 'util', 'char_class': 'digito'}
# ClassifiedChar {'char': '0', 'char_type': 'util', 'char_class': 'digito'}
# ClassifiedChar {'char': '0', 'char_type': 'util', 'char_class': 'digito'}
# ClassifiedChar {'char': '0', 'char_type': 'util', 'char_class': 'digito'}
# ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# ClassifiedChar {'char': 'F', 'char_type': 'util', 'char_class': 'letra'}
# ClassifiedChar {'char': 'O', 'char_type': 'util', 'char_class': 'letra'}
# ClassifiedChar {'char': 'R', 'char_type': 'util', 'char_class': 'letra'}
# ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# ClassifiedChar {'char': 'I', 'char_type': 'util', 'char_class': 'letra'}
# ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# ClassifiedChar {'char': '=', 'char_type': 'util', 'char_class': 'especial'}
# ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# ClassifiedChar {'char': '1', 'char_type': 'util', 'char_class': 'digito'}
# ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# ClassifiedChar {'char': 'T', 'char_type': 'util', 'char_class': 'letra'}
# ClassifiedChar {'char': 'O', 'char_type': 'util', 'char_class': 'letra'}
# ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# ClassifiedChar {'char': '1', 'char_type': 'util', 'char_class': 'digito'}
# ClassifiedChar {'char': '0', 'char_type': 'util', 'char_class': 'digito'}
# ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# ClassifiedChar {'char': '\n', 'char_type': 'controle', 'char_class': 'especial'}
# ClassifiedChar {'char': '9', 'char_type': 'util', 'char_class': 'digito'}
# ClassifiedChar {'char': '0', 'char_type': 'util', 'char_class': 'digito'}
# ClassifiedChar {'char': '0', 'char_type': 'util', 'char_class': 'digito'}
# ClassifiedChar {'char': '0', 'char_type': 'util', 'char_class': 'digito'}
# ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# ClassifiedChar {'char': 'P', 'char_type': 'util', 'char_class': 'letra'}
# ClassifiedChar {'char': 'R', 'char_type': 'util', 'char_class': 'letra'}
# ClassifiedChar {'char': 'I', 'char_type': 'util', 'char_class': 'letra'}
# ClassifiedChar {'char': 'N', 'char_type': 'util', 'char_class': 'letra'}
# ClassifiedChar {'char': 'T', 'char_type': 'util', 'char_class': 'letra'}
# ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# ClassifiedChar {'char': 'Z', 'char_type': 'util', 'char_class': 'letra'}
# ClassifiedChar {'char': '(', 'char_type': 'util', 'char_class': 'especial'}
# ClassifiedChar {'char': 'I', 'char_type': 'util', 'char_class': 'letra'}
# ClassifiedChar {'char': ')', 'char_type': 'util', 'char_class': 'especial'}
# ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# ClassifiedChar {'char': '\n', 'char_type': 'controle', 'char_class': 'especial'}
# ClassifiedChar {'char': '9', 'char_type': 'util', 'char_class': 'digito'}
# ClassifiedChar {'char': '0', 'char_type': 'util', 'char_class': 'digito'}
# ClassifiedChar {'char': '0', 'char_type': 'util', 'char_class': 'digito'}
# ClassifiedChar {'char': '0', 'char_type': 'util', 'char_class': 'digito'}
# ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# ClassifiedChar {'char': 'N', 'char_type': 'util', 'char_class': 'letra'}
# ClassifiedChar {'char': 'E', 'char_type': 'util', 'char_class': 'letra'}
# ClassifiedChar {'char': 'X', 'char_type': 'util', 'char_class': 'letra'}
# ClassifiedChar {'char': 'T', 'char_type': 'util', 'char_class': 'letra'}
# ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# ClassifiedChar {'char': 'I', 'char_type': 'util', 'char_class': 'letra'}
# ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}

# %%
lexical.list_events(20000)
# Out:
# 1.  ClassifiedChar {'char': '1', 'char_type': 'util', 'char_class': 'digito'}
# 2.  ClassifiedChar {'char': '0', 'char_type': 'util', 'char_class': 'digito'}
# 3.  ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# 4.  ClassifiedChar {'char': 'L', 'char_type': 'util', 'char_class': 'letra'}
# 5.  ClassifiedChar {'char': 'E', 'char_type': 'util', 'char_class': 'letra'}
# 6.  ClassifiedChar {'char': 'T', 'char_type': 'util', 'char_class': 'letra'}
# 7.  ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# 8.  ClassifiedChar {'char': 'N', 'char_type': 'util', 'char_class': 'letra'}
# 9.  ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# 10.  ClassifiedChar {'char': '=', 'char_type': 'util', 'char_class': 'especial'}
# 11.  ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# 12.  ClassifiedChar {'char': '1', 'char_type': 'util', 'char_class': 'digito'}
# 13.  ClassifiedChar {'char': '0', 'char_type': 'util', 'char_class': 'digito'}
# 14.  ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# 15.  ClassifiedChar {'char': '\n', 'char_type': 'controle', 'char_class': 'especial'}
# 16.  ClassifiedChar {'char': '2', 'char_type': 'util', 'char_class': 'digito'}
# 17.  ClassifiedChar {'char': '0', 'char_type': 'util', 'char_class': 'digito'}
# 18.  ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# 19.  ClassifiedChar {'char': 'D', 'char_type': 'util', 'char_class': 'letra'}
# 20.  ClassifiedChar {'char': 'A', 'char_type': 'util', 'char_class': 'letra'}
# 21.  ClassifiedChar {'char': 'T', 'char_type': 'util', 'char_class': 'letra'}
# 22.  ClassifiedChar {'char': 'A', 'char_type': 'util', 'char_class': 'letra'}
# 23.  ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# 24.  ClassifiedChar {'char': '5', 'char_type': 'util', 'char_class': 'digito'}
# 25.  ClassifiedChar {'char': '3', 'char_type': 'util', 'char_class': 'digito'}
# 26.  ClassifiedChar {'char': ',', 'char_type': 'util', 'char_class': 'especial'}
# 27.  ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# 28.  ClassifiedChar {'char': '7', 'char_type': 'util', 'char_class': 'digito'}
# 29.  ClassifiedChar {'char': '7', 'char_type': 'util', 'char_class': 'digito'}
# 30.  ClassifiedChar {'char': ',', 'char_type': 'util', 'char_class': 'especial'}
# 31.  ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# 32.  ClassifiedChar {'char': '8', 'char_type': 'util', 'char_class': 'digito'}
# 33.  ClassifiedChar {'char': '2', 'char_type': 'util', 'char_class': 'digito'}
# 34.  ClassifiedChar {'char': ',', 'char_type': 'util', 'char_class': 'especial'}
# 35.  ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# 36.  ClassifiedChar {'char': '1', 'char_type': 'util', 'char_class': 'digito'}
# 37.  ClassifiedChar {'char': '2', 'char_type': 'util', 'char_class': 'digito'}
# 38.  ClassifiedChar {'char': ',', 'char_type': 'util', 'char_class': 'especial'}
# 39.  ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# 40.  ClassifiedChar {'char': '3', 'char_type': 'util', 'char_class': 'digito'}
# 41.  ClassifiedChar {'char': '8', 'char_type': 'util', 'char_class': 'digito'}
# 42.  ClassifiedChar {'char': ',', 'char_type': 'util', 'char_class': 'especial'}
# 43.  ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# 44.  ClassifiedChar {'char': '9', 'char_type': 'util', 'char_class': 'digito'}
# 45.  ClassifiedChar {'char': '0', 'char_type': 'util', 'char_class': 'digito'}
# 46.  ClassifiedChar {'char': ',', 'char_type': 'util', 'char_class': 'especial'}
# 47.  ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# 48.  ClassifiedChar {'char': '1', 'char_type': 'util', 'char_class': 'digito'}
# 49.  ClassifiedChar {'char': '6', 'char_type': 'util', 'char_class': 'digito'}
# 50.  ClassifiedChar {'char': ',', 'char_type': 'util', 'char_class': 'especial'}
# 51.  ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# 52.  ClassifiedChar {'char': '7', 'char_type': 'util', 'char_class': 'digito'}
# 53.  ClassifiedChar {'char': '2', 'char_type': 'util', 'char_class': 'digito'}
# 54.  ClassifiedChar {'char': ',', 'char_type': 'util', 'char_class': 'especial'}
# 55.  ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# 56.  ClassifiedChar {'char': '5', 'char_type': 'util', 'char_class': 'digito'}
# 57.  ClassifiedChar {'char': '5', 'char_type': 'util', 'char_class': 'digito'}
# 58.  ClassifiedChar {'char': ',', 'char_type': 'util', 'char_class': 'especial'}
# 59.  ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# 60.  ClassifiedChar {'char': '6', 'char_type': 'util', 'char_class': 'digito'}
# 61.  ClassifiedChar {'char': '2', 'char_type': 'util', 'char_class': 'digito'}
# 62.  ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# 63.  ClassifiedChar {'char': '\n', 'char_type': 'controle', 'char_class': 'especial'}
# 64.  ClassifiedChar {'char': '3', 'char_type': 'util', 'char_class': 'digito'}
# 65.  ClassifiedChar {'char': '0', 'char_type': 'util', 'char_class': 'digito'}
# 66.  ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# 67.  ClassifiedChar {'char': 'D', 'char_type': 'util', 'char_class': 'letra'}
# 68.  ClassifiedChar {'char': 'I', 'char_type': 'util', 'char_class': 'letra'}
# 69.  ClassifiedChar {'char': 'M', 'char_type': 'util', 'char_class': 'letra'}
# 70.  ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# 71.  ClassifiedChar {'char': 'Z', 'char_type': 'util', 'char_class': 'letra'}
# 72.  ClassifiedChar {'char': '(', 'char_type': 'util', 'char_class': 'especial'}
# 73.  ClassifiedChar {'char': '1', 'char_type': 'util', 'char_class': 'digito'}
# 74.  ClassifiedChar {'char': '0', 'char_type': 'util', 'char_class': 'digito'}
# 75.  ClassifiedChar {'char': ')', 'char_type': 'util', 'char_class': 'especial'}
# 76.  ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# 77.  ClassifiedChar {'char': '\n', 'char_type': 'controle', 'char_class': 'especial'}
# 78.  ClassifiedChar {'char': '3', 'char_type': 'util', 'char_class': 'digito'}
# 79.  ClassifiedChar {'char': '5', 'char_type': 'util', 'char_class': 'digito'}
# 80.  ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# 81.  ClassifiedChar {'char': 'D', 'char_type': 'util', 'char_class': 'letra'}
# 82.  ClassifiedChar {'char': 'I', 'char_type': 'util', 'char_class': 'letra'}
# 83.  ClassifiedChar {'char': 'M', 'char_type': 'util', 'char_class': 'letra'}
# 84.  ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# 85.  ClassifiedChar {'char': 'S', 'char_type': 'util', 'char_class': 'letra'}
# 86.  ClassifiedChar {'char': '(', 'char_type': 'util', 'char_class': 'especial'}
# 87.  ClassifiedChar {'char': '1', 'char_type': 'util', 'char_class': 'digito'}
# 88.  ClassifiedChar {'char': '0', 'char_type': 'util', 'char_class': 'digito'}
# 89.  ClassifiedChar {'char': '0', 'char_type': 'util', 'char_class': 'digito'}
# 90.  ClassifiedChar {'char': '0', 'char_type': 'util', 'char_class': 'digito'}
# 91.  ClassifiedChar {'char': ')', 'char_type': 'util', 'char_class': 'especial'}
# 92.  ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# 93.  ClassifiedChar {'char': '\n', 'char_type': 'controle', 'char_class': 'especial'}
# 94.  ClassifiedChar {'char': '3', 'char_type': 'util', 'char_class': 'digito'}
# 95.  ClassifiedChar {'char': '6', 'char_type': 'util', 'char_class': 'digito'}
# 96.  ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# 97.  ClassifiedChar {'char': 'L', 'char_type': 'util', 'char_class': 'letra'}
# 98.  ClassifiedChar {'char': 'E', 'char_type': 'util', 'char_class': 'letra'}
# 99.  ClassifiedChar {'char': 'T', 'char_type': 'util', 'char_class': 'letra'}
# 100.  ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# 101.  ClassifiedChar {'char': 'P', 'char_type': 'util', 'char_class': 'letra'}
# 102.  ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# 103.  ClassifiedChar {'char': '=', 'char_type': 'util', 'char_class': 'especial'}
# 104.  ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# 105.  ClassifiedChar {'char': '1', 'char_type': 'util', 'char_class': 'digito'}
# 106.  ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# 107.  ClassifiedChar {'char': '\n', 'char_type': 'controle', 'char_class': 'especial'}
# 108.  ClassifiedChar {'char': '4', 'char_type': 'util', 'char_class': 'digito'}
# 109.  ClassifiedChar {'char': '0', 'char_type': 'util', 'char_class': 'digito'}
# 110.  ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# 111.  ClassifiedChar {'char': 'F', 'char_type': 'util', 'char_class': 'letra'}
# 112.  ClassifiedChar {'char': 'O', 'char_type': 'util', 'char_class': 'letra'}
# 113.  ClassifiedChar {'char': 'R', 'char_type': 'util', 'char_class': 'letra'}
# 114.  ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# 115.  ClassifiedChar {'char': 'I', 'char_type': 'util', 'char_class': 'letra'}
# 116.  ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# 117.  ClassifiedChar {'char': '=', 'char_type': 'util', 'char_class': 'especial'}
# 118.  ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# 119.  ClassifiedChar {'char': '1', 'char_type': 'util', 'char_class': 'digito'}
# 120.  ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# 121.  ClassifiedChar {'char': 'T', 'char_type': 'util', 'char_class': 'letra'}
# 122.  ClassifiedChar {'char': 'O', 'char_type': 'util', 'char_class': 'letra'}
# 123.  ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# 124.  ClassifiedChar {'char': 'N', 'char_type': 'util', 'char_class': 'letra'}
# 125.  ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# 126.  ClassifiedChar {'char': '\n', 'char_type': 'controle', 'char_class': 'especial'}
# 127.  ClassifiedChar {'char': '5', 'char_type': 'util', 'char_class': 'digito'}
# 128.  ClassifiedChar {'char': '0', 'char_type': 'util', 'char_class': 'digito'}
# 129.  ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# 130.  ClassifiedChar {'char': 'R', 'char_type': 'util', 'char_class': 'letra'}
# 131.  ClassifiedChar {'char': 'E', 'char_type': 'util', 'char_class': 'letra'}
# 132.  ClassifiedChar {'char': 'A', 'char_type': 'util', 'char_class': 'letra'}
# 133.  ClassifiedChar {'char': 'D', 'char_type': 'util', 'char_class': 'letra'}
# 134.  ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# 135.  ClassifiedChar {'char': 'Z', 'char_type': 'util', 'char_class': 'letra'}
# 136.  ClassifiedChar {'char': '(', 'char_type': 'util', 'char_class': 'especial'}
# 137.  ClassifiedChar {'char': 'I', 'char_type': 'util', 'char_class': 'letra'}
# 138.  ClassifiedChar {'char': ')', 'char_type': 'util', 'char_class': 'especial'}
# 139.  ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# 140.  ClassifiedChar {'char': '\n', 'char_type': 'controle', 'char_class': 'especial'}
# 141.  ClassifiedChar {'char': '6', 'char_type': 'util', 'char_class': 'digito'}
# 142.  ClassifiedChar {'char': '0', 'char_type': 'util', 'char_class': 'digito'}
# 143.  ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# 144.  ClassifiedChar {'char': 'N', 'char_type': 'util', 'char_class': 'letra'}
# 145.  ClassifiedChar {'char': 'E', 'char_type': 'util', 'char_class': 'letra'}
# 146.  ClassifiedChar {'char': 'X', 'char_type': 'util', 'char_class': 'letra'}
# 147.  ClassifiedChar {'char': 'T', 'char_type': 'util', 'char_class': 'letra'}
# 148.  ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# 149.  ClassifiedChar {'char': 'I', 'char_type': 'util', 'char_class': 'letra'}
# 150.  ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# 151.  ClassifiedChar {'char': '\n', 'char_type': 'controle', 'char_class': 'especial'}
# 152.  ClassifiedChar {'char': '1', 'char_type': 'util', 'char_class': 'digito'}
# 153.  ClassifiedChar {'char': '0', 'char_type': 'util', 'char_class': 'digito'}
# 154.  ClassifiedChar {'char': '0', 'char_type': 'util', 'char_class': 'digito'}
# 155.  ClassifiedChar {'char': '0', 'char_type': 'util', 'char_class': 'digito'}
# 156.  ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# 157.  ClassifiedChar {'char': 'F', 'char_type': 'util', 'char_class': 'letra'}
# 158.  ClassifiedChar {'char': 'O', 'char_type': 'util', 'char_class': 'letra'}
# 159.  ClassifiedChar {'char': 'R', 'char_type': 'util', 'char_class': 'letra'}
# 160.  ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# 161.  ClassifiedChar {'char': 'I', 'char_type': 'util', 'char_class': 'letra'}
# 162.  ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# 163.  ClassifiedChar {'char': '=', 'char_type': 'util', 'char_class': 'especial'}
# 164.  ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# 165.  ClassifiedChar {'char': '1', 'char_type': 'util', 'char_class': 'digito'}
# 166.  ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# 167.  ClassifiedChar {'char': 'T', 'char_type': 'util', 'char_class': 'letra'}
# 168.  ClassifiedChar {'char': 'O', 'char_type': 'util', 'char_class': 'letra'}
# 169.  ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# 170.  ClassifiedChar {'char': 'N', 'char_type': 'util', 'char_class': 'letra'}
# 171.  ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# 172.  ClassifiedChar {'char': '\n', 'char_type': 'controle', 'char_class': 'especial'}
# 173.  ClassifiedChar {'char': '1', 'char_type': 'util', 'char_class': 'digito'}
# 174.  ClassifiedChar {'char': '5', 'char_type': 'util', 'char_class': 'digito'}
# 175.  ClassifiedChar {'char': '0', 'char_type': 'util', 'char_class': 'digito'}
# 176.  ClassifiedChar {'char': '0', 'char_type': 'util', 'char_class': 'digito'}
# 177.  ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# 178.  ClassifiedChar {'char': 'F', 'char_type': 'util', 'char_class': 'letra'}
# 179.  ClassifiedChar {'char': 'O', 'char_type': 'util', 'char_class': 'letra'}
# 180.  ClassifiedChar {'char': 'R', 'char_type': 'util', 'char_class': 'letra'}
# 181.  ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# 182.  ClassifiedChar {'char': 'J', 'char_type': 'util', 'char_class': 'letra'}
# 183.  ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# 184.  ClassifiedChar {'char': '=', 'char_type': 'util', 'char_class': 'especial'}
# 185.  ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# 186.  ClassifiedChar {'char': 'I', 'char_type': 'util', 'char_class': 'letra'}
# 187.  ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# 188.  ClassifiedChar {'char': 'T', 'char_type': 'util', 'char_class': 'letra'}
# 189.  ClassifiedChar {'char': 'O', 'char_type': 'util', 'char_class': 'letra'}
# 190.  ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# 191.  ClassifiedChar {'char': 'N', 'char_type': 'util', 'char_class': 'letra'}
# 192.  ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# 193.  ClassifiedChar {'char': '\n', 'char_type': 'controle', 'char_class': 'especial'}
# 194.  ClassifiedChar {'char': '1', 'char_type': 'util', 'char_class': 'digito'}
# 195.  ClassifiedChar {'char': '5', 'char_type': 'util', 'char_class': 'digito'}
# 196.  ClassifiedChar {'char': '1', 'char_type': 'util', 'char_class': 'digito'}
# 197.  ClassifiedChar {'char': '0', 'char_type': 'util', 'char_class': 'digito'}
# 198.  ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# 199.  ClassifiedChar {'char': 'I', 'char_type': 'util', 'char_class': 'letra'}
# 200.  ClassifiedChar {'char': 'F', 'char_type': 'util', 'char_class': 'letra'}
# 201.  ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# 202.  ClassifiedChar {'char': 'Z', 'char_type': 'util', 'char_class': 'letra'}
# 203.  ClassifiedChar {'char': '(', 'char_type': 'util', 'char_class': 'especial'}
# 204.  ClassifiedChar {'char': 'I', 'char_type': 'util', 'char_class': 'letra'}
# 205.  ClassifiedChar {'char': ')', 'char_type': 'util', 'char_class': 'especial'}
# 206.  ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# 207.  ClassifiedChar {'char': '<', 'char_type': 'util', 'char_class': 'especial'}
# 208.  ClassifiedChar {'char': '=', 'char_type': 'util', 'char_class': 'especial'}
# 209.  ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# 210.  ClassifiedChar {'char': 'Z', 'char_type': 'util', 'char_class': 'letra'}
# 211.  ClassifiedChar {'char': '(', 'char_type': 'util', 'char_class': 'especial'}
# 212.  ClassifiedChar {'char': 'J', 'char_type': 'util', 'char_class': 'letra'}
# 213.  ClassifiedChar {'char': ')', 'char_type': 'util', 'char_class': 'especial'}
# 214.  ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# 215.  ClassifiedChar {'char': 'T', 'char_type': 'util', 'char_class': 'letra'}
# 216.  ClassifiedChar {'char': 'H', 'char_type': 'util', 'char_class': 'letra'}
# 217.  ClassifiedChar {'char': 'E', 'char_type': 'util', 'char_class': 'letra'}
# 218.  ClassifiedChar {'char': 'N', 'char_type': 'util', 'char_class': 'letra'}
# 219.  ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# 220.  ClassifiedChar {'char': '1', 'char_type': 'util', 'char_class': 'digito'}
# 221.  ClassifiedChar {'char': '8', 'char_type': 'util', 'char_class': 'digito'}
# 222.  ClassifiedChar {'char': '0', 'char_type': 'util', 'char_class': 'digito'}
# 223.  ClassifiedChar {'char': '0', 'char_type': 'util', 'char_class': 'digito'}
# 224.  ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# 225.  ClassifiedChar {'char': '\n', 'char_type': 'controle', 'char_class': 'especial'}
# 226.  ClassifiedChar {'char': '1', 'char_type': 'util', 'char_class': 'digito'}
# 227.  ClassifiedChar {'char': '5', 'char_type': 'util', 'char_class': 'digito'}
# 228.  ClassifiedChar {'char': '2', 'char_type': 'util', 'char_class': 'digito'}
# 229.  ClassifiedChar {'char': '0', 'char_type': 'util', 'char_class': 'digito'}
# 230.  ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# 231.  ClassifiedChar {'char': 'L', 'char_type': 'util', 'char_class': 'letra'}
# 232.  ClassifiedChar {'char': 'E', 'char_type': 'util', 'char_class': 'letra'}
# 233.  ClassifiedChar {'char': 'T', 'char_type': 'util', 'char_class': 'letra'}
# 234.  ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# 235.  ClassifiedChar {'char': 'T', 'char_type': 'util', 'char_class': 'letra'}
# 236.  ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# 237.  ClassifiedChar {'char': '=', 'char_type': 'util', 'char_class': 'especial'}
# 238.  ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# 239.  ClassifiedChar {'char': 'Z', 'char_type': 'util', 'char_class': 'letra'}
# 240.  ClassifiedChar {'char': '(', 'char_type': 'util', 'char_class': 'especial'}
# 241.  ClassifiedChar {'char': 'J', 'char_type': 'util', 'char_class': 'letra'}
# 242.  ClassifiedChar {'char': ')', 'char_type': 'util', 'char_class': 'especial'}
# 243.  ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# 244.  ClassifiedChar {'char': '\n', 'char_type': 'controle', 'char_class': 'especial'}
# 245.  ClassifiedChar {'char': '1', 'char_type': 'util', 'char_class': 'digito'}
# 246.  ClassifiedChar {'char': '5', 'char_type': 'util', 'char_class': 'digito'}
# 247.  ClassifiedChar {'char': '3', 'char_type': 'util', 'char_class': 'digito'}
# 248.  ClassifiedChar {'char': '0', 'char_type': 'util', 'char_class': 'digito'}
# 249.  ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# 250.  ClassifiedChar {'char': 'L', 'char_type': 'util', 'char_class': 'letra'}
# 251.  ClassifiedChar {'char': 'E', 'char_type': 'util', 'char_class': 'letra'}
# 252.  ClassifiedChar {'char': 'T', 'char_type': 'util', 'char_class': 'letra'}
# 253.  ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# 254.  ClassifiedChar {'char': 'Z', 'char_type': 'util', 'char_class': 'letra'}
# 255.  ClassifiedChar {'char': '(', 'char_type': 'util', 'char_class': 'especial'}
# 256.  ClassifiedChar {'char': 'J', 'char_type': 'util', 'char_class': 'letra'}
# 257.  ClassifiedChar {'char': ')', 'char_type': 'util', 'char_class': 'especial'}
# 258.  ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# 259.  ClassifiedChar {'char': '=', 'char_type': 'util', 'char_class': 'especial'}
# 260.  ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# 261.  ClassifiedChar {'char': 'Z', 'char_type': 'util', 'char_class': 'letra'}
# 262.  ClassifiedChar {'char': '(', 'char_type': 'util', 'char_class': 'especial'}
# 263.  ClassifiedChar {'char': 'I', 'char_type': 'util', 'char_class': 'letra'}
# 264.  ClassifiedChar {'char': ')', 'char_type': 'util', 'char_class': 'especial'}
# 265.  ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# 266.  ClassifiedChar {'char': '\n', 'char_type': 'controle', 'char_class': 'especial'}
# 267.  ClassifiedChar {'char': '1', 'char_type': 'util', 'char_class': 'digito'}
# 268.  ClassifiedChar {'char': '5', 'char_type': 'util', 'char_class': 'digito'}
# 269.  ClassifiedChar {'char': '4', 'char_type': 'util', 'char_class': 'digito'}
# 270.  ClassifiedChar {'char': '0', 'char_type': 'util', 'char_class': 'digito'}
# 271.  ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# 272.  ClassifiedChar {'char': 'L', 'char_type': 'util', 'char_class': 'letra'}
# 273.  ClassifiedChar {'char': 'E', 'char_type': 'util', 'char_class': 'letra'}
# 274.  ClassifiedChar {'char': 'T', 'char_type': 'util', 'char_class': 'letra'}
# 275.  ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# 276.  ClassifiedChar {'char': 'Z', 'char_type': 'util', 'char_class': 'letra'}
# 277.  ClassifiedChar {'char': '(', 'char_type': 'util', 'char_class': 'especial'}
# 278.  ClassifiedChar {'char': 'I', 'char_type': 'util', 'char_class': 'letra'}
# 279.  ClassifiedChar {'char': ')', 'char_type': 'util', 'char_class': 'especial'}
# 280.  ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# 281.  ClassifiedChar {'char': '=', 'char_type': 'util', 'char_class': 'especial'}
# 282.  ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# 283.  ClassifiedChar {'char': 'T', 'char_type': 'util', 'char_class': 'letra'}
# 284.  ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# 285.  ClassifiedChar {'char': '\n', 'char_type': 'controle', 'char_class': 'especial'}
# 286.  ClassifiedChar {'char': '1', 'char_type': 'util', 'char_class': 'digito'}
# 287.  ClassifiedChar {'char': '8', 'char_type': 'util', 'char_class': 'digito'}
# 288.  ClassifiedChar {'char': '0', 'char_type': 'util', 'char_class': 'digito'}
# 289.  ClassifiedChar {'char': '0', 'char_type': 'util', 'char_class': 'digito'}
# 290.  ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# 291.  ClassifiedChar {'char': 'N', 'char_type': 'util', 'char_class': 'letra'}
# 292.  ClassifiedChar {'char': 'E', 'char_type': 'util', 'char_class': 'letra'}
# 293.  ClassifiedChar {'char': 'X', 'char_type': 'util', 'char_class': 'letra'}
# 294.  ClassifiedChar {'char': 'T', 'char_type': 'util', 'char_class': 'letra'}
# 295.  ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# 296.  ClassifiedChar {'char': 'J', 'char_type': 'util', 'char_class': 'letra'}
# 297.  ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# 298.  ClassifiedChar {'char': '\n', 'char_type': 'controle', 'char_class': 'especial'}
# 299.  ClassifiedChar {'char': '1', 'char_type': 'util', 'char_class': 'digito'}
# 300.  ClassifiedChar {'char': '8', 'char_type': 'util', 'char_class': 'digito'}
# 301.  ClassifiedChar {'char': '1', 'char_type': 'util', 'char_class': 'digito'}
# 302.  ClassifiedChar {'char': '0', 'char_type': 'util', 'char_class': 'digito'}
# 303.  ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# 304.  ClassifiedChar {'char': 'N', 'char_type': 'util', 'char_class': 'letra'}
# 305.  ClassifiedChar {'char': 'E', 'char_type': 'util', 'char_class': 'letra'}
# 306.  ClassifiedChar {'char': 'X', 'char_type': 'util', 'char_class': 'letra'}
# 307.  ClassifiedChar {'char': 'T', 'char_type': 'util', 'char_class': 'letra'}
# 308.  ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# 309.  ClassifiedChar {'char': 'I', 'char_type': 'util', 'char_class': 'letra'}
# 310.  ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# 311.  ClassifiedChar {'char': '\n', 'char_type': 'controle', 'char_class': 'especial'}
# 312.  ClassifiedChar {'char': '9', 'char_type': 'util', 'char_class': 'digito'}
# 313.  ClassifiedChar {'char': '0', 'char_type': 'util', 'char_class': 'digito'}
# 314.  ClassifiedChar {'char': '0', 'char_type': 'util', 'char_class': 'digito'}
# 315.  ClassifiedChar {'char': '0', 'char_type': 'util', 'char_class': 'digito'}
# 316.  ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# 317.  ClassifiedChar {'char': 'F', 'char_type': 'util', 'char_class': 'letra'}
# 318.  ClassifiedChar {'char': 'O', 'char_type': 'util', 'char_class': 'letra'}
# 319.  ClassifiedChar {'char': 'R', 'char_type': 'util', 'char_class': 'letra'}
# 320.  ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# 321.  ClassifiedChar {'char': 'I', 'char_type': 'util', 'char_class': 'letra'}
# 322.  ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# 323.  ClassifiedChar {'char': '=', 'char_type': 'util', 'char_class': 'especial'}
# 324.  ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# 325.  ClassifiedChar {'char': '1', 'char_type': 'util', 'char_class': 'digito'}
# 326.  ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# 327.  ClassifiedChar {'char': 'T', 'char_type': 'util', 'char_class': 'letra'}
# 328.  ClassifiedChar {'char': 'O', 'char_type': 'util', 'char_class': 'letra'}
# 329.  ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# 330.  ClassifiedChar {'char': '1', 'char_type': 'util', 'char_class': 'digito'}
# 331.  ClassifiedChar {'char': '0', 'char_type': 'util', 'char_class': 'digito'}
# 332.  ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# 333.  ClassifiedChar {'char': '\n', 'char_type': 'controle', 'char_class': 'especial'}
# 334.  ClassifiedChar {'char': '9', 'char_type': 'util', 'char_class': 'digito'}
# 335.  ClassifiedChar {'char': '0', 'char_type': 'util', 'char_class': 'digito'}
# 336.  ClassifiedChar {'char': '0', 'char_type': 'util', 'char_class': 'digito'}
# 337.  ClassifiedChar {'char': '0', 'char_type': 'util', 'char_class': 'digito'}
# 338.  ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# 339.  ClassifiedChar {'char': 'P', 'char_type': 'util', 'char_class': 'letra'}
# 340.  ClassifiedChar {'char': 'R', 'char_type': 'util', 'char_class': 'letra'}
# 341.  ClassifiedChar {'char': 'I', 'char_type': 'util', 'char_class': 'letra'}
# 342.  ClassifiedChar {'char': 'N', 'char_type': 'util', 'char_class': 'letra'}
# 343.  ClassifiedChar {'char': 'T', 'char_type': 'util', 'char_class': 'letra'}
# 344.  ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# 345.  ClassifiedChar {'char': 'Z', 'char_type': 'util', 'char_class': 'letra'}
# 346.  ClassifiedChar {'char': '(', 'char_type': 'util', 'char_class': 'especial'}
# 347.  ClassifiedChar {'char': 'I', 'char_type': 'util', 'char_class': 'letra'}
# 348.  ClassifiedChar {'char': ')', 'char_type': 'util', 'char_class': 'especial'}
# 349.  ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# 350.  ClassifiedChar {'char': '\n', 'char_type': 'controle', 'char_class': 'especial'}
# 351.  ClassifiedChar {'char': '9', 'char_type': 'util', 'char_class': 'digito'}
# 352.  ClassifiedChar {'char': '0', 'char_type': 'util', 'char_class': 'digito'}
# 353.  ClassifiedChar {'char': '0', 'char_type': 'util', 'char_class': 'digito'}
# 354.  ClassifiedChar {'char': '0', 'char_type': 'util', 'char_class': 'digito'}
# 355.  ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# 356.  ClassifiedChar {'char': 'N', 'char_type': 'util', 'char_class': 'letra'}
# 357.  ClassifiedChar {'char': 'E', 'char_type': 'util', 'char_class': 'letra'}
# 358.  ClassifiedChar {'char': 'X', 'char_type': 'util', 'char_class': 'letra'}
# 359.  ClassifiedChar {'char': 'T', 'char_type': 'util', 'char_class': 'letra'}
# 360.  ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}
# 361.  ClassifiedChar {'char': 'I', 'char_type': 'util', 'char_class': 'letra'}
# 362.  ClassifiedChar {'char': 'espaco', 'char_type': 'descartavel', 'char_class': 'delimitador'}

# %%
lexical.fetch_exhaustive(debug=True)
# Out:
# Token {'token': 'digit', 'value': '10'}
# Token {'token': 'LET', 'value': 'LET'}
# Token {'token': 'letter', 'value': 'N'}
# Token {'token': '=', 'value': '='}
# Token {'token': 'digit', 'value': '10'}
# Token {'token': '\n', 'value': '\n'}
# Token {'token': 'digit', 'value': '20'}
# Token {'token': 'DATA', 'value': 'DATA'}
# Token {'token': 'digit', 'value': '53'}
# Token {'token': ',', 'value': ','}
# Token {'token': 'digit', 'value': '77'}
# Token {'token': ',', 'value': ','}
# Token {'token': 'digit', 'value': '82'}
# Token {'token': ',', 'value': ','}
# Token {'token': 'digit', 'value': '12'}
# Token {'token': ',', 'value': ','}
# Token {'token': 'digit', 'value': '38'}
# Token {'token': ',', 'value': ','}
# Token {'token': 'digit', 'value': '90'}
# Token {'token': ',', 'value': ','}
# Token {'token': 'digit', 'value': '16'}
# Token {'token': ',', 'value': ','}
# Token {'token': 'digit', 'value': '72'}
# Token {'token': ',', 'value': ','}
# Token {'token': 'digit', 'value': '55'}
# Token {'token': ',', 'value': ','}
# Token {'token': 'digit', 'value': '62'}
# Token {'token': '\n', 'value': '\n'}
# Token {'token': 'digit', 'value': '30'}
# Token {'token': 'DIM', 'value': 'DIM'}
# Token {'token': 'letter', 'value': 'Z'}
# Token {'token': '(', 'value': '('}
# Token {'token': 'digit', 'value': '10'}
# Token {'token': ')', 'value': ')'}
# Token {'token': '\n', 'value': '\n'}
# Token {'token': 'digit', 'value': '35'}
# Token {'token': 'DIM', 'value': 'DIM'}
# Token {'token': 'letter', 'value': 'S'}
# Token {'token': '(', 'value': '('}
# Token {'token': 'digit', 'value': '1000'}
# Token {'token': ')', 'value': ')'}
# Token {'token': '\n', 'value': '\n'}
# Token {'token': 'digit', 'value': '36'}
# Token {'token': 'LET', 'value': 'LET'}
# Token {'token': 'letter', 'value': 'P'}
# Token {'token': '=', 'value': '='}
# Token {'token': 'digit', 'value': '1'}
# Token {'token': '\n', 'value': '\n'}
# Token {'token': 'digit', 'value': '40'}
# Token {'token': 'FOR', 'value': 'FOR'}
# Token {'token': 'letter', 'value': 'I'}
# Token {'token': '=', 'value': '='}
# Token {'token': 'digit', 'value': '1'}
# Token {'token': 'TO', 'value': 'TO'}
# Token {'token': 'letter', 'value': 'N'}
# Token {'token': '\n', 'value': '\n'}
# Token {'token': 'digit', 'value': '50'}
# Token {'token': 'READ', 'value': 'READ'}
# Token {'token': 'letter', 'value': 'Z'}
# Token {'token': '(', 'value': '('}
# Token {'token': 'letter', 'value': 'I'}
# Token {'token': ')', 'value': ')'}
# Token {'token': '\n', 'value': '\n'}
# Token {'token': 'digit', 'value': '60'}
# Token {'token': 'NEXT', 'value': 'NEXT'}
# Token {'token': 'letter', 'value': 'I'}
# Token {'token': '\n', 'value': '\n'}
# Token {'token': 'digit', 'value': '1000'}
# Token {'token': 'FOR', 'value': 'FOR'}
# Token {'token': 'letter', 'value': 'I'}
# Token {'token': '=', 'value': '='}
# Token {'token': 'digit', 'value': '1'}
# Token {'token': 'TO', 'value': 'TO'}
# Token {'token': 'letter', 'value': 'N'}
# Token {'token': '\n', 'value': '\n'}
# Token {'token': 'digit', 'value': '1500'}
# Token {'token': 'FOR', 'value': 'FOR'}
# Token {'token': 'letter', 'value': 'J'}
# Token {'token': '=', 'value': '='}
# Token {'token': 'letter', 'value': 'I'}
# Token {'token': 'TO', 'value': 'TO'}
# Token {'token': 'letter', 'value': 'N'}
# Token {'token': '\n', 'value': '\n'}
# Token {'token': 'digit', 'value': '1510'}
# Token {'token': 'IF', 'value': 'IF'}
# Token {'token': 'letter', 'value': 'Z'}
# Token {'token': '(', 'value': '('}
# Token {'token': 'letter', 'value': 'I'}
# Token {'token': ')', 'value': ')'}
# Token {'token': '<=', 'value': '<='}
# Token {'token': 'letter', 'value': 'Z'}
# Token {'token': '(', 'value': '('}
# Token {'token': 'letter', 'value': 'J'}
# Token {'token': ')', 'value': ')'}
# Token {'token': 'THEN', 'value': 'THEN'}
# Token {'token': 'digit', 'value': '1800'}
# Token {'token': '\n', 'value': '\n'}
# Token {'token': 'digit', 'value': '1520'}
# Token {'token': 'LET', 'value': 'LET'}
# Token {'token': 'letter', 'value': 'T'}
# Token {'token': '=', 'value': '='}
# Token {'token': 'letter', 'value': 'Z'}
# Token {'token': '(', 'value': '('}
# Token {'token': 'letter', 'value': 'J'}
# Token {'token': ')', 'value': ')'}
# Token {'token': '\n', 'value': '\n'}
# Token {'token': 'digit', 'value': '1530'}
# Token {'token': 'LET', 'value': 'LET'}
# Token {'token': 'letter', 'value': 'Z'}
# Token {'token': '(', 'value': '('}
# Token {'token': 'letter', 'value': 'J'}
# Token {'token': ')', 'value': ')'}
# Token {'token': '=', 'value': '='}
# Token {'token': 'letter', 'value': 'Z'}
# Token {'token': '(', 'value': '('}
# Token {'token': 'letter', 'value': 'I'}
# Token {'token': ')', 'value': ')'}
# Token {'token': '\n', 'value': '\n'}
# Token {'token': 'digit', 'value': '1540'}
# Token {'token': 'LET', 'value': 'LET'}
# Token {'token': 'letter', 'value': 'Z'}
# Token {'token': '(', 'value': '('}
# Token {'token': 'letter', 'value': 'I'}
# Token {'token': ')', 'value': ')'}
# Token {'token': '=', 'value': '='}
# Token {'token': 'letter', 'value': 'T'}
# Token {'token': '\n', 'value': '\n'}
# Token {'token': 'digit', 'value': '1800'}
# Token {'token': 'NEXT', 'value': 'NEXT'}
# Token {'token': 'letter', 'value': 'J'}
# Token {'token': '\n', 'value': '\n'}
# Token {'token': 'digit', 'value': '1810'}
# Token {'token': 'NEXT', 'value': 'NEXT'}
# Token {'token': 'letter', 'value': 'I'}
# Token {'token': '\n', 'value': '\n'}
# Token {'token': 'digit', 'value': '9000'}
# Token {'token': 'FOR', 'value': 'FOR'}
# Token {'token': 'letter', 'value': 'I'}
# Token {'token': '=', 'value': '='}
# Token {'token': 'digit', 'value': '1'}
# Token {'token': 'TO', 'value': 'TO'}
# Token {'token': 'digit', 'value': '10'}
# Token {'token': '\n', 'value': '\n'}
# Token {'token': 'digit', 'value': '9000'}
# Token {'token': 'PRINT', 'value': 'PRINT'}
# Token {'token': 'letter', 'value': 'Z'}
# Token {'token': '(', 'value': '('}
# Token {'token': 'letter', 'value': 'I'}
# Token {'token': ')', 'value': ')'}
# Token {'token': '\n', 'value': '\n'}
# Token {'token': 'digit', 'value': '9000'}
# Token {'token': 'NEXT', 'value': 'NEXT'}
# Token {'token': 'letter', 'value': 'I'}

# %%
syntatical.list_events(20000)
# Out:
# 1.  Token {'token': 'digit', 'value': '10'}
# 2.  Token {'token': 'LET', 'value': 'LET'}
# 3.  Token {'token': 'letter', 'value': 'N'}
# 4.  Token {'token': '=', 'value': '='}
# 5.  Token {'token': 'digit', 'value': '10'}
# 6.  Token {'token': '\n', 'value': '\n'}
# 7.  Token {'token': 'digit', 'value': '20'}
# 8.  Token {'token': 'DATA', 'value': 'DATA'}
# 9.  Token {'token': 'digit', 'value': '53'}
# 10.  Token {'token': ',', 'value': ','}
# 11.  Token {'token': 'digit', 'value': '77'}
# 12.  Token {'token': ',', 'value': ','}
# 13.  Token {'token': 'digit', 'value': '82'}
# 14.  Token {'token': ',', 'value': ','}
# 15.  Token {'token': 'digit', 'value': '12'}
# 16.  Token {'token': ',', 'value': ','}
# 17.  Token {'token': 'digit', 'value': '38'}
# 18.  Token {'token': ',', 'value': ','}
# 19.  Token {'token': 'digit', 'value': '90'}
# 20.  Token {'token': ',', 'value': ','}
# 21.  Token {'token': 'digit', 'value': '16'}
# 22.  Token {'token': ',', 'value': ','}
# 23.  Token {'token': 'digit', 'value': '72'}
# 24.  Token {'token': ',', 'value': ','}
# 25.  Token {'token': 'digit', 'value': '55'}
# 26.  Token {'token': ',', 'value': ','}
# 27.  Token {'token': 'digit', 'value': '62'}
# 28.  Token {'token': '\n', 'value': '\n'}
# 29.  Token {'token': 'digit', 'value': '30'}
# 30.  Token {'token': 'DIM', 'value': 'DIM'}
# 31.  Token {'token': 'letter', 'value': 'Z'}
# 32.  Token {'token': '(', 'value': '('}
# 33.  Token {'token': 'digit', 'value': '10'}
# 34.  Token {'token': ')', 'value': ')'}
# 35.  Token {'token': '\n', 'value': '\n'}
# 36.  Token {'token': 'digit', 'value': '35'}
# 37.  Token {'token': 'DIM', 'value': 'DIM'}
# 38.  Token {'token': 'letter', 'value': 'S'}
# 39.  Token {'token': '(', 'value': '('}
# 40.  Token {'token': 'digit', 'value': '1000'}
# 41.  Token {'token': ')', 'value': ')'}
# 42.  Token {'token': '\n', 'value': '\n'}
# 43.  Token {'token': 'digit', 'value': '36'}
# 44.  Token {'token': 'LET', 'value': 'LET'}
# 45.  Token {'token': 'letter', 'value': 'P'}
# 46.  Token {'token': '=', 'value': '='}
# 47.  Token {'token': 'digit', 'value': '1'}
# 48.  Token {'token': '\n', 'value': '\n'}
# 49.  Token {'token': 'digit', 'value': '40'}
# 50.  Token {'token': 'FOR', 'value': 'FOR'}
# 51.  Token {'token': 'letter', 'value': 'I'}
# 52.  Token {'token': '=', 'value': '='}
# 53.  Token {'token': 'digit', 'value': '1'}
# 54.  Token {'token': 'TO', 'value': 'TO'}
# 55.  Token {'token': 'letter', 'value': 'N'}
# 56.  Token {'token': '\n', 'value': '\n'}
# 57.  Token {'token': 'digit', 'value': '50'}
# 58.  Token {'token': 'READ', 'value': 'READ'}
# 59.  Token {'token': 'letter', 'value': 'Z'}
# 60.  Token {'token': '(', 'value': '('}
# 61.  Token {'token': 'letter', 'value': 'I'}
# 62.  Token {'token': ')', 'value': ')'}
# 63.  Token {'token': '\n', 'value': '\n'}
# 64.  Token {'token': 'digit', 'value': '60'}
# 65.  Token {'token': 'NEXT', 'value': 'NEXT'}
# 66.  Token {'token': 'letter', 'value': 'I'}
# 67.  Token {'token': '\n', 'value': '\n'}
# 68.  Token {'token': 'digit', 'value': '1000'}
# 69.  Token {'token': 'FOR', 'value': 'FOR'}
# 70.  Token {'token': 'letter', 'value': 'I'}
# 71.  Token {'token': '=', 'value': '='}
# 72.  Token {'token': 'digit', 'value': '1'}
# 73.  Token {'token': 'TO', 'value': 'TO'}
# 74.  Token {'token': 'letter', 'value': 'N'}
# 75.  Token {'token': '\n', 'value': '\n'}
# 76.  Token {'token': 'digit', 'value': '1500'}
# 77.  Token {'token': 'FOR', 'value': 'FOR'}
# 78.  Token {'token': 'letter', 'value': 'J'}
# 79.  Token {'token': '=', 'value': '='}
# 80.  Token {'token': 'letter', 'value': 'I'}
# 81.  Token {'token': 'TO', 'value': 'TO'}
# 82.  Token {'token': 'letter', 'value': 'N'}
# 83.  Token {'token': '\n', 'value': '\n'}
# 84.  Token {'token': 'digit', 'value': '1510'}
# 85.  Token {'token': 'IF', 'value': 'IF'}
# 86.  Token {'token': 'letter', 'value': 'Z'}
# 87.  Token {'token': '(', 'value': '('}
# 88.  Token {'token': 'letter', 'value': 'I'}
# 89.  Token {'token': ')', 'value': ')'}
# 90.  Token {'token': '<=', 'value': '<='}
# 91.  Token {'token': 'letter', 'value': 'Z'}
# 92.  Token {'token': '(', 'value': '('}
# 93.  Token {'token': 'letter', 'value': 'J'}
# 94.  Token {'token': ')', 'value': ')'}
# 95.  Token {'token': 'THEN', 'value': 'THEN'}
# 96.  Token {'token': 'digit', 'value': '1800'}
# 97.  Token {'token': '\n', 'value': '\n'}
# 98.  Token {'token': 'digit', 'value': '1520'}
# 99.  Token {'token': 'LET', 'value': 'LET'}
# 100.  Token {'token': 'letter', 'value': 'T'}
# 101.  Token {'token': '=', 'value': '='}
# 102.  Token {'token': 'letter', 'value': 'Z'}
# 103.  Token {'token': '(', 'value': '('}
# 104.  Token {'token': 'letter', 'value': 'J'}
# 105.  Token {'token': ')', 'value': ')'}
# 106.  Token {'token': '\n', 'value': '\n'}
# 107.  Token {'token': 'digit', 'value': '1530'}
# 108.  Token {'token': 'LET', 'value': 'LET'}
# 109.  Token {'token': 'letter', 'value': 'Z'}
# 110.  Token {'token': '(', 'value': '('}
# 111.  Token {'token': 'letter', 'value': 'J'}
# 112.  Token {'token': ')', 'value': ')'}
# 113.  Token {'token': '=', 'value': '='}
# 114.  Token {'token': 'letter', 'value': 'Z'}
# 115.  Token {'token': '(', 'value': '('}
# 116.  Token {'token': 'letter', 'value': 'I'}
# 117.  Token {'token': ')', 'value': ')'}
# 118.  Token {'token': '\n', 'value': '\n'}
# 119.  Token {'token': 'digit', 'value': '1540'}
# 120.  Token {'token': 'LET', 'value': 'LET'}
# 121.  Token {'token': 'letter', 'value': 'Z'}
# 122.  Token {'token': '(', 'value': '('}
# 123.  Token {'token': 'letter', 'value': 'I'}
# 124.  Token {'token': ')', 'value': ')'}
# 125.  Token {'token': '=', 'value': '='}
# 126.  Token {'token': 'letter', 'value': 'T'}
# 127.  Token {'token': '\n', 'value': '\n'}
# 128.  Token {'token': 'digit', 'value': '1800'}
# 129.  Token {'token': 'NEXT', 'value': 'NEXT'}
# 130.  Token {'token': 'letter', 'value': 'J'}
# 131.  Token {'token': '\n', 'value': '\n'}
# 132.  Token {'token': 'digit', 'value': '1810'}
# 133.  Token {'token': 'NEXT', 'value': 'NEXT'}
# 134.  Token {'token': 'letter', 'value': 'I'}
# 135.  Token {'token': '\n', 'value': '\n'}
# 136.  Token {'token': 'digit', 'value': '9000'}
# 137.  Token {'token': 'FOR', 'value': 'FOR'}
# 138.  Token {'token': 'letter', 'value': 'I'}
# 139.  Token {'token': '=', 'value': '='}
# 140.  Token {'token': 'digit', 'value': '1'}
# 141.  Token {'token': 'TO', 'value': 'TO'}
# 142.  Token {'token': 'digit', 'value': '10'}
# 143.  Token {'token': '\n', 'value': '\n'}
# 144.  Token {'token': 'digit', 'value': '9000'}
# 145.  Token {'token': 'PRINT', 'value': 'PRINT'}
# 146.  Token {'token': 'letter', 'value': 'Z'}
# 147.  Token {'token': '(', 'value': '('}
# 148.  Token {'token': 'letter', 'value': 'I'}
# 149.  Token {'token': ')', 'value': ')'}
# 150.  Token {'token': '\n', 'value': '\n'}
# 151.  Token {'token': 'digit', 'value': '9000'}
# 152.  Token {'token': 'NEXT', 'value': 'NEXT'}
# 153.  Token {'token': 'letter', 'value': 'I'}

# %%
syntatical.fetch_exhaustive()
# Out:
# digit(10) A Program [] {'A': {':BStatement': 'B'}, 'B': {'\n': 'C'}, 'C': {':BStatement': 'F', ':Int': 'G'}, 'F': {'\n': 'D'}, 'G': {'END': 'H'}, 'D': {'\n': 'E', ':BStatement': 'F', ':Int': 'G'}, 'E': {'\n': 'E', ':BStatement': 'F', ':Int': 'G'}, 'H': {}}
# is '10' in [':BStatement']
# Trying machine :BStatement
# digit(10) A BStatement [] {'A': {':Int': 'B'}, 'B': {':Remark': 'K', ':Dim': 'G', ':Def': 'H', ':Read': 'L', ':Goto': 'O', ':Return': 'J', ':For': 'E', ':Data': 'M', ':Gosub': 'I', ':Print': 'N', ':Next': 'F', ':Assign': 'C', ':If': 'D'}, 'G': {}, 'K': {}, 'N': {}, 'D': {}, 'H': {}, 'J': {}, 'M': {}, 'F': {}, 'O': {}, 'I': {}, 'C': {}, 'E': {}, 'L': {}}
# is '10' in [':Int']
# Trying machine :Int
# digit(10) A Int [] {'A': {'digit': 'B'}, 'B': {'digit': 'C'}, 'C': {'digit': 'C'}}
# is '10' in ['digit']
# 	Normal transition
# LET(LET) B Int [] {'A': {'digit': 'B'}, 'B': {'digit': 'C'}, 'C': {'digit': 'C'}}
# is 'LET' in ['digit']
# Found token 'Int': [{'token': 'digit', 'value': '10'}]
# :Int([{'token': 'digit', 'value': '10'}]) A BStatement [] {'A': {':Int': 'B'}, 'B': {':Remark': 'K', ':Dim': 'G', ':Def': 'H', ':Read': 'L', ':Goto': 'O', ':Return': 'J', ':For': 'E', ':Data': 'M', ':Gosub': 'I', ':Print': 'N', ':Next': 'F', ':Assign': 'C', ':If': 'D'}, 'G': {}, 'K': {}, 'N': {}, 'D': {}, 'H': {}, 'J': {}, 'M': {}, 'F': {}, 'O': {}, 'I': {}, 'C': {}, 'E': {}, 'L': {}}
# is '[{'token': 'digit', 'value': '10'}]' in [':Int']
# 	Normal transition
# LET(LET) B BStatement [] {'A': {':Int': 'B'}, 'B': {':Remark': 'K', ':Dim': 'G', ':Def': 'H', ':Read': 'L', ':Goto': 'O', ':Return': 'J', ':For': 'E', ':Data': 'M', ':Gosub': 'I', ':Print': 'N', ':Next': 'F', ':Assign': 'C', ':If': 'D'}, 'G': {}, 'K': {}, 'N': {}, 'D': {}, 'H': {}, 'J': {}, 'M': {}, 'F': {}, 'O': {}, 'I': {}, 'C': {}, 'E': {}, 'L': {}}
# is 'LET' in [':Remark', ':Dim', ':Def', ':Read', ':Goto', ':Return', ':For', ':Data', ':Gosub', ':Print', ':Next', ':Assign', ':If']
# Trying machine :Remark
# LET(LET) A Remark [] {'A': {'REM': 'B'}, 'B': {':Character': 'C'}, 'C': {':Character': 'C'}}
# is 'LET' in ['REM']
# Backtracking...
# LET(LET) B BStatement [':Dim', ':Def', ':Read', ':Goto', ':Return', ':For', ':Data', ':Gosub', ':Print', ':Next', ':Assign', ':If'] {'A': {':Int': 'B'}, 'B': {':Remark': 'K', ':Dim': 'G', ':Def': 'H', ':Read': 'L', ':Goto': 'O', ':Return': 'J', ':For': 'E', ':Data': 'M', ':Gosub': 'I', ':Print': 'N', ':Next': 'F', ':Assign': 'C', ':If': 'D'}, 'G': {}, 'K': {}, 'N': {}, 'D': {}, 'H': {}, 'J': {}, 'M': {}, 'F': {}, 'O': {}, 'I': {}, 'C': {}, 'E': {}, 'L': {}}
# is 'LET' in [':Remark', ':Dim', ':Def', ':Read', ':Goto', ':Return', ':For', ':Data', ':Gosub', ':Print', ':Next', ':Assign', ':If']
# Trying machine :Dim
# LET(LET) A Dim [] {'A': {'DIM': 'B'}, 'B': {'letter': 'C'}, 'C': {'(': 'D'}, 'D': {':Int': 'E'}, 'E': {')': 'H', ',': 'G'}, 'H': {',': 'J'}, 'G': {':Int': 'F'}, 'J': {'letter': 'K'}, 'F': {')': 'H', ',': 'G'}, 'K': {'(': 'L'}, 'L': {':Int': 'M'}, 'M': {')': 'I', ',': 'O'}, 'I': {',': 'J'}, 'O': {':Int': 'N'}, 'N': {')': 'I', ',': 'O'}}
# is 'LET' in ['DIM']
# Backtracking...
# LET(LET) B BStatement [':Def', ':Read', ':Goto', ':Return', ':For', ':Data', ':Gosub', ':Print', ':Next', ':Assign', ':If'] {'A': {':Int': 'B'}, 'B': {':Remark': 'K', ':Dim': 'G', ':Def': 'H', ':Read': 'L', ':Goto': 'O', ':Return': 'J', ':For': 'E', ':Data': 'M', ':Gosub': 'I', ':Print': 'N', ':Next': 'F', ':Assign': 'C', ':If': 'D'}, 'G': {}, 'K': {}, 'N': {}, 'D': {}, 'H': {}, 'J': {}, 'M': {}, 'F': {}, 'O': {}, 'I': {}, 'C': {}, 'E': {}, 'L': {}}
# is 'LET' in [':Remark', ':Dim', ':Def', ':Read', ':Goto', ':Return', ':For', ':Data', ':Gosub', ':Print', ':Next', ':Assign', ':If']
# Trying machine :Def
# LET(LET) A Def [] {'A': {'DEF FN': 'B'}, 'B': {'letter': 'C'}, 'C': {'(': 'D'}, 'D': {'letter': 'E'}, 'E': {')': 'G', 'digit': 'F'}, 'G': {'=': 'H'}, 'F': {')': 'G'}, 'H': {':Exp': 'I'}, 'I': {}}
# is 'LET' in ['DEF FN']
# Backtracking...
# LET(LET) B BStatement [':Read', ':Goto', ':Return', ':For', ':Data', ':Gosub', ':Print', ':Next', ':Assign', ':If'] {'A': {':Int': 'B'}, 'B': {':Remark': 'K', ':Dim': 'G', ':Def': 'H', ':Read': 'L', ':Goto': 'O', ':Return': 'J', ':For': 'E', ':Data': 'M', ':Gosub': 'I', ':Print': 'N', ':Next': 'F', ':Assign': 'C', ':If': 'D'}, 'G': {}, 'K': {}, 'N': {}, 'D': {}, 'H': {}, 'J': {}, 'M': {}, 'F': {}, 'O': {}, 'I': {}, 'C': {}, 'E': {}, 'L': {}}
# is 'LET' in [':Remark', ':Dim', ':Def', ':Read', ':Goto', ':Return', ':For', ':Data', ':Gosub', ':Print', ':Next', ':Assign', ':If']
# Trying machine :Read
# LET(LET) A Read [] {'A': {'READ': 'B'}, 'B': {':Var': 'C'}, 'C': {',': 'E'}, 'E': {':Var': 'D'}, 'D': {',': 'E'}}
# is 'LET' in ['READ']
# Backtracking...
# LET(LET) B BStatement [':Goto', ':Return', ':For', ':Data', ':Gosub', ':Print', ':Next', ':Assign', ':If'] {'A': {':Int': 'B'}, 'B': {':Remark': 'K', ':Dim': 'G', ':Def': 'H', ':Read': 'L', ':Goto': 'O', ':Return': 'J', ':For': 'E', ':Data': 'M', ':Gosub': 'I', ':Print': 'N', ':Next': 'F', ':Assign': 'C', ':If': 'D'}, 'G': {}, 'K': {}, 'N': {}, 'D': {}, 'H': {}, 'J': {}, 'M': {}, 'F': {}, 'O': {}, 'I': {}, 'C': {}, 'E': {}, 'L': {}}
# is 'LET' in [':Remark', ':Dim', ':Def', ':Read', ':Goto', ':Return', ':For', ':Data', ':Gosub', ':Print', ':Next', ':Assign', ':If']
# Trying machine :Goto
# LET(LET) A Goto [] {'A': {'GOTO': 'B', 'GO': 'C'}, 'B': {':Int': 'E'}, 'C': {'TO': 'D'}, 'D': {':Int': 'E'}, 'E': {}}
# is 'LET' in ['GOTO', 'GO']
# Backtracking...
# LET(LET) B BStatement [':Return', ':For', ':Data', ':Gosub', ':Print', ':Next', ':Assign', ':If'] {'A': {':Int': 'B'}, 'B': {':Remark': 'K', ':Dim': 'G', ':Def': 'H', ':Read': 'L', ':Goto': 'O', ':Return': 'J', ':For': 'E', ':Data': 'M', ':Gosub': 'I', ':Print': 'N', ':Next': 'F', ':Assign': 'C', ':If': 'D'}, 'G': {}, 'K': {}, 'N': {}, 'D': {}, 'H': {}, 'J': {}, 'M': {}, 'F': {}, 'O': {}, 'I': {}, 'C': {}, 'E': {}, 'L': {}}
# is 'LET' in [':Remark', ':Dim', ':Def', ':Read', ':Goto', ':Return', ':For', ':Data', ':Gosub', ':Print', ':Next', ':Assign', ':If']
# Trying machine :Return
# LET(LET) A Return [] {'A': {'RETURN': 'B'}, 'B': {}}
# is 'LET' in ['RETURN']
# Backtracking...
# LET(LET) B BStatement [':For', ':Data', ':Gosub', ':Print', ':Next', ':Assign', ':If'] {'A': {':Int': 'B'}, 'B': {':Remark': 'K', ':Dim': 'G', ':Def': 'H', ':Read': 'L', ':Goto': 'O', ':Return': 'J', ':For': 'E', ':Data': 'M', ':Gosub': 'I', ':Print': 'N', ':Next': 'F', ':Assign': 'C', ':If': 'D'}, 'G': {}, 'K': {}, 'N': {}, 'D': {}, 'H': {}, 'J': {}, 'M': {}, 'F': {}, 'O': {}, 'I': {}, 'C': {}, 'E': {}, 'L': {}}
# is 'LET' in [':Remark', ':Dim', ':Def', ':Read', ':Goto', ':Return', ':For', ':Data', ':Gosub', ':Print', ':Next', ':Assign', ':If']
# Trying machine :For
# LET(LET) A For [] {'A': {'FOR': 'B'}, 'B': {'letter': 'C'}, 'C': {'digit': 'D', '=': 'E'}, 'D': {'=': 'E'}, 'E': {':Exp': 'F'}, 'F': {'TO': 'G'}, 'G': {':Exp': 'H'}, 'H': {'STEP': 'I'}, 'I': {':Exp': 'J'}, 'J': {}}
# is 'LET' in ['FOR']
# Backtracking...
# LET(LET) B BStatement [':Data', ':Gosub', ':Print', ':Next', ':Assign', ':If'] {'A': {':Int': 'B'}, 'B': {':Remark': 'K', ':Dim': 'G', ':Def': 'H', ':Read': 'L', ':Goto': 'O', ':Return': 'J', ':For': 'E', ':Data': 'M', ':Gosub': 'I', ':Print': 'N', ':Next': 'F', ':Assign': 'C', ':If': 'D'}, 'G': {}, 'K': {}, 'N': {}, 'D': {}, 'H': {}, 'J': {}, 'M': {}, 'F': {}, 'O': {}, 'I': {}, 'C': {}, 'E': {}, 'L': {}}
# is 'LET' in [':Remark', ':Dim', ':Def', ':Read', ':Goto', ':Return', ':For', ':Data', ':Gosub', ':Print', ':Next', ':Assign', ':If']
# Trying machine :Data
# LET(LET) A Data [] {'A': {'DATA': 'B'}, 'B': {':Snum': 'C'}, 'C': {',': 'E'}, 'E': {':Snum': 'D'}, 'D': {',': 'E'}}
# is 'LET' in ['DATA']
# Backtracking...
# LET(LET) B BStatement [':Gosub', ':Print', ':Next', ':Assign', ':If'] {'A': {':Int': 'B'}, 'B': {':Remark': 'K', ':Dim': 'G', ':Def': 'H', ':Read': 'L', ':Goto': 'O', ':Return': 'J', ':For': 'E', ':Data': 'M', ':Gosub': 'I', ':Print': 'N', ':Next': 'F', ':Assign': 'C', ':If': 'D'}, 'G': {}, 'K': {}, 'N': {}, 'D': {}, 'H': {}, 'J': {}, 'M': {}, 'F': {}, 'O': {}, 'I': {}, 'C': {}, 'E': {}, 'L': {}}
# is 'LET' in [':Remark', ':Dim', ':Def', ':Read', ':Goto', ':Return', ':For', ':Data', ':Gosub', ':Print', ':Next', ':Assign', ':If']
# Trying machine :Gosub
# LET(LET) A Gosub [] {'A': {'GOSUB': 'B'}, 'B': {':Int': 'C'}, 'C': {}}
# is 'LET' in ['GOSUB']
# Backtracking...
# LET(LET) B BStatement [':Print', ':Next', ':Assign', ':If'] {'A': {':Int': 'B'}, 'B': {':Remark': 'K', ':Dim': 'G', ':Def': 'H', ':Read': 'L', ':Goto': 'O', ':Return': 'J', ':For': 'E', ':Data': 'M', ':Gosub': 'I', ':Print': 'N', ':Next': 'F', ':Assign': 'C', ':If': 'D'}, 'G': {}, 'K': {}, 'N': {}, 'D': {}, 'H': {}, 'J': {}, 'M': {}, 'F': {}, 'O': {}, 'I': {}, 'C': {}, 'E': {}, 'L': {}}
# is 'LET' in [':Remark', ':Dim', ':Def', ':Read', ':Goto', ':Return', ':For', ':Data', ':Gosub', ':Print', ':Next', ':Assign', ':If']
# Trying machine :Print
# LET(LET) A Print [] {'A': {'PRINT': 'B'}, 'B': {':Pitem': 'C'}, 'C': {',': 'F'}, 'F': {':Pitem': 'D'}, 'D': {',': 'F'}, 'G': {}, 'E': {}}
# is 'LET' in ['PRINT']
# Backtracking...
# LET(LET) B BStatement [':Next', ':Assign', ':If'] {'A': {':Int': 'B'}, 'B': {':Remark': 'K', ':Dim': 'G', ':Def': 'H', ':Read': 'L', ':Goto': 'O', ':Return': 'J', ':For': 'E', ':Data': 'M', ':Gosub': 'I', ':Print': 'N', ':Next': 'F', ':Assign': 'C', ':If': 'D'}, 'G': {}, 'K': {}, 'N': {}, 'D': {}, 'H': {}, 'J': {}, 'M': {}, 'F': {}, 'O': {}, 'I': {}, 'C': {}, 'E': {}, 'L': {}}
# is 'LET' in [':Remark', ':Dim', ':Def', ':Read', ':Goto', ':Return', ':For', ':Data', ':Gosub', ':Print', ':Next', ':Assign', ':If']
# Trying machine :Next
# LET(LET) A Next [] {'A': {'NEXT': 'B'}, 'B': {'letter': 'C'}, 'C': {'digit': 'D'}, 'D': {}}
# is 'LET' in ['NEXT']
# Backtracking...
# LET(LET) B BStatement [':Assign', ':If'] {'A': {':Int': 'B'}, 'B': {':Remark': 'K', ':Dim': 'G', ':Def': 'H', ':Read': 'L', ':Goto': 'O', ':Return': 'J', ':For': 'E', ':Data': 'M', ':Gosub': 'I', ':Print': 'N', ':Next': 'F', ':Assign': 'C', ':If': 'D'}, 'G': {}, 'K': {}, 'N': {}, 'D': {}, 'H': {}, 'J': {}, 'M': {}, 'F': {}, 'O': {}, 'I': {}, 'C': {}, 'E': {}, 'L': {}}
# is 'LET' in [':Remark', ':Dim', ':Def', ':Read', ':Goto', ':Return', ':For', ':Data', ':Gosub', ':Print', ':Next', ':Assign', ':If']
# Trying machine :Assign
# LET(LET) A Assign [] {'A': {'LET': 'B'}, 'B': {':Var': 'C'}, 'C': {'=': 'D'}, 'D': {':Exp': 'E'}, 'E': {}}
# is 'LET' in ['LET']
# 	Normal transition
# letter(N) B Assign [] {'A': {'LET': 'B'}, 'B': {':Var': 'C'}, 'C': {'=': 'D'}, 'D': {':Exp': 'E'}, 'E': {}}
# is 'N' in [':Var']
# Trying machine :Var
# letter(N) A Var [] {'A': {'letter': 'B'}, 'B': {'digit': 'C', '(': 'E'}, 'E': {':Exp': 'F'}, 'F': {',': 'H', ')': 'I'}, 'H': {':Exp': 'G'}, 'G': {',': 'H', ')': 'I'}, 'C': {}, 'D': {}, 'I': {}}
# is 'N' in ['letter']
# 	Normal transition
# =(=) B Var [] {'A': {'letter': 'B'}, 'B': {'digit': 'C', '(': 'E'}, 'E': {':Exp': 'F'}, 'F': {',': 'H', ')': 'I'}, 'H': {':Exp': 'G'}, 'G': {',': 'H', ')': 'I'}, 'C': {}, 'D': {}, 'I': {}}
# is '=' in ['digit', '(']
# Found token 'Var': [{'token': 'letter', 'value': 'N'}]
# :Var([{'token': 'letter', 'value': 'N'}]) B Assign [] {'A': {'LET': 'B'}, 'B': {':Var': 'C'}, 'C': {'=': 'D'}, 'D': {':Exp': 'E'}, 'E': {}}
# is '[{'token': 'letter', 'value': 'N'}]' in [':Var']
# 	Normal transition
# =(=) C Assign [] {'A': {'LET': 'B'}, 'B': {':Var': 'C'}, 'C': {'=': 'D'}, 'D': {':Exp': 'E'}, 'E': {}}
# is '=' in ['=']
# 	Normal transition
# digit(10) D Assign [] {'A': {'LET': 'B'}, 'B': {':Var': 'C'}, 'C': {'=': 'D'}, 'D': {':Exp': 'E'}, 'E': {}}
# is '10' in [':Exp']
# Trying machine :Exp
# digit(10) A Exp [] {'A': {'+': 'B', '-': 'C', ':Eb': 'D'}, 'B': {':Eb': 'D'}, 'C': {':Eb': 'D'}, 'D': {'-': 'G', '/': 'I', '*': 'H', '↑': 'J', '+': 'F'}, 'G': {':Eb': 'E'}, 'I': {':Eb': 'E'}, 'H': {':Eb': 'E'}, 'J': {':Eb': 'E'}, 'F': {':Eb': 'E'}, 'E': {'*': 'H', '↑': 'J', '+': 'F', '-': 'G', '/': 'I'}}
# is '10' in ['+', '-', ':Eb']
# Trying machine :Eb
# digit(10) A Eb [] {'A': {':Num': 'G', 'FN': 'J', ':Predef': 'L', '(': 'B', ':Var': 'H'}, 'J': {'letter': 'K'}, 'L': {'(': 'C'}, 'B': {':Exp': 'I'}, 'K': {'(': 'C'}, 'C': {':Exp': 'D'}, 'I': {')': 'F'}, 'D': {')': 'E'}, 'F': {}, 'G': {}, 'H': {}, 'E': {}}
# is '10' in [':Num', 'FN', ':Predef', '(', ':Var']
# Trying machine :Num
# digit(10) A Num [] {'A': {':Int': 'B', '.': 'E'}, 'B': {'.': 'C', 'E': 'G'}, 'E': {':Int': 'F'}, 'C': {'digit': 'D', 'E': 'G'}, 'G': {'+': 'H', ':Int': 'J', '-': 'I'}, 'F': {'E': 'G'}, 'D': {'digit': 'D', 'E': 'G'}, 'H': {':Int': 'J'}, 'I': {':Int': 'J'}, 'J': {}}
# is '10' in [':Int', '.']
# Trying machine :Int
# digit(10) A Int [] {'A': {'digit': 'B'}, 'B': {'digit': 'C'}, 'C': {'digit': 'C'}}
# is '10' in ['digit']
# 	Normal transition
#
# (
# ) B Int [] {'A': {'digit': 'B'}, 'B': {'digit': 'C'}, 'C': {'digit': 'C'}}
# is '
# ' in ['digit']
# Found token 'Int': [{'token': 'digit', 'value': '10'}]
# :Int([{'token': 'digit', 'value': '10'}]) A Num [] {'A': {':Int': 'B', '.': 'E'}, 'B': {'.': 'C', 'E': 'G'}, 'E': {':Int': 'F'}, 'C': {'digit': 'D', 'E': 'G'}, 'G': {'+': 'H', ':Int': 'J', '-': 'I'}, 'F': {'E': 'G'}, 'D': {'digit': 'D', 'E': 'G'}, 'H': {':Int': 'J'}, 'I': {':Int': 'J'}, 'J': {}}
# is '[{'token': 'digit', 'value': '10'}]' in [':Int', '.']
# 	Normal transition
#
# (
# ) B Num [] {'A': {':Int': 'B', '.': 'E'}, 'B': {'.': 'C', 'E': 'G'}, 'E': {':Int': 'F'}, 'C': {'digit': 'D', 'E': 'G'}, 'G': {'+': 'H', ':Int': 'J', '-': 'I'}, 'F': {'E': 'G'}, 'D': {'digit': 'D', 'E': 'G'}, 'H': {':Int': 'J'}, 'I': {':Int': 'J'}, 'J': {}}
# is '
# ' in ['.', 'E']
# Found token 'Num': [{'token': ':Int', 'value': [{'token': 'digit', 'value': '10'}]}]
# :Num([{'token': ':Int', 'value': [{'token': 'digit', 'value': '10'}]}]) A Eb [':Predef', ':Var'] {'A': {':Num': 'G', 'FN': 'J', ':Predef': 'L', '(': 'B', ':Var': 'H'}, 'J': {'letter': 'K'}, 'L': {'(': 'C'}, 'B': {':Exp': 'I'}, 'K': {'(': 'C'}, 'C': {':Exp': 'D'}, 'I': {')': 'F'}, 'D': {')': 'E'}, 'F': {}, 'G': {}, 'H': {}, 'E': {}}
# is '[{'token': ':Int', 'value': [{'token': 'digit', 'value': '10'}]}]' in [':Num', 'FN', ':Predef', '(', ':Var']
# 	Normal transition
#
# (
# ) G Eb [] {'A': {':Num': 'G', 'FN': 'J', ':Predef': 'L', '(': 'B', ':Var': 'H'}, 'J': {'letter': 'K'}, 'L': {'(': 'C'}, 'B': {':Exp': 'I'}, 'K': {'(': 'C'}, 'C': {':Exp': 'D'}, 'I': {')': 'F'}, 'D': {')': 'E'}, 'F': {}, 'G': {}, 'H': {}, 'E': {}}
# is '
# ' in []
# Found token 'Eb': [{'token': ':Num', 'value': [{'token': ':Int', 'value': [{'token': 'digit', 'value': '10'}]}]}]
# :Eb([{'token': ':Num', 'value': [{'token': ':Int', 'value': [{'token': 'digit', 'value': '10'}]}]}]) A Exp [] {'A': {'+': 'B', '-': 'C', ':Eb': 'D'}, 'B': {':Eb': 'D'}, 'C': {':Eb': 'D'}, 'D': {'-': 'G', '/': 'I', '*': 'H', '↑': 'J', '+': 'F'}, 'G': {':Eb': 'E'}, 'I': {':Eb': 'E'}, 'H': {':Eb': 'E'}, 'J': {':Eb': 'E'}, 'F': {':Eb': 'E'}, 'E': {'*': 'H', '↑': 'J', '+': 'F', '-': 'G', '/': 'I'}}
# is '[{'token': ':Num', 'value': [{'token': ':Int', 'value': [{'token': 'digit', 'value': '10'}]}]}]' in ['+', '-', ':Eb']
# 	Normal transition
#
# (
# ) D Exp [] {'A': {'+': 'B', '-': 'C', ':Eb': 'D'}, 'B': {':Eb': 'D'}, 'C': {':Eb': 'D'}, 'D': {'-': 'G', '/': 'I', '*': 'H', '↑': 'J', '+': 'F'}, 'G': {':Eb': 'E'}, 'I': {':Eb': 'E'}, 'H': {':Eb': 'E'}, 'J': {':Eb': 'E'}, 'F': {':Eb': 'E'}, 'E': {'*': 'H', '↑': 'J', '+': 'F', '-': 'G', '/': 'I'}}
# is '
# ' in ['-', '/', '*', '↑', '+']
# Found token 'Exp': [{'token': ':Eb', 'value': [{'token': ':Num', 'value': [{'token': ':Int', 'value': [{'token': 'digit', 'value': '10'}]}]}]}]
# :Exp([{'token': ':Eb', 'value': [{'token': ':Num', 'value': [{'token': ':Int', 'value': [{'token': 'digit', 'value': '10'}]}]}]}]) D Assign [] {'A': {'LET': 'B'}, 'B': {':Var': 'C'}, 'C': {'=': 'D'}, 'D': {':Exp': 'E'}, 'E': {}}
# is '[{'token': ':Eb', 'value': [{'token': ':Num', 'value': [{'token': ':Int', 'value': [{'token': 'digit', 'value': '10'}]}]}]}]' in [':Exp']
# 	Normal transition
#
# (
# ) E Assign [] {'A': {'LET': 'B'}, 'B': {':Var': 'C'}, 'C': {'=': 'D'}, 'D': {':Exp': 'E'}, 'E': {}}
# is '
# ' in []
# Found token 'Assign': [{'token': 'LET', 'value': 'LET'}, {'token': ':Var', 'value': [{'token': 'letter', 'value': 'N'}]}, {'token': '=', 'value': '='}, {'token': ':Exp', 'value': [{'token': ':Eb', 'value': [{'token': ':Num', 'value': [{'token': ':Int', 'value': [{'token': 'digit', 'value': '10'}]}]}]}]}]
# :Assign([{'token': 'LET', 'value': 'LET'}, {'token': ':Var', 'value': [{'token': 'letter', 'value': 'N'}]}, {'token': '=', 'value': '='}, {'token': ':Exp', 'value': [{'token': ':Eb', 'value': [{'token': ':Num', 'value': [{'token': ':Int', 'value': [{'token': 'digit', 'value': '10'}]}]}]}]}]) B BStatement [':If'] {'A': {':Int': 'B'}, 'B': {':Remark': 'K', ':Dim': 'G', ':Def': 'H', ':Read': 'L', ':Goto': 'O', ':Return': 'J', ':For': 'E', ':Data': 'M', ':Gosub': 'I', ':Print': 'N', ':Next': 'F', ':Assign': 'C', ':If': 'D'}, 'G': {}, 'K': {}, 'N': {}, 'D': {}, 'H': {}, 'J': {}, 'M': {}, 'F': {}, 'O': {}, 'I': {}, 'C': {}, 'E': {}, 'L': {}}
# is '[{'token': 'LET', 'value': 'LET'}, {'token': ':Var', 'value': [{'token': 'letter', 'value': 'N'}]}, {'token': '=', 'value': '='}, {'token': ':Exp', 'value': [{'token': ':Eb', 'value': [{'token': ':Num', 'value': [{'token': ':Int', 'value': [{'token': 'digit', 'value': '10'}]}]}]}]}]' in [':Remark', ':Dim', ':Def', ':Read', ':Goto', ':Return', ':For', ':Data', ':Gosub', ':Print', ':Next', ':Assign', ':If']
# 	Normal transition
#
# (
# ) C BStatement [] {'A': {':Int': 'B'}, 'B': {':Remark': 'K', ':Dim': 'G', ':Def': 'H', ':Read': 'L', ':Goto': 'O', ':Return': 'J', ':For': 'E', ':Data': 'M', ':Gosub': 'I', ':Print': 'N', ':Next': 'F', ':Assign': 'C', ':If': 'D'}, 'G': {}, 'K': {}, 'N': {}, 'D': {}, 'H': {}, 'J': {}, 'M': {}, 'F': {}, 'O': {}, 'I': {}, 'C': {}, 'E': {}, 'L': {}}
# is '
# ' in []
# Found token 'BStatement': [{'token': ':Int', 'value': [{'token': 'digit', 'value': '10'}]}, {'token': ':Assign', 'value': [{'token': 'LET', 'value': 'LET'}, {'token': ':Var', 'value': [{'token': 'letter', 'value': 'N'}]}, {'token': '=', 'value': '='}, {'token': ':Exp', 'value': [{'token': ':Eb', 'value': [{'token': ':Num', 'value': [{'token': ':Int', 'value': [{'token': 'digit', 'value': '10'}]}]}]}]}]}]
# :BStatement([{'token': ':Int', 'value': [{'token': 'digit', 'value': '10'}]}, {'token': ':Assign', 'value': [{'token': 'LET', 'value': 'LET'}, {'token': ':Var', 'value': [{'token': 'letter', 'value': 'N'}]}, {'token': '=', 'value': '='}, {'token': ':Exp', 'value': [{'token': ':Eb', 'value': [{'token': ':Num', 'value': [{'token': ':Int', 'value': [{'token': 'digit', 'value': '10'}]}]}]}]}]}]) A Program [] {'A': {':BStatement': 'B'}, 'B': {'\n': 'C'}, 'C': {':BStatement': 'F', ':Int': 'G'}, 'F': {'\n': 'D'}, 'G': {'END': 'H'}, 'D': {'\n': 'E', ':BStatement': 'F', ':Int': 'G'}, 'E': {'\n': 'E', ':BStatement': 'F', ':Int': 'G'}, 'H': {}}
# is '[{'token': ':Int', 'value': [{'token': 'digit', 'value': '10'}]}, {'token': ':Assign', 'value': [{'token': 'LET', 'value': 'LET'}, {'token': ':Var', 'value': [{'token': 'letter', 'value': 'N'}]}, {'token': '=', 'value': '='}, {'token': ':Exp', 'value': [{'token': ':Eb', 'value': [{'token': ':Num', 'value': [{'token': ':Int', 'value': [{'token': 'digit', 'value': '10'}]}]}]}]}]}]' in [':BStatement']
# 	Normal transition
#
# (
# ) B Program [] {'A': {':BStatement': 'B'}, 'B': {'\n': 'C'}, 'C': {':BStatement': 'F', ':Int': 'G'}, 'F': {'\n': 'D'}, 'G': {'END': 'H'}, 'D': {'\n': 'E', ':BStatement': 'F', ':Int': 'G'}, 'E': {'\n': 'E', ':BStatement': 'F', ':Int': 'G'}, 'H': {}}
# is '
# ' in ['\n']
# 	Normal transition
# digit(20) C Program [] {'A': {':BStatement': 'B'}, 'B': {'\n': 'C'}, 'C': {':BStatement': 'F', ':Int': 'G'}, 'F': {'\n': 'D'}, 'G': {'END': 'H'}, 'D': {'\n': 'E', ':BStatement': 'F', ':Int': 'G'}, 'E': {'\n': 'E', ':BStatement': 'F', ':Int': 'G'}, 'H': {}}
# is '20' in [':BStatement', ':Int']
# Trying machine :BStatement
# digit(20) A BStatement [] {'A': {':Int': 'B'}, 'B': {':Remark': 'K', ':Dim': 'G', ':Def': 'H', ':Read': 'L', ':Goto': 'O', ':Return': 'J', ':For': 'E', ':Data': 'M', ':Gosub': 'I', ':Print': 'N', ':Next': 'F', ':Assign': 'C', ':If': 'D'}, 'G': {}, 'K': {}, 'N': {}, 'D': {}, 'H': {}, 'J': {}, 'M': {}, 'F': {}, 'O': {}, 'I': {}, 'C': {}, 'E': {}, 'L': {}}
# is '20' in [':Int']
# Trying machine :Int
# digit(20) A Int [] {'A': {'digit': 'B'}, 'B': {'digit': 'C'}, 'C': {'digit': 'C'}}
# is '20' in ['digit']
# 	Normal transition
# DATA(DATA) B Int [] {'A': {'digit': 'B'}, 'B': {'digit': 'C'}, 'C': {'digit': 'C'}}
# is 'DATA' in ['digit']
# Found token 'Int': [{'token': 'digit', 'value': '20'}]
# :Int([{'token': 'digit', 'value': '20'}]) A BStatement [] {'A': {':Int': 'B'}, 'B': {':Remark': 'K', ':Dim': 'G', ':Def': 'H', ':Read': 'L', ':Goto': 'O', ':Return': 'J', ':For': 'E', ':Data': 'M', ':Gosub': 'I', ':Print': 'N', ':Next': 'F', ':Assign': 'C', ':If': 'D'}, 'G': {}, 'K': {}, 'N': {}, 'D': {}, 'H': {}, 'J': {}, 'M': {}, 'F': {}, 'O': {}, 'I': {}, 'C': {}, 'E': {}, 'L': {}}
# is '[{'token': 'digit', 'value': '20'}]' in [':Int']
# 	Normal transition
# DATA(DATA) B BStatement [] {'A': {':Int': 'B'}, 'B': {':Remark': 'K', ':Dim': 'G', ':Def': 'H', ':Read': 'L', ':Goto': 'O', ':Return': 'J', ':For': 'E', ':Data': 'M', ':Gosub': 'I', ':Print': 'N', ':Next': 'F', ':Assign': 'C', ':If': 'D'}, 'G': {}, 'K': {}, 'N': {}, 'D': {}, 'H': {}, 'J': {}, 'M': {}, 'F': {}, 'O': {}, 'I': {}, 'C': {}, 'E': {}, 'L': {}}
# is 'DATA' in [':Remark', ':Dim', ':Def', ':Read', ':Goto', ':Return', ':For', ':Data', ':Gosub', ':Print', ':Next', ':Assign', ':If']
# Trying machine :Remark
# DATA(DATA) A Remark [] {'A': {'REM': 'B'}, 'B': {':Character': 'C'}, 'C': {':Character': 'C'}}
# is 'DATA' in ['REM']
# Backtracking...
# DATA(DATA) B BStatement [':Dim', ':Def', ':Read', ':Goto', ':Return', ':For', ':Data', ':Gosub', ':Print', ':Next', ':Assign', ':If'] {'A': {':Int': 'B'}, 'B': {':Remark': 'K', ':Dim': 'G', ':Def': 'H', ':Read': 'L', ':Goto': 'O', ':Return': 'J', ':For': 'E', ':Data': 'M', ':Gosub': 'I', ':Print': 'N', ':Next': 'F', ':Assign': 'C', ':If': 'D'}, 'G': {}, 'K': {}, 'N': {}, 'D': {}, 'H': {}, 'J': {}, 'M': {}, 'F': {}, 'O': {}, 'I': {}, 'C': {}, 'E': {}, 'L': {}}
# is 'DATA' in [':Remark', ':Dim', ':Def', ':Read', ':Goto', ':Return', ':For', ':Data', ':Gosub', ':Print', ':Next', ':Assign', ':If']
# Trying machine :Dim
# DATA(DATA) A Dim [] {'A': {'DIM': 'B'}, 'B': {'letter': 'C'}, 'C': {'(': 'D'}, 'D': {':Int': 'E'}, 'E': {')': 'H', ',': 'G'}, 'H': {',': 'J'}, 'G': {':Int': 'F'}, 'J': {'letter': 'K'}, 'F': {')': 'H', ',': 'G'}, 'K': {'(': 'L'}, 'L': {':Int': 'M'}, 'M': {')': 'I', ',': 'O'}, 'I': {',': 'J'}, 'O': {':Int': 'N'}, 'N': {')': 'I', ',': 'O'}}
# is 'DATA' in ['DIM']
# Backtracking...
# DATA(DATA) B BStatement [':Def', ':Read', ':Goto', ':Return', ':For', ':Data', ':Gosub', ':Print', ':Next', ':Assign', ':If'] {'A': {':Int': 'B'}, 'B': {':Remark': 'K', ':Dim': 'G', ':Def': 'H', ':Read': 'L', ':Goto': 'O', ':Return': 'J', ':For': 'E', ':Data': 'M', ':Gosub': 'I', ':Print': 'N', ':Next': 'F', ':Assign': 'C', ':If': 'D'}, 'G': {}, 'K': {}, 'N': {}, 'D': {}, 'H': {}, 'J': {}, 'M': {}, 'F': {}, 'O': {}, 'I': {}, 'C': {}, 'E': {}, 'L': {}}
# is 'DATA' in [':Remark', ':Dim', ':Def', ':Read', ':Goto', ':Return', ':For', ':Data', ':Gosub', ':Print', ':Next', ':Assign', ':If']
# Trying machine :Def
# DATA(DATA) A Def [] {'A': {'DEF FN': 'B'}, 'B': {'letter': 'C'}, 'C': {'(': 'D'}, 'D': {'letter': 'E'}, 'E': {')': 'G', 'digit': 'F'}, 'G': {'=': 'H'}, 'F': {')': 'G'}, 'H': {':Exp': 'I'}, 'I': {}}
# is 'DATA' in ['DEF FN']
# Backtracking...
# DATA(DATA) B BStatement [':Read', ':Goto', ':Return', ':For', ':Data', ':Gosub', ':Print', ':Next', ':Assign', ':If'] {'A': {':Int': 'B'}, 'B': {':Remark': 'K', ':Dim': 'G', ':Def': 'H', ':Read': 'L', ':Goto': 'O', ':Return': 'J', ':For': 'E', ':Data': 'M', ':Gosub': 'I', ':Print': 'N', ':Next': 'F', ':Assign': 'C', ':If': 'D'}, 'G': {}, 'K': {}, 'N': {}, 'D': {}, 'H': {}, 'J': {}, 'M': {}, 'F': {}, 'O': {}, 'I': {}, 'C': {}, 'E': {}, 'L': {}}
# is 'DATA' in [':Remark', ':Dim', ':Def', ':Read', ':Goto', ':Return', ':For', ':Data', ':Gosub', ':Print', ':Next', ':Assign', ':If']
# Trying machine :Read
# DATA(DATA) A Read [] {'A': {'READ': 'B'}, 'B': {':Var': 'C'}, 'C': {',': 'E'}, 'E': {':Var': 'D'}, 'D': {',': 'E'}}
# is 'DATA' in ['READ']
# Backtracking...
# DATA(DATA) B BStatement [':Goto', ':Return', ':For', ':Data', ':Gosub', ':Print', ':Next', ':Assign', ':If'] {'A': {':Int': 'B'}, 'B': {':Remark': 'K', ':Dim': 'G', ':Def': 'H', ':Read': 'L', ':Goto': 'O', ':Return': 'J', ':For': 'E', ':Data': 'M', ':Gosub': 'I', ':Print': 'N', ':Next': 'F', ':Assign': 'C', ':If': 'D'}, 'G': {}, 'K': {}, 'N': {}, 'D': {}, 'H': {}, 'J': {}, 'M': {}, 'F': {}, 'O': {}, 'I': {}, 'C': {}, 'E': {}, 'L': {}}
# is 'DATA' in [':Remark', ':Dim', ':Def', ':Read', ':Goto', ':Return', ':For', ':Data', ':Gosub', ':Print', ':Next', ':Assign', ':If']
# Trying machine :Goto
# DATA(DATA) A Goto [] {'A': {'GOTO': 'B', 'GO': 'C'}, 'B': {':Int': 'E'}, 'C': {'TO': 'D'}, 'D': {':Int': 'E'}, 'E': {}}
# is 'DATA' in ['GOTO', 'GO']
# Backtracking...
# DATA(DATA) B BStatement [':Return', ':For', ':Data', ':Gosub', ':Print', ':Next', ':Assign', ':If'] {'A': {':Int': 'B'}, 'B': {':Remark': 'K', ':Dim': 'G', ':Def': 'H', ':Read': 'L', ':Goto': 'O', ':Return': 'J', ':For': 'E', ':Data': 'M', ':Gosub': 'I', ':Print': 'N', ':Next': 'F', ':Assign': 'C', ':If': 'D'}, 'G': {}, 'K': {}, 'N': {}, 'D': {}, 'H': {}, 'J': {}, 'M': {}, 'F': {}, 'O': {}, 'I': {}, 'C': {}, 'E': {}, 'L': {}}
# is 'DATA' in [':Remark', ':Dim', ':Def', ':Read', ':Goto', ':Return', ':For', ':Data', ':Gosub', ':Print', ':Next', ':Assign', ':If']
# Trying machine :Return
# DATA(DATA) A Return [] {'A': {'RETURN': 'B'}, 'B': {}}
# is 'DATA' in ['RETURN']
# Backtracking...
# DATA(DATA) B BStatement [':For', ':Data', ':Gosub', ':Print', ':Next', ':Assign', ':If'] {'A': {':Int': 'B'}, 'B': {':Remark': 'K', ':Dim': 'G', ':Def': 'H', ':Read': 'L', ':Goto': 'O', ':Return': 'J', ':For': 'E', ':Data': 'M', ':Gosub': 'I', ':Print': 'N', ':Next': 'F', ':Assign': 'C', ':If': 'D'}, 'G': {}, 'K': {}, 'N': {}, 'D': {}, 'H': {}, 'J': {}, 'M': {}, 'F': {}, 'O': {}, 'I': {}, 'C': {}, 'E': {}, 'L': {}}
# is 'DATA' in [':Remark', ':Dim', ':Def', ':Read', ':Goto', ':Return', ':For', ':Data', ':Gosub', ':Print', ':Next', ':Assign', ':If']
# Trying machine :For
# DATA(DATA) A For [] {'A': {'FOR': 'B'}, 'B': {'letter': 'C'}, 'C': {'digit': 'D', '=': 'E'}, 'D': {'=': 'E'}, 'E': {':Exp': 'F'}, 'F': {'TO': 'G'}, 'G': {':Exp': 'H'}, 'H': {'STEP': 'I'}, 'I': {':Exp': 'J'}, 'J': {}}
# is 'DATA' in ['FOR']
# Backtracking...
# DATA(DATA) B BStatement [':Data', ':Gosub', ':Print', ':Next', ':Assign', ':If'] {'A': {':Int': 'B'}, 'B': {':Remark': 'K', ':Dim': 'G', ':Def': 'H', ':Read': 'L', ':Goto': 'O', ':Return': 'J', ':For': 'E', ':Data': 'M', ':Gosub': 'I', ':Print': 'N', ':Next': 'F', ':Assign': 'C', ':If': 'D'}, 'G': {}, 'K': {}, 'N': {}, 'D': {}, 'H': {}, 'J': {}, 'M': {}, 'F': {}, 'O': {}, 'I': {}, 'C': {}, 'E': {}, 'L': {}}
# is 'DATA' in [':Remark', ':Dim', ':Def', ':Read', ':Goto', ':Return', ':For', ':Data', ':Gosub', ':Print', ':Next', ':Assign', ':If']
# Trying machine :Data
# DATA(DATA) A Data [] {'A': {'DATA': 'B'}, 'B': {':Snum': 'C'}, 'C': {',': 'E'}, 'E': {':Snum': 'D'}, 'D': {',': 'E'}}
# is 'DATA' in ['DATA']
# 	Normal transition
# digit(53) B Data [] {'A': {'DATA': 'B'}, 'B': {':Snum': 'C'}, 'C': {',': 'E'}, 'E': {':Snum': 'D'}, 'D': {',': 'E'}}
# is '53' in [':Snum']
# Trying machine :Snum
# digit(53) A Snum [] {'A': {'+': 'B', '-': 'C', ':Num': 'D'}, 'B': {':Num': 'D'}, 'C': {':Num': 'D'}, 'D': {}}
# is '53' in ['+', '-', ':Num']
# Trying machine :Num
# digit(53) A Num [] {'A': {':Int': 'B', '.': 'E'}, 'B': {'.': 'C', 'E': 'G'}, 'E': {':Int': 'F'}, 'C': {'digit': 'D', 'E': 'G'}, 'G': {'+': 'H', ':Int': 'J', '-': 'I'}, 'F': {'E': 'G'}, 'D': {'digit': 'D', 'E': 'G'}, 'H': {':Int': 'J'}, 'I': {':Int': 'J'}, 'J': {}}
# is '53' in [':Int', '.']
# Trying machine :Int
# digit(53) A Int [] {'A': {'digit': 'B'}, 'B': {'digit': 'C'}, 'C': {'digit': 'C'}}
# is '53' in ['digit']
# 	Normal transition
# ,(,) B Int [] {'A': {'digit': 'B'}, 'B': {'digit': 'C'}, 'C': {'digit': 'C'}}
# is ',' in ['digit']
# Found token 'Int': [{'token': 'digit', 'value': '53'}]
# :Int([{'token': 'digit', 'value': '53'}]) A Num [] {'A': {':Int': 'B', '.': 'E'}, 'B': {'.': 'C', 'E': 'G'}, 'E': {':Int': 'F'}, 'C': {'digit': 'D', 'E': 'G'}, 'G': {'+': 'H', ':Int': 'J', '-': 'I'}, 'F': {'E': 'G'}, 'D': {'digit': 'D', 'E': 'G'}, 'H': {':Int': 'J'}, 'I': {':Int': 'J'}, 'J': {}}
# is '[{'token': 'digit', 'value': '53'}]' in [':Int', '.']
# 	Normal transition
# ,(,) B Num [] {'A': {':Int': 'B', '.': 'E'}, 'B': {'.': 'C', 'E': 'G'}, 'E': {':Int': 'F'}, 'C': {'digit': 'D', 'E': 'G'}, 'G': {'+': 'H', ':Int': 'J', '-': 'I'}, 'F': {'E': 'G'}, 'D': {'digit': 'D', 'E': 'G'}, 'H': {':Int': 'J'}, 'I': {':Int': 'J'}, 'J': {}}
# is ',' in ['.', 'E']
# Found token 'Num': [{'token': ':Int', 'value': [{'token': 'digit', 'value': '53'}]}]
# :Num([{'token': ':Int', 'value': [{'token': 'digit', 'value': '53'}]}]) A Snum [] {'A': {'+': 'B', '-': 'C', ':Num': 'D'}, 'B': {':Num': 'D'}, 'C': {':Num': 'D'}, 'D': {}}
# is '[{'token': ':Int', 'value': [{'token': 'digit', 'value': '53'}]}]' in ['+', '-', ':Num']
# 	Normal transition
# ,(,) D Snum [] {'A': {'+': 'B', '-': 'C', ':Num': 'D'}, 'B': {':Num': 'D'}, 'C': {':Num': 'D'}, 'D': {}}
# is ',' in []
# Found token 'Snum': [{'token': ':Num', 'value': [{'token': ':Int', 'value': [{'token': 'digit', 'value': '53'}]}]}]
# :Snum([{'token': ':Num', 'value': [{'token': ':Int', 'value': [{'token': 'digit', 'value': '53'}]}]}]) B Data [] {'A': {'DATA': 'B'}, 'B': {':Snum': 'C'}, 'C': {',': 'E'}, 'E': {':Snum': 'D'}, 'D': {',': 'E'}}
# is '[{'token': ':Num', 'value': [{'token': ':Int', 'value': [{'token': 'digit', 'value': '53'}]}]}]' in [':Snum']
# 	Normal transition
# ,(,) C Data [] {'A': {'DATA': 'B'}, 'B': {':Snum': 'C'}, 'C': {',': 'E'}, 'E': {':Snum': 'D'}, 'D': {',': 'E'}}
# is ',' in [',']
# 	Normal transition
# digit(77) E Data [] {'A': {'DATA': 'B'}, 'B': {':Snum': 'C'}, 'C': {',': 'E'}, 'E': {':Snum': 'D'}, 'D': {',': 'E'}}
# is '77' in [':Snum']
# Trying machine :Snum
# digit(77) A Snum [] {'A': {'+': 'B', '-': 'C', ':Num': 'D'}, 'B': {':Num': 'D'}, 'C': {':Num': 'D'}, 'D': {}}
# is '77' in ['+', '-', ':Num']
# Trying machine :Num
# digit(77) A Num [] {'A': {':Int': 'B', '.': 'E'}, 'B': {'.': 'C', 'E': 'G'}, 'E': {':Int': 'F'}, 'C': {'digit': 'D', 'E': 'G'}, 'G': {'+': 'H', ':Int': 'J', '-': 'I'}, 'F': {'E': 'G'}, 'D': {'digit': 'D', 'E': 'G'}, 'H': {':Int': 'J'}, 'I': {':Int': 'J'}, 'J': {}}
# is '77' in [':Int', '.']
# Trying machine :Int
# digit(77) A Int [] {'A': {'digit': 'B'}, 'B': {'digit': 'C'}, 'C': {'digit': 'C'}}
# is '77' in ['digit']
# 	Normal transition
# ,(,) B Int [] {'A': {'digit': 'B'}, 'B': {'digit': 'C'}, 'C': {'digit': 'C'}}
# is ',' in ['digit']
# Found token 'Int': [{'token': 'digit', 'value': '77'}]
# :Int([{'token': 'digit', 'value': '77'}]) A Num [] {'A': {':Int': 'B', '.': 'E'}, 'B': {'.': 'C', 'E': 'G'}, 'E': {':Int': 'F'}, 'C': {'digit': 'D', 'E': 'G'}, 'G': {'+': 'H', ':Int': 'J', '-': 'I'}, 'F': {'E': 'G'}, 'D': {'digit': 'D', 'E': 'G'}, 'H': {':Int': 'J'}, 'I': {':Int': 'J'}, 'J': {}}
# is '[{'token': 'digit', 'value': '77'}]' in [':Int', '.']
# 	Normal transition
# ,(,) B Num [] {'A': {':Int': 'B', '.': 'E'}, 'B': {'.': 'C', 'E': 'G'}, 'E': {':Int': 'F'}, 'C': {'digit': 'D', 'E': 'G'}, 'G': {'+': 'H', ':Int': 'J', '-': 'I'}, 'F': {'E': 'G'}, 'D': {'digit': 'D', 'E': 'G'}, 'H': {':Int': 'J'}, 'I': {':Int': 'J'}, 'J': {}}
# is ',' in ['.', 'E']
# Found token 'Num': [{'token': ':Int', 'value': [{'token': 'digit', 'value': '77'}]}]
# :Num([{'token': ':Int', 'value': [{'token': 'digit', 'value': '77'}]}]) A Snum [] {'A': {'+': 'B', '-': 'C', ':Num': 'D'}, 'B': {':Num': 'D'}, 'C': {':Num': 'D'}, 'D': {}}
# is '[{'token': ':Int', 'value': [{'token': 'digit', 'value': '77'}]}]' in ['+', '-', ':Num']
# 	Normal transition
# ,(,) D Snum [] {'A': {'+': 'B', '-': 'C', ':Num': 'D'}, 'B': {':Num': 'D'}, 'C': {':Num': 'D'}, 'D': {}}
# is ',' in []
# Found token 'Snum': [{'token': ':Num', 'value': [{'token': ':Int', 'value': [{'token': 'digit', 'value': '77'}]}]}]
# :Snum([{'token': ':Num', 'value': [{'token': ':Int', 'value': [{'token': 'digit', 'value': '77'}]}]}]) E Data [] {'A': {'DATA': 'B'}, 'B': {':Snum': 'C'}, 'C': {',': 'E'}, 'E': {':Snum': 'D'}, 'D': {',': 'E'}}
# is '[{'token': ':Num', 'value': [{'token': ':Int', 'value': [{'token': 'digit', 'value': '77'}]}]}]' in [':Snum']
# 	Normal transition
# ,(,) D Data [] {'A': {'DATA': 'B'}, 'B': {':Snum': 'C'}, 'C': {',': 'E'}, 'E': {':Snum': 'D'}, 'D': {',': 'E'}}
# is ',' in [',']
# 	Normal transition
# digit(82) E Data [] {'A': {'DATA': 'B'}, 'B': {':Snum': 'C'}, 'C': {',': 'E'}, 'E': {':Snum': 'D'}, 'D': {',': 'E'}}
# is '82' in [':Snum']
# Trying machine :Snum
# digit(82) A Snum [] {'A': {'+': 'B', '-': 'C', ':Num': 'D'}, 'B': {':Num': 'D'}, 'C': {':Num': 'D'}, 'D': {}}
# is '82' in ['+', '-', ':Num']
# Trying machine :Num
# digit(82) A Num [] {'A': {':Int': 'B', '.': 'E'}, 'B': {'.': 'C', 'E': 'G'}, 'E': {':Int': 'F'}, 'C': {'digit': 'D', 'E': 'G'}, 'G': {'+': 'H', ':Int': 'J', '-': 'I'}, 'F': {'E': 'G'}, 'D': {'digit': 'D', 'E': 'G'}, 'H': {':Int': 'J'}, 'I': {':Int': 'J'}, 'J': {}}
# is '82' in [':Int', '.']
# Trying machine :Int
# digit(82) A Int [] {'A': {'digit': 'B'}, 'B': {'digit': 'C'}, 'C': {'digit': 'C'}}
# is '82' in ['digit']
# 	Normal transition
# ,(,) B Int [] {'A': {'digit': 'B'}, 'B': {'digit': 'C'}, 'C': {'digit': 'C'}}
# is ',' in ['digit']
# Found token 'Int': [{'token': 'digit', 'value': '82'}]
# :Int([{'token': 'digit', 'value': '82'}]) A Num [] {'A': {':Int': 'B', '.': 'E'}, 'B': {'.': 'C', 'E': 'G'}, 'E': {':Int': 'F'}, 'C': {'digit': 'D', 'E': 'G'}, 'G': {'+': 'H', ':Int': 'J', '-': 'I'}, 'F': {'E': 'G'}, 'D': {'digit': 'D', 'E': 'G'}, 'H': {':Int': 'J'}, 'I': {':Int': 'J'}, 'J': {}}
# is '[{'token': 'digit', 'value': '82'}]' in [':Int', '.']
# 	Normal transition
# ,(,) B Num [] {'A': {':Int': 'B', '.': 'E'}, 'B': {'.': 'C', 'E': 'G'}, 'E': {':Int': 'F'}, 'C': {'digit': 'D', 'E': 'G'}, 'G': {'+': 'H', ':Int': 'J', '-': 'I'}, 'F': {'E': 'G'}, 'D': {'digit': 'D', 'E': 'G'}, 'H': {':Int': 'J'}, 'I': {':Int': 'J'}, 'J': {}}
# is ',' in ['.', 'E']
# Found token 'Num': [{'token': ':Int', 'value': [{'token': 'digit', 'value': '82'}]}]
# :Num([{'token': ':Int', 'value': [{'token': 'digit', 'value': '82'}]}]) A Snum [] {'A': {'+': 'B', '-': 'C', ':Num': 'D'}, 'B': {':Num': 'D'}, 'C': {':Num': 'D'}, 'D': {}}
# is '[{'token': ':Int', 'value': [{'token': 'digit', 'value': '82'}]}]' in ['+', '-', ':Num']
# 	Normal transition
# ,(,) D Snum [] {'A': {'+': 'B', '-': 'C', ':Num': 'D'}, 'B': {':Num': 'D'}, 'C': {':Num': 'D'}, 'D': {}}
# is ',' in []
# Found token 'Snum': [{'token': ':Num', 'value': [{'token': ':Int', 'value': [{'token': 'digit', 'value': '82'}]}]}]
# :Snum([{'token': ':Num', 'value': [{'token': ':Int', 'value': [{'token': 'digit', 'value': '82'}]}]}]) E Data [] {'A': {'DATA': 'B'}, 'B': {':Snum': 'C'}, 'C': {',': 'E'}, 'E': {':Snum': 'D'}, 'D': {',': 'E'}}
# is '[{'token': ':Num', 'value': [{'token': ':Int', 'value': [{'token': 'digit', 'value': '82'}]}]}]' in [':Snum']
# 	Normal transition
# ,(,) D Data [] {'A': {'DATA': 'B'}, 'B': {':Snum': 'C'}, 'C': {',': 'E'}, 'E': {':Snum': 'D'}, 'D': {',': 'E'}}
# is ',' in [',']
# 	Normal transition
# digit(12) E Data [] {'A': {'DATA': 'B'}, 'B': {':Snum': 'C'}, 'C': {',': 'E'}, 'E': {':Snum': 'D'}, 'D': {',': 'E'}}
# is '12' in [':Snum']
# Trying machine :Snum
# digit(12) A Snum [] {'A': {'+': 'B', '-': 'C', ':Num': 'D'}, 'B': {':Num': 'D'}, 'C': {':Num': 'D'}, 'D': {}}
# is '12' in ['+', '-', ':Num']
# Trying machine :Num
# digit(12) A Num [] {'A': {':Int': 'B', '.': 'E'}, 'B': {'.': 'C', 'E': 'G'}, 'E': {':Int': 'F'}, 'C': {'digit': 'D', 'E': 'G'}, 'G': {'+': 'H', ':Int': 'J', '-': 'I'}, 'F': {'E': 'G'}, 'D': {'digit': 'D', 'E': 'G'}, 'H': {':Int': 'J'}, 'I': {':Int': 'J'}, 'J': {}}
# is '12' in [':Int', '.']
# Trying machine :Int
# digit(12) A Int [] {'A': {'digit': 'B'}, 'B': {'digit': 'C'}, 'C': {'digit': 'C'}}
# is '12' in ['digit']
# 	Normal transition
# ,(,) B Int [] {'A': {'digit': 'B'}, 'B': {'digit': 'C'}, 'C': {'digit': 'C'}}
# is ',' in ['digit']
# Found token 'Int': [{'token': 'digit', 'value': '12'}]
# :Int([{'token': 'digit', 'value': '12'}]) A Num [] {'A': {':Int': 'B', '.': 'E'}, 'B': {'.': 'C', 'E': 'G'}, 'E': {':Int': 'F'}, 'C': {'digit': 'D', 'E': 'G'}, 'G': {'+': 'H', ':Int': 'J', '-': 'I'}, 'F': {'E': 'G'}, 'D': {'digit': 'D', 'E': 'G'}, 'H': {':Int': 'J'}, 'I': {':Int': 'J'}, 'J': {}}
# is '[{'token': 'digit', 'value': '12'}]' in [':Int', '.']
# 	Normal transition
# ,(,) B Num [] {'A': {':Int': 'B', '.': 'E'}, 'B': {'.': 'C', 'E': 'G'}, 'E': {':Int': 'F'}, 'C': {'digit': 'D', 'E': 'G'}, 'G': {'+': 'H', ':Int': 'J', '-': 'I'}, 'F': {'E': 'G'}, 'D': {'digit': 'D', 'E': 'G'}, 'H': {':Int': 'J'}, 'I': {':Int': 'J'}, 'J': {}}
# is ',' in ['.', 'E']
# Found token 'Num': [{'token': ':Int', 'value': [{'token': 'digit', 'value': '12'}]}]
# :Num([{'token': ':Int', 'value': [{'token': 'digit', 'value': '12'}]}]) A Snum [] {'A': {'+': 'B', '-': 'C', ':Num': 'D'}, 'B': {':Num': 'D'}, 'C': {':Num': 'D'}, 'D': {}}
# is '[{'token': ':Int', 'value': [{'token': 'digit', 'value': '12'}]}]' in ['+', '-', ':Num']
# 	Normal transition
# ,(,) D Snum [] {'A': {'+': 'B', '-': 'C', ':Num': 'D'}, 'B': {':Num': 'D'}, 'C': {':Num': 'D'}, 'D': {}}
# is ',' in []
# Found token 'Snum': [{'token': ':Num', 'value': [{'token': ':Int', 'value': [{'token': 'digit', 'value': '12'}]}]}]
# :Snum([{'token': ':Num', 'value': [{'token': ':Int', 'value': [{'token': 'digit', 'value': '12'}]}]}]) E Data [] {'A': {'DATA': 'B'}, 'B': {':Snum': 'C'}, 'C': {',': 'E'}, 'E': {':Snum': 'D'}, 'D': {',': 'E'}}
# is '[{'token': ':Num', 'value': [{'token': ':Int', 'value': [{'token': 'digit', 'value': '12'}]}]}]' in [':Snum']
# 	Normal transition
# ,(,) D Data [] {'A': {'DATA': 'B'}, 'B': {':Snum': 'C'}, 'C': {',': 'E'}, 'E': {':Snum': 'D'}, 'D': {',': 'E'}}
# is ',' in [',']
# 	Normal transition
# digit(38) E Data [] {'A': {'DATA': 'B'}, 'B': {':Snum': 'C'}, 'C': {',': 'E'}, 'E': {':Snum': 'D'}, 'D': {',': 'E'}}
# is '38' in [':Snum']
# Trying machine :Snum
# digit(38) A Snum [] {'A': {'+': 'B', '-': 'C', ':Num': 'D'}, 'B': {':Num': 'D'}, 'C': {':Num': 'D'}, 'D': {}}
# is '38' in ['+', '-', ':Num']
# Trying machine :Num
# digit(38) A Num [] {'A': {':Int': 'B', '.': 'E'}, 'B': {'.': 'C', 'E': 'G'}, 'E': {':Int': 'F'}, 'C': {'digit': 'D', 'E': 'G'}, 'G': {'+': 'H', ':Int': 'J', '-': 'I'}, 'F': {'E': 'G'}, 'D': {'digit': 'D', 'E': 'G'}, 'H': {':Int': 'J'}, 'I': {':Int': 'J'}, 'J': {}}
# is '38' in [':Int', '.']
# Trying machine :Int
# digit(38) A Int [] {'A': {'digit': 'B'}, 'B': {'digit': 'C'}, 'C': {'digit': 'C'}}
# is '38' in ['digit']
# 	Normal transition
# ,(,) B Int [] {'A': {'digit': 'B'}, 'B': {'digit': 'C'}, 'C': {'digit': 'C'}}
# is ',' in ['digit']
# Found token 'Int': [{'token': 'digit', 'value': '38'}]
# :Int([{'token': 'digit', 'value': '38'}]) A Num [] {'A': {':Int': 'B', '.': 'E'}, 'B': {'.': 'C', 'E': 'G'}, 'E': {':Int': 'F'}, 'C': {'digit': 'D', 'E': 'G'}, 'G': {'+': 'H', ':Int': 'J', '-': 'I'}, 'F': {'E': 'G'}, 'D': {'digit': 'D', 'E': 'G'}, 'H': {':Int': 'J'}, 'I': {':Int': 'J'}, 'J': {}}
# is '[{'token': 'digit', 'value': '38'}]' in [':Int', '.']
# 	Normal transition
# ,(,) B Num [] {'A': {':Int': 'B', '.': 'E'}, 'B': {'.': 'C', 'E': 'G'}, 'E': {':Int': 'F'}, 'C': {'digit': 'D', 'E': 'G'}, 'G': {'+': 'H', ':Int': 'J', '-': 'I'}, 'F': {'E': 'G'}, 'D': {'digit': 'D', 'E': 'G'}, 'H': {':Int': 'J'}, 'I': {':Int': 'J'}, 'J': {}}
# is ',' in ['.', 'E']
# Found token 'Num': [{'token': ':Int', 'value': [{'token': 'digit', 'value': '38'}]}]
# :Num([{'token': ':Int', 'value': [{'token': 'digit', 'value': '38'}]}]) A Snum [] {'A': {'+': 'B', '-': 'C', ':Num': 'D'}, 'B': {':Num': 'D'}, 'C': {':Num': 'D'}, 'D': {}}
# is '[{'token': ':Int', 'value': [{'token': 'digit', 'value': '38'}]}]' in ['+', '-', ':Num']
# 	Normal transition
# ,(,) D Snum [] {'A': {'+': 'B', '-': 'C', ':Num': 'D'}, 'B': {':Num': 'D'}, 'C': {':Num': 'D'}, 'D': {}}
# is ',' in []
# Found token 'Snum': [{'token': ':Num', 'value': [{'token': ':Int', 'value': [{'token': 'digit', 'value': '38'}]}]}]
# :Snum([{'token': ':Num', 'value': [{'token': ':Int', 'value': [{'token': 'digit', 'value': '38'}]}]}]) E Data [] {'A': {'DATA': 'B'}, 'B': {':Snum': 'C'}, 'C': {',': 'E'}, 'E': {':Snum': 'D'}, 'D': {',': 'E'}}
# is '[{'token': ':Num', 'value': [{'token': ':Int', 'value': [{'token': 'digit', 'value': '38'}]}]}]' in [':Snum']
# 	Normal transition
# ,(,) D Data [] {'A': {'DATA': 'B'}, 'B': {':Snum': 'C'}, 'C': {',': 'E'}, 'E': {':Snum': 'D'}, 'D': {',': 'E'}}
# is ',' in [',']
# 	Normal transition
# digit(90) E Data [] {'A': {'DATA': 'B'}, 'B': {':Snum': 'C'}, 'C': {',': 'E'}, 'E': {':Snum': 'D'}, 'D': {',': 'E'}}
# is '90' in [':Snum']
# Trying machine :Snum
# digit(90) A Snum [] {'A': {'+': 'B', '-': 'C', ':Num': 'D'}, 'B': {':Num': 'D'}, 'C': {':Num': 'D'}, 'D': {}}
# is '90' in ['+', '-', ':Num']
# Trying machine :Num
# digit(90) A Num [] {'A': {':Int': 'B', '.': 'E'}, 'B': {'.': 'C', 'E': 'G'}, 'E': {':Int': 'F'}, 'C': {'digit': 'D', 'E': 'G'}, 'G': {'+': 'H', ':Int': 'J', '-': 'I'}, 'F': {'E': 'G'}, 'D': {'digit': 'D', 'E': 'G'}, 'H': {':Int': 'J'}, 'I': {':Int': 'J'}, 'J': {}}
# is '90' in [':Int', '.']
# Trying machine :Int
# digit(90) A Int [] {'A': {'digit': 'B'}, 'B': {'digit': 'C'}, 'C': {'digit': 'C'}}
# is '90' in ['digit']
# 	Normal transition
# ,(,) B Int [] {'A': {'digit': 'B'}, 'B': {'digit': 'C'}, 'C': {'digit': 'C'}}
# is ',' in ['digit']
# Found token 'Int': [{'token': 'digit', 'value': '90'}]
# :Int([{'token': 'digit', 'value': '90'}]) A Num [] {'A': {':Int': 'B', '.': 'E'}, 'B': {'.': 'C', 'E': 'G'}, 'E': {':Int': 'F'}, 'C': {'digit': 'D', 'E': 'G'}, 'G': {'+': 'H', ':Int': 'J', '-': 'I'}, 'F': {'E': 'G'}, 'D': {'digit': 'D', 'E': 'G'}, 'H': {':Int': 'J'}, 'I': {':Int': 'J'}, 'J': {}}
# is '[{'token': 'digit', 'value': '90'}]' in [':Int', '.']
# 	Normal transition
# ,(,) B Num [] {'A': {':Int': 'B', '.': 'E'}, 'B': {'.': 'C', 'E': 'G'}, 'E': {':Int': 'F'}, 'C': {'digit': 'D', 'E': 'G'}, 'G': {'+': 'H', ':Int': 'J', '-': 'I'}, 'F': {'E': 'G'}, 'D': {'digit': 'D', 'E': 'G'}, 'H': {':Int': 'J'}, 'I': {':Int': 'J'}, 'J': {}}
# is ',' in ['.', 'E']
# Found token 'Num': [{'token': ':Int', 'value': [{'token': 'digit', 'value': '90'}]}]
# :Num([{'token': ':Int', 'value': [{'token': 'digit', 'value': '90'}]}]) A Snum [] {'A': {'+': 'B', '-': 'C', ':Num': 'D'}, 'B': {':Num': 'D'}, 'C': {':Num': 'D'}, 'D': {}}
# is '[{'token': ':Int', 'value': [{'token': 'digit', 'value': '90'}]}]' in ['+', '-', ':Num']
# 	Normal transition
# ,(,) D Snum [] {'A': {'+': 'B', '-': 'C', ':Num': 'D'}, 'B': {':Num': 'D'}, 'C': {':Num': 'D'}, 'D': {}}
# is ',' in []
# Found token 'Snum': [{'token': ':Num', 'value': [{'token': ':Int', 'value': [{'token': 'digit', 'value': '90'}]}]}]
# :Snum([{'token': ':Num', 'value': [{'token': ':Int', 'value': [{'token': 'digit', 'value': '90'}]}]}]) E Data [] {'A': {'DATA': 'B'}, 'B': {':Snum': 'C'}, 'C': {',': 'E'}, 'E': {':Snum': 'D'}, 'D': {',': 'E'}}
# is '[{'token': ':Num', 'value': [{'token': ':Int', 'value': [{'token': 'digit', 'value': '90'}]}]}]' in [':Snum']
# 	Normal transition
# ,(,) D Data [] {'A': {'DATA': 'B'}, 'B': {':Snum': 'C'}, 'C': {',': 'E'}, 'E': {':Snum': 'D'}, 'D': {',': 'E'}}
# is ',' in [',']
# 	Normal transition
# digit(16) E Data [] {'A': {'DATA': 'B'}, 'B': {':Snum': 'C'}, 'C': {',': 'E'}, 'E': {':Snum': 'D'}, 'D': {',': 'E'}}
# is '16' in [':Snum']
# Trying machine :Snum
# digit(16) A Snum [] {'A': {'+': 'B', '-': 'C', ':Num': 'D'}, 'B': {':Num': 'D'}, 'C': {':Num': 'D'}, 'D': {}}
# is '16' in ['+', '-', ':Num']
# Trying machine :Num
# digit(16) A Num [] {'A': {':Int': 'B', '.': 'E'}, 'B': {'.': 'C', 'E': 'G'}, 'E': {':Int': 'F'}, 'C': {'digit': 'D', 'E': 'G'}, 'G': {'+': 'H', ':Int': 'J', '-': 'I'}, 'F': {'E': 'G'}, 'D': {'digit': 'D', 'E': 'G'}, 'H': {':Int': 'J'}, 'I': {':Int': 'J'}, 'J': {}}
# is '16' in [':Int', '.']
# Trying machine :Int
# digit(16) A Int [] {'A': {'digit': 'B'}, 'B': {'digit': 'C'}, 'C': {'digit': 'C'}}
# is '16' in ['digit']
# 	Normal transition
# ,(,) B Int [] {'A': {'digit': 'B'}, 'B': {'digit': 'C'}, 'C': {'digit': 'C'}}
# is ',' in ['digit']
# Found token 'Int': [{'token': 'digit', 'value': '16'}]
# :Int([{'token': 'digit', 'value': '16'}]) A Num [] {'A': {':Int': 'B', '.': 'E'}, 'B': {'.': 'C', 'E': 'G'}, 'E': {':Int': 'F'}, 'C': {'digit': 'D', 'E': 'G'}, 'G': {'+': 'H', ':Int': 'J', '-': 'I'}, 'F': {'E': 'G'}, 'D': {'digit': 'D', 'E': 'G'}, 'H': {':Int': 'J'}, 'I': {':Int': 'J'}, 'J': {}}
# is '[{'token': 'digit', 'value': '16'}]' in [':Int', '.']
# 	Normal transition
# ,(,) B Num [] {'A': {':Int': 'B', '.': 'E'}, 'B': {'.': 'C', 'E': 'G'}, 'E': {':Int': 'F'}, 'C': {'digit': 'D', 'E': 'G'}, 'G': {'+': 'H', ':Int': 'J', '-': 'I'}, 'F': {'E': 'G'}, 'D': {'digit': 'D', 'E': 'G'}, 'H': {':Int': 'J'}, 'I': {':Int': 'J'}, 'J': {}}
# is ',' in ['.', 'E']
# Found token 'Num': [{'token': ':Int', 'value': [{'token': 'digit', 'value': '16'}]}]
# :Num([{'token': ':Int', 'value': [{'token': 'digit', 'value': '16'}]}]) A Snum [] {'A': {'+': 'B', '-': 'C', ':Num': 'D'}, 'B': {':Num': 'D'}, 'C': {':Num': 'D'}, 'D': {}}
# is '[{'token': ':Int', 'value': [{'token': 'digit', 'value': '16'}]}]' in ['+', '-', ':Num']
# 	Normal transition
# ,(,) D Snum [] {'A': {'+': 'B', '-': 'C', ':Num': 'D'}, 'B': {':Num': 'D'}, 'C': {':Num': 'D'}, 'D': {}}
# is ',' in []
# Found token 'Snum': [{'token': ':Num', 'value': [{'token': ':Int', 'value': [{'token': 'digit', 'value': '16'}]}]}]
# :Snum([{'token': ':Num', 'value': [{'token': ':Int', 'value': [{'token': 'digit', 'value': '16'}]}]}]) E Data [] {'A': {'DATA': 'B'}, 'B': {':Snum': 'C'}, 'C': {',': 'E'}, 'E': {':Snum': 'D'}, 'D': {',': 'E'}}
# is '[{'token': ':Num', 'value': [{'token': ':Int', 'value': [{'token': 'digit', 'value': '16'}]}]}]' in [':Snum']
# 	Normal transition
# ,(,) D Data [] {'A': {'DATA': 'B'}, 'B': {':Snum': 'C'}, 'C': {',': 'E'}, 'E': {':Snum': 'D'}, 'D': {',': 'E'}}
# is ',' in [',']
# 	Normal transition
# digit(72) E Data [] {'A': {'DATA': 'B'}, 'B': {':Snum': 'C'}, 'C': {',': 'E'}, 'E': {':Snum': 'D'}, 'D': {',': 'E'}}
# is '72' in [':Snum']
# Trying machine :Snum
# digit(72) A Snum [] {'A': {'+': 'B', '-': 'C', ':Num': 'D'}, 'B': {':Num': 'D'}, 'C': {':Num': 'D'}, 'D': {}}
# is '72' in ['+', '-', ':Num']
# Trying machine :Num
# digit(72) A Num [] {'A': {':Int': 'B', '.': 'E'}, 'B': {'.': 'C', 'E': 'G'}, 'E': {':Int': 'F'}, 'C': {'digit': 'D', 'E': 'G'}, 'G': {'+': 'H', ':Int': 'J', '-': 'I'}, 'F': {'E': 'G'}, 'D': {'digit': 'D', 'E': 'G'}, 'H': {':Int': 'J'}, 'I': {':Int': 'J'}, 'J': {}}
# is '72' in [':Int', '.']
# Trying machine :Int
# digit(72) A Int [] {'A': {'digit': 'B'}, 'B': {'digit': 'C'}, 'C': {'digit': 'C'}}
# is '72' in ['digit']
# 	Normal transition
# ,(,) B Int [] {'A': {'digit': 'B'}, 'B': {'digit': 'C'}, 'C': {'digit': 'C'}}
# is ',' in ['digit']
# Found token 'Int': [{'token': 'digit', 'value': '72'}]
# :Int([{'token': 'digit', 'value': '72'}]) A Num [] {'A': {':Int': 'B', '.': 'E'}, 'B': {'.': 'C', 'E': 'G'}, 'E': {':Int': 'F'}, 'C': {'digit': 'D', 'E': 'G'}, 'G': {'+': 'H', ':Int': 'J', '-': 'I'}, 'F': {'E': 'G'}, 'D': {'digit': 'D', 'E': 'G'}, 'H': {':Int': 'J'}, 'I': {':Int': 'J'}, 'J': {}}
# is '[{'token': 'digit', 'value': '72'}]' in [':Int', '.']
# 	Normal transition
# ,(,) B Num [] {'A': {':Int': 'B', '.': 'E'}, 'B': {'.': 'C', 'E': 'G'}, 'E': {':Int': 'F'}, 'C': {'digit': 'D', 'E': 'G'}, 'G': {'+': 'H', ':Int': 'J', '-': 'I'}, 'F': {'E': 'G'}, 'D': {'digit': 'D', 'E': 'G'}, 'H': {':Int': 'J'}, 'I': {':Int': 'J'}, 'J': {}}
# is ',' in ['.', 'E']
# Found token 'Num': [{'token': ':Int', 'value': [{'token': 'digit', 'value': '72'}]}]
# :Num([{'token': ':Int', 'value': [{'token': 'digit', 'value': '72'}]}]) A Snum [] {'A': {'+': 'B', '-': 'C', ':Num': 'D'}, 'B': {':Num': 'D'}, 'C': {':Num': 'D'}, 'D': {}}
# is '[{'token': ':Int', 'value': [{'token': 'digit', 'value': '72'}]}]' in ['+', '-', ':Num']
# 	Normal transition
# ,(,) D Snum [] {'A': {'+': 'B', '-': 'C', ':Num': 'D'}, 'B': {':Num': 'D'}, 'C': {':Num': 'D'}, 'D': {}}
# is ',' in []
# Found token 'Snum': [{'token': ':Num', 'value': [{'token': ':Int', 'value': [{'token': 'digit', 'value': '72'}]}]}]
# ...
# is '[{'token': ':Eb', 'value': [{'token': ':Var', 'value': [{'token': 'letter', 'value': 'Z'}, {'token': '(', 'value': '('}, {'token': ':Exp', 'value': [{'token': ':Eb', 'value': [{'token': ':Var', 'value': [{'token': 'letter', 'value': 'I'}]}]}]}, {'token': ')', 'value': ')'}]}]}]' in ['"', ':Exp']
# 	Normal transition
#
# (
# ) B Pitem [] {'A': {'"': 'C', ':Exp': 'B'}, 'C': {':Character': 'D'}, 'D': {'"': 'F', ':Character': 'E'}, 'F': {':Exp': 'G'}, 'E': {'"': 'F', ':Character': 'E'}, 'G': {}, 'B': {}}
# is '
# ' in []
# Found token 'Pitem': [{'token': ':Exp', 'value': [{'token': ':Eb', 'value': [{'token': ':Var', 'value': [{'token': 'letter', 'value': 'Z'}, {'token': '(', 'value': '('}, {'token': ':Exp', 'value': [{'token': ':Eb', 'value': [{'token': ':Var', 'value': [{'token': 'letter', 'value': 'I'}]}]}]}, {'token': ')', 'value': ')'}]}]}]}]
# :Pitem([{'token': ':Exp', 'value': [{'token': ':Eb', 'value': [{'token': ':Var', 'value': [{'token': 'letter', 'value': 'Z'}, {'token': '(', 'value': '('}, {'token': ':Exp', 'value': [{'token': ':Eb', 'value': [{'token': ':Var', 'value': [{'token': 'letter', 'value': 'I'}]}]}]}, {'token': ')', 'value': ')'}]}]}]}]) B Print [] {'A': {'PRINT': 'B'}, 'B': {':Pitem': 'C'}, 'C': {',': 'F'}, 'F': {':Pitem': 'D'}, 'D': {',': 'F'}, 'G': {}, 'E': {}}
# is '[{'token': ':Exp', 'value': [{'token': ':Eb', 'value': [{'token': ':Var', 'value': [{'token': 'letter', 'value': 'Z'}, {'token': '(', 'value': '('}, {'token': ':Exp', 'value': [{'token': ':Eb', 'value': [{'token': ':Var', 'value': [{'token': 'letter', 'value': 'I'}]}]}]}, {'token': ')', 'value': ')'}]}]}]}]' in [':Pitem']
# 	Normal transition
#
# (
# ) C Print [] {'A': {'PRINT': 'B'}, 'B': {':Pitem': 'C'}, 'C': {',': 'F'}, 'F': {':Pitem': 'D'}, 'D': {',': 'F'}, 'G': {}, 'E': {}}
# is '
# ' in [',']
# Found token 'Print': [{'token': 'PRINT', 'value': 'PRINT'}, {'token': ':Pitem', 'value': [{'token': ':Exp', 'value': [{'token': ':Eb', 'value': [{'token': ':Var', 'value': [{'token': 'letter', 'value': 'Z'}, {'token': '(', 'value': '('}, {'token': ':Exp', 'value': [{'token': ':Eb', 'value': [{'token': ':Var', 'value': [{'token': 'letter', 'value': 'I'}]}]}]}, {'token': ')', 'value': ')'}]}]}]}]}]
# :Print([{'token': 'PRINT', 'value': 'PRINT'}, {'token': ':Pitem', 'value': [{'token': ':Exp', 'value': [{'token': ':Eb', 'value': [{'token': ':Var', 'value': [{'token': 'letter', 'value': 'Z'}, {'token': '(', 'value': '('}, {'token': ':Exp', 'value': [{'token': ':Eb', 'value': [{'token': ':Var', 'value': [{'token': 'letter', 'value': 'I'}]}]}]}, {'token': ')', 'value': ')'}]}]}]}]}]) B BStatement [':Next', ':Assign', ':If'] {'A': {':Int': 'B'}, 'B': {':Remark': 'K', ':Dim': 'G', ':Def': 'H', ':Read': 'L', ':Goto': 'O', ':Return': 'J', ':For': 'E', ':Data': 'M', ':Gosub': 'I', ':Print': 'N', ':Next': 'F', ':Assign': 'C', ':If': 'D'}, 'G': {}, 'K': {}, 'N': {}, 'D': {}, 'H': {}, 'J': {}, 'M': {}, 'F': {}, 'O': {}, 'I': {}, 'C': {}, 'E': {}, 'L': {}}
# is '[{'token': 'PRINT', 'value': 'PRINT'}, {'token': ':Pitem', 'value': [{'token': ':Exp', 'value': [{'token': ':Eb', 'value': [{'token': ':Var', 'value': [{'token': 'letter', 'value': 'Z'}, {'token': '(', 'value': '('}, {'token': ':Exp', 'value': [{'token': ':Eb', 'value': [{'token': ':Var', 'value': [{'token': 'letter', 'value': 'I'}]}]}]}, {'token': ')', 'value': ')'}]}]}]}]}]' in [':Remark', ':Dim', ':Def', ':Read', ':Goto', ':Return', ':For', ':Data', ':Gosub', ':Print', ':Next', ':Assign', ':If']
# 	Normal transition
#
# (
# ) N BStatement [] {'A': {':Int': 'B'}, 'B': {':Remark': 'K', ':Dim': 'G', ':Def': 'H', ':Read': 'L', ':Goto': 'O', ':Return': 'J', ':For': 'E', ':Data': 'M', ':Gosub': 'I', ':Print': 'N', ':Next': 'F', ':Assign': 'C', ':If': 'D'}, 'G': {}, 'K': {}, 'N': {}, 'D': {}, 'H': {}, 'J': {}, 'M': {}, 'F': {}, 'O': {}, 'I': {}, 'C': {}, 'E': {}, 'L': {}}
# is '
# ' in []
# Found token 'BStatement': [{'token': ':Int', 'value': [{'token': 'digit', 'value': '9000'}]}, {'token': ':Print', 'value': [{'token': 'PRINT', 'value': 'PRINT'}, {'token': ':Pitem', 'value': [{'token': ':Exp', 'value': [{'token': ':Eb', 'value': [{'token': ':Var', 'value': [{'token': 'letter', 'value': 'Z'}, {'token': '(', 'value': '('}, {'token': ':Exp', 'value': [{'token': ':Eb', 'value': [{'token': ':Var', 'value': [{'token': 'letter', 'value': 'I'}]}]}]}, {'token': ')', 'value': ')'}]}]}]}]}]}]
# :BStatement([{'token': ':Int', 'value': [{'token': 'digit', 'value': '9000'}]}, {'token': ':Print', 'value': [{'token': 'PRINT', 'value': 'PRINT'}, {'token': ':Pitem', 'value': [{'token': ':Exp', 'value': [{'token': ':Eb', 'value': [{'token': ':Var', 'value': [{'token': 'letter', 'value': 'Z'}, {'token': '(', 'value': '('}, {'token': ':Exp', 'value': [{'token': ':Eb', 'value': [{'token': ':Var', 'value': [{'token': 'letter', 'value': 'I'}]}]}]}, {'token': ')', 'value': ')'}]}]}]}]}]}]) D Program [':Int'] {'A': {':BStatement': 'B'}, 'B': {'\n': 'C'}, 'C': {':BStatement': 'F', ':Int': 'G'}, 'F': {'\n': 'D'}, 'G': {'END': 'H'}, 'D': {'\n': 'E', ':BStatement': 'F', ':Int': 'G'}, 'E': {'\n': 'E', ':BStatement': 'F', ':Int': 'G'}, 'H': {}}
# is '[{'token': ':Int', 'value': [{'token': 'digit', 'value': '9000'}]}, {'token': ':Print', 'value': [{'token': 'PRINT', 'value': 'PRINT'}, {'token': ':Pitem', 'value': [{'token': ':Exp', 'value': [{'token': ':Eb', 'value': [{'token': ':Var', 'value': [{'token': 'letter', 'value': 'Z'}, {'token': '(', 'value': '('}, {'token': ':Exp', 'value': [{'token': ':Eb', 'value': [{'token': ':Var', 'value': [{'token': 'letter', 'value': 'I'}]}]}]}, {'token': ')', 'value': ')'}]}]}]}]}]}]' in ['\n', ':BStatement', ':Int']
# 	Normal transition
#
# (
# ) F Program [] {'A': {':BStatement': 'B'}, 'B': {'\n': 'C'}, 'C': {':BStatement': 'F', ':Int': 'G'}, 'F': {'\n': 'D'}, 'G': {'END': 'H'}, 'D': {'\n': 'E', ':BStatement': 'F', ':Int': 'G'}, 'E': {'\n': 'E', ':BStatement': 'F', ':Int': 'G'}, 'H': {}}
# is '
# ' in ['\n']
# 	Normal transition
# digit(9000) D Program [] {'A': {':BStatement': 'B'}, 'B': {'\n': 'C'}, 'C': {':BStatement': 'F', ':Int': 'G'}, 'F': {'\n': 'D'}, 'G': {'END': 'H'}, 'D': {'\n': 'E', ':BStatement': 'F', ':Int': 'G'}, 'E': {'\n': 'E', ':BStatement': 'F', ':Int': 'G'}, 'H': {}}
# is '9000' in ['\n', ':BStatement', ':Int']
# Trying machine :BStatement
# digit(9000) A BStatement [] {'A': {':Int': 'B'}, 'B': {':Remark': 'K', ':Dim': 'G', ':Def': 'H', ':Read': 'L', ':Goto': 'O', ':Return': 'J', ':For': 'E', ':Data': 'M', ':Gosub': 'I', ':Print': 'N', ':Next': 'F', ':Assign': 'C', ':If': 'D'}, 'G': {}, 'K': {}, 'N': {}, 'D': {}, 'H': {}, 'J': {}, 'M': {}, 'F': {}, 'O': {}, 'I': {}, 'C': {}, 'E': {}, 'L': {}}
# is '9000' in [':Int']
# Trying machine :Int
# digit(9000) A Int [] {'A': {'digit': 'B'}, 'B': {'digit': 'C'}, 'C': {'digit': 'C'}}
# is '9000' in ['digit']
# 	Normal transition
# NEXT(NEXT) B Int [] {'A': {'digit': 'B'}, 'B': {'digit': 'C'}, 'C': {'digit': 'C'}}
# is 'NEXT' in ['digit']
# Found token 'Int': [{'token': 'digit', 'value': '9000'}]
# :Int([{'token': 'digit', 'value': '9000'}]) A BStatement [] {'A': {':Int': 'B'}, 'B': {':Remark': 'K', ':Dim': 'G', ':Def': 'H', ':Read': 'L', ':Goto': 'O', ':Return': 'J', ':For': 'E', ':Data': 'M', ':Gosub': 'I', ':Print': 'N', ':Next': 'F', ':Assign': 'C', ':If': 'D'}, 'G': {}, 'K': {}, 'N': {}, 'D': {}, 'H': {}, 'J': {}, 'M': {}, 'F': {}, 'O': {}, 'I': {}, 'C': {}, 'E': {}, 'L': {}}
# is '[{'token': 'digit', 'value': '9000'}]' in [':Int']
# 	Normal transition
# NEXT(NEXT) B BStatement [] {'A': {':Int': 'B'}, 'B': {':Remark': 'K', ':Dim': 'G', ':Def': 'H', ':Read': 'L', ':Goto': 'O', ':Return': 'J', ':For': 'E', ':Data': 'M', ':Gosub': 'I', ':Print': 'N', ':Next': 'F', ':Assign': 'C', ':If': 'D'}, 'G': {}, 'K': {}, 'N': {}, 'D': {}, 'H': {}, 'J': {}, 'M': {}, 'F': {}, 'O': {}, 'I': {}, 'C': {}, 'E': {}, 'L': {}}
# is 'NEXT' in [':Remark', ':Dim', ':Def', ':Read', ':Goto', ':Return', ':For', ':Data', ':Gosub', ':Print', ':Next', ':Assign', ':If']
# Trying machine :Remark
# NEXT(NEXT) A Remark [] {'A': {'REM': 'B'}, 'B': {':Character': 'C'}, 'C': {':Character': 'C'}}
# is 'NEXT' in ['REM']
# Backtracking...
# NEXT(NEXT) B BStatement [':Dim', ':Def', ':Read', ':Goto', ':Return', ':For', ':Data', ':Gosub', ':Print', ':Next', ':Assign', ':If'] {'A': {':Int': 'B'}, 'B': {':Remark': 'K', ':Dim': 'G', ':Def': 'H', ':Read': 'L', ':Goto': 'O', ':Return': 'J', ':For': 'E', ':Data': 'M', ':Gosub': 'I', ':Print': 'N', ':Next': 'F', ':Assign': 'C', ':If': 'D'}, 'G': {}, 'K': {}, 'N': {}, 'D': {}, 'H': {}, 'J': {}, 'M': {}, 'F': {}, 'O': {}, 'I': {}, 'C': {}, 'E': {}, 'L': {}}
# is 'NEXT' in [':Remark', ':Dim', ':Def', ':Read', ':Goto', ':Return', ':For', ':Data', ':Gosub', ':Print', ':Next', ':Assign', ':If']
# Trying machine :Dim
# NEXT(NEXT) A Dim [] {'A': {'DIM': 'B'}, 'B': {'letter': 'C'}, 'C': {'(': 'D'}, 'D': {':Int': 'E'}, 'E': {')': 'H', ',': 'G'}, 'H': {',': 'J'}, 'G': {':Int': 'F'}, 'J': {'letter': 'K'}, 'F': {')': 'H', ',': 'G'}, 'K': {'(': 'L'}, 'L': {':Int': 'M'}, 'M': {')': 'I', ',': 'O'}, 'I': {',': 'J'}, 'O': {':Int': 'N'}, 'N': {')': 'I', ',': 'O'}}
# is 'NEXT' in ['DIM']
# Backtracking...
# NEXT(NEXT) B BStatement [':Def', ':Read', ':Goto', ':Return', ':For', ':Data', ':Gosub', ':Print', ':Next', ':Assign', ':If'] {'A': {':Int': 'B'}, 'B': {':Remark': 'K', ':Dim': 'G', ':Def': 'H', ':Read': 'L', ':Goto': 'O', ':Return': 'J', ':For': 'E', ':Data': 'M', ':Gosub': 'I', ':Print': 'N', ':Next': 'F', ':Assign': 'C', ':If': 'D'}, 'G': {}, 'K': {}, 'N': {}, 'D': {}, 'H': {}, 'J': {}, 'M': {}, 'F': {}, 'O': {}, 'I': {}, 'C': {}, 'E': {}, 'L': {}}
# is 'NEXT' in [':Remark', ':Dim', ':Def', ':Read', ':Goto', ':Return', ':For', ':Data', ':Gosub', ':Print', ':Next', ':Assign', ':If']
# Trying machine :Def
# NEXT(NEXT) A Def [] {'A': {'DEF FN': 'B'}, 'B': {'letter': 'C'}, 'C': {'(': 'D'}, 'D': {'letter': 'E'}, 'E': {')': 'G', 'digit': 'F'}, 'G': {'=': 'H'}, 'F': {')': 'G'}, 'H': {':Exp': 'I'}, 'I': {}}
# is 'NEXT' in ['DEF FN']
# Backtracking...
# NEXT(NEXT) B BStatement [':Read', ':Goto', ':Return', ':For', ':Data', ':Gosub', ':Print', ':Next', ':Assign', ':If'] {'A': {':Int': 'B'}, 'B': {':Remark': 'K', ':Dim': 'G', ':Def': 'H', ':Read': 'L', ':Goto': 'O', ':Return': 'J', ':For': 'E', ':Data': 'M', ':Gosub': 'I', ':Print': 'N', ':Next': 'F', ':Assign': 'C', ':If': 'D'}, 'G': {}, 'K': {}, 'N': {}, 'D': {}, 'H': {}, 'J': {}, 'M': {}, 'F': {}, 'O': {}, 'I': {}, 'C': {}, 'E': {}, 'L': {}}
# is 'NEXT' in [':Remark', ':Dim', ':Def', ':Read', ':Goto', ':Return', ':For', ':Data', ':Gosub', ':Print', ':Next', ':Assign', ':If']
# Trying machine :Read
# NEXT(NEXT) A Read [] {'A': {'READ': 'B'}, 'B': {':Var': 'C'}, 'C': {',': 'E'}, 'E': {':Var': 'D'}, 'D': {',': 'E'}}
# is 'NEXT' in ['READ']
# Backtracking...
# NEXT(NEXT) B BStatement [':Goto', ':Return', ':For', ':Data', ':Gosub', ':Print', ':Next', ':Assign', ':If'] {'A': {':Int': 'B'}, 'B': {':Remark': 'K', ':Dim': 'G', ':Def': 'H', ':Read': 'L', ':Goto': 'O', ':Return': 'J', ':For': 'E', ':Data': 'M', ':Gosub': 'I', ':Print': 'N', ':Next': 'F', ':Assign': 'C', ':If': 'D'}, 'G': {}, 'K': {}, 'N': {}, 'D': {}, 'H': {}, 'J': {}, 'M': {}, 'F': {}, 'O': {}, 'I': {}, 'C': {}, 'E': {}, 'L': {}}
# is 'NEXT' in [':Remark', ':Dim', ':Def', ':Read', ':Goto', ':Return', ':For', ':Data', ':Gosub', ':Print', ':Next', ':Assign', ':If']
# Trying machine :Goto
# NEXT(NEXT) A Goto [] {'A': {'GOTO': 'B', 'GO': 'C'}, 'B': {':Int': 'E'}, 'C': {'TO': 'D'}, 'D': {':Int': 'E'}, 'E': {}}
# is 'NEXT' in ['GOTO', 'GO']
# Backtracking...
# NEXT(NEXT) B BStatement [':Return', ':For', ':Data', ':Gosub', ':Print', ':Next', ':Assign', ':If'] {'A': {':Int': 'B'}, 'B': {':Remark': 'K', ':Dim': 'G', ':Def': 'H', ':Read': 'L', ':Goto': 'O', ':Return': 'J', ':For': 'E', ':Data': 'M', ':Gosub': 'I', ':Print': 'N', ':Next': 'F', ':Assign': 'C', ':If': 'D'}, 'G': {}, 'K': {}, 'N': {}, 'D': {}, 'H': {}, 'J': {}, 'M': {}, 'F': {}, 'O': {}, 'I': {}, 'C': {}, 'E': {}, 'L': {}}
# is 'NEXT' in [':Remark', ':Dim', ':Def', ':Read', ':Goto', ':Return', ':For', ':Data', ':Gosub', ':Print', ':Next', ':Assign', ':If']
# Trying machine :Return
# NEXT(NEXT) A Return [] {'A': {'RETURN': 'B'}, 'B': {}}
# is 'NEXT' in ['RETURN']
# Backtracking...
# NEXT(NEXT) B BStatement [':For', ':Data', ':Gosub', ':Print', ':Next', ':Assign', ':If'] {'A': {':Int': 'B'}, 'B': {':Remark': 'K', ':Dim': 'G', ':Def': 'H', ':Read': 'L', ':Goto': 'O', ':Return': 'J', ':For': 'E', ':Data': 'M', ':Gosub': 'I', ':Print': 'N', ':Next': 'F', ':Assign': 'C', ':If': 'D'}, 'G': {}, 'K': {}, 'N': {}, 'D': {}, 'H': {}, 'J': {}, 'M': {}, 'F': {}, 'O': {}, 'I': {}, 'C': {}, 'E': {}, 'L': {}}
# is 'NEXT' in [':Remark', ':Dim', ':Def', ':Read', ':Goto', ':Return', ':For', ':Data', ':Gosub', ':Print', ':Next', ':Assign', ':If']
# Trying machine :For
# NEXT(NEXT) A For [] {'A': {'FOR': 'B'}, 'B': {'letter': 'C'}, 'C': {'digit': 'D', '=': 'E'}, 'D': {'=': 'E'}, 'E': {':Exp': 'F'}, 'F': {'TO': 'G'}, 'G': {':Exp': 'H'}, 'H': {'STEP': 'I'}, 'I': {':Exp': 'J'}, 'J': {}}
# is 'NEXT' in ['FOR']
# Backtracking...
# NEXT(NEXT) B BStatement [':Data', ':Gosub', ':Print', ':Next', ':Assign', ':If'] {'A': {':Int': 'B'}, 'B': {':Remark': 'K', ':Dim': 'G', ':Def': 'H', ':Read': 'L', ':Goto': 'O', ':Return': 'J', ':For': 'E', ':Data': 'M', ':Gosub': 'I', ':Print': 'N', ':Next': 'F', ':Assign': 'C', ':If': 'D'}, 'G': {}, 'K': {}, 'N': {}, 'D': {}, 'H': {}, 'J': {}, 'M': {}, 'F': {}, 'O': {}, 'I': {}, 'C': {}, 'E': {}, 'L': {}}
# is 'NEXT' in [':Remark', ':Dim', ':Def', ':Read', ':Goto', ':Return', ':For', ':Data', ':Gosub', ':Print', ':Next', ':Assign', ':If']
# Trying machine :Data
# NEXT(NEXT) A Data [] {'A': {'DATA': 'B'}, 'B': {':Snum': 'C'}, 'C': {',': 'E'}, 'E': {':Snum': 'D'}, 'D': {',': 'E'}}
# is 'NEXT' in ['DATA']
# Backtracking...
# NEXT(NEXT) B BStatement [':Gosub', ':Print', ':Next', ':Assign', ':If'] {'A': {':Int': 'B'}, 'B': {':Remark': 'K', ':Dim': 'G', ':Def': 'H', ':Read': 'L', ':Goto': 'O', ':Return': 'J', ':For': 'E', ':Data': 'M', ':Gosub': 'I', ':Print': 'N', ':Next': 'F', ':Assign': 'C', ':If': 'D'}, 'G': {}, 'K': {}, 'N': {}, 'D': {}, 'H': {}, 'J': {}, 'M': {}, 'F': {}, 'O': {}, 'I': {}, 'C': {}, 'E': {}, 'L': {}}
# is 'NEXT' in [':Remark', ':Dim', ':Def', ':Read', ':Goto', ':Return', ':For', ':Data', ':Gosub', ':Print', ':Next', ':Assign', ':If']
# Trying machine :Gosub
# NEXT(NEXT) A Gosub [] {'A': {'GOSUB': 'B'}, 'B': {':Int': 'C'}, 'C': {}}
# is 'NEXT' in ['GOSUB']
# Backtracking...
# NEXT(NEXT) B BStatement [':Print', ':Next', ':Assign', ':If'] {'A': {':Int': 'B'}, 'B': {':Remark': 'K', ':Dim': 'G', ':Def': 'H', ':Read': 'L', ':Goto': 'O', ':Return': 'J', ':For': 'E', ':Data': 'M', ':Gosub': 'I', ':Print': 'N', ':Next': 'F', ':Assign': 'C', ':If': 'D'}, 'G': {}, 'K': {}, 'N': {}, 'D': {}, 'H': {}, 'J': {}, 'M': {}, 'F': {}, 'O': {}, 'I': {}, 'C': {}, 'E': {}, 'L': {}}
# is 'NEXT' in [':Remark', ':Dim', ':Def', ':Read', ':Goto', ':Return', ':For', ':Data', ':Gosub', ':Print', ':Next', ':Assign', ':If']
# Trying machine :Print
# NEXT(NEXT) A Print [] {'A': {'PRINT': 'B'}, 'B': {':Pitem': 'C'}, 'C': {',': 'F'}, 'F': {':Pitem': 'D'}, 'D': {',': 'F'}, 'G': {}, 'E': {}}
# is 'NEXT' in ['PRINT']
# Backtracking...
# NEXT(NEXT) B BStatement [':Next', ':Assign', ':If'] {'A': {':Int': 'B'}, 'B': {':Remark': 'K', ':Dim': 'G', ':Def': 'H', ':Read': 'L', ':Goto': 'O', ':Return': 'J', ':For': 'E', ':Data': 'M', ':Gosub': 'I', ':Print': 'N', ':Next': 'F', ':Assign': 'C', ':If': 'D'}, 'G': {}, 'K': {}, 'N': {}, 'D': {}, 'H': {}, 'J': {}, 'M': {}, 'F': {}, 'O': {}, 'I': {}, 'C': {}, 'E': {}, 'L': {}}
# is 'NEXT' in [':Remark', ':Dim', ':Def', ':Read', ':Goto', ':Return', ':For', ':Data', ':Gosub', ':Print', ':Next', ':Assign', ':If']
# Trying machine :Next
# NEXT(NEXT) A Next [] {'A': {'NEXT': 'B'}, 'B': {'letter': 'C'}, 'C': {'digit': 'D'}, 'D': {}}
# is 'NEXT' in ['NEXT']
# 	Normal transition
# letter(I) B Next [] {'A': {'NEXT': 'B'}, 'B': {'letter': 'C'}, 'C': {'digit': 'D'}, 'D': {}}
# is 'I' in ['letter']
# 	Normal transition

# %%
syntatical.list_events(200)

# %%
[x.parameters for x in syntatical.output.list]
# Out:
# [{'type': 'Int', 'tokens': [{'token': 'digit', 'value': '10'}]},
#  {'type': 'Var', 'tokens': [{'token': 'letter', 'value': 'N'}]},
#  {'type': 'Int', 'tokens': [{'token': 'digit', 'value': '10'}]},
#  {'type': 'Num',
#   'tokens': [{'token': ':Int', 'value': [{'token': 'digit', 'value': '10'}]}]},
#  {'type': 'Eb',
#   'tokens': [{'token': ':Num',
#     'value': [{'token': ':Int',
#       'value': [{'token': 'digit', 'value': '10'}]}]}]},
#  {'type': 'Exp',
#   'tokens': [{'token': ':Eb',
#     'value': [{'token': ':Num',
#       'value': [{'token': ':Int',
#         'value': [{'token': 'digit', 'value': '10'}]}]}]}]},
#  {'type': 'Assign',
#   'tokens': [{'token': 'LET', 'value': 'LET'},
#    {'token': ':Var', 'value': [{'token': 'letter', 'value': 'N'}]},
#    {'token': '=', 'value': '='},
#    {'token': ':Exp',
#     'value': [{'token': ':Eb',
#       'value': [{'token': ':Num',
#         'value': [{'token': ':Int',
#           'value': [{'token': 'digit', 'value': '10'}]}]}]}]}]},
#  {'type': 'BStatement',
#   'tokens': [{'token': ':Int', 'value': [{'token': 'digit', 'value': '10'}]},
#    {'token': ':Assign',
#     'value': [{'token': 'LET', 'value': 'LET'},
#      {'token': ':Var', 'value': [{'token': 'letter', 'value': 'N'}]},
#      {'token': '=', 'value': '='},
#      {'token': ':Exp',
#       'value': [{'token': ':Eb',
#         'value': [{'token': ':Num',
#           'value': [{'token': ':Int',
#             'value': [{'token': 'digit', 'value': '10'}]}]}]}]}]}]},
#  {'type': 'Int', 'tokens': [{'token': 'digit', 'value': '20'}]},
#  {'type': 'Int', 'tokens': [{'token': 'digit', 'value': '53'}]},
#  {'type': 'Num',
#   'tokens': [{'token': ':Int', 'value': [{'token': 'digit', 'value': '53'}]}]},
#  {'type': 'Snum',
#   'tokens': [{'token': ':Num',
#     'value': [{'token': ':Int',
#       'value': [{'token': 'digit', 'value': '53'}]}]}]},
#  {'type': 'Int', 'tokens': [{'token': 'digit', 'value': '77'}]},
#  {'type': 'Num',
#   'tokens': [{'token': ':Int', 'value': [{'token': 'digit', 'value': '77'}]}]},
#  {'type': 'Snum',
#   'tokens': [{'token': ':Num',
#     'value': [{'token': ':Int',
#       'value': [{'token': 'digit', 'value': '77'}]}]}]},
#  {'type': 'Int', 'tokens': [{'token': 'digit', 'value': '82'}]},
#  {'type': 'Num',
#   'tokens': [{'token': ':Int', 'value': [{'token': 'digit', 'value': '82'}]}]},
#  {'type': 'Snum',
#   'tokens': [{'token': ':Num',
#     'value': [{'token': ':Int',
#       'value': [{'token': 'digit', 'value': '82'}]}]}]},
#  {'type': 'Int', 'tokens': [{'token': 'digit', 'value': '12'}]},
#  {'type': 'Num',
#   'tokens': [{'token': ':Int', 'value': [{'token': 'digit', 'value': '12'}]}]},
#  {'type': 'Snum',
#   'tokens': [{'token': ':Num',
#     'value': [{'token': ':Int',
#       'value': [{'token': 'digit', 'value': '12'}]}]}]},
#  {'type': 'Int', 'tokens': [{'token': 'digit', 'value': '38'}]},
#  {'type': 'Num',
#   'tokens': [{'token': ':Int', 'value': [{'token': 'digit', 'value': '38'}]}]},
#  {'type': 'Snum',
#   'tokens': [{'token': ':Num',
#     'value': [{'token': ':Int',
#       'value': [{'token': 'digit', 'value': '38'}]}]}]},
#  {'type': 'Int', 'tokens': [{'token': 'digit', 'value': '90'}]},
#  {'type': 'Num',
#   'tokens': [{'token': ':Int', 'value': [{'token': 'digit', 'value': '90'}]}]},
#  {'type': 'Snum',
#   'tokens': [{'token': ':Num',
#     'value': [{'token': ':Int',
#       'value': [{'token': 'digit', 'value': '90'}]}]}]},
#  {'type': 'Int', 'tokens': [{'token': 'digit', 'value': '16'}]},
#  {'type': 'Num',
#   'tokens': [{'token': ':Int', 'value': [{'token': 'digit', 'value': '16'}]}]},
#  {'type': 'Snum',
#   'tokens': [{'token': ':Num',
#     'value': [{'token': ':Int',
#       'value': [{'token': 'digit', 'value': '16'}]}]}]},
#  {'type': 'Int', 'tokens': [{'token': 'digit', 'value': '72'}]},
#  {'type': 'Num',
#   'tokens': [{'token': ':Int', 'value': [{'token': 'digit', 'value': '72'}]}]},
#  {'type': 'Snum',
#   'tokens': [{'token': ':Num',
#     'value': [{'token': ':Int',
#       'value': [{'token': 'digit', 'value': '72'}]}]}]},
#  {'type': 'Int', 'tokens': [{'token': 'digit', 'value': '55'}]},
#  {'type': 'Num',
#   'tokens': [{'token': ':Int', 'value': [{'token': 'digit', 'value': '55'}]}]},
#  {'type': 'Snum',
#   'tokens': [{'token': ':Num',
#     'value': [{'token': ':Int',
#       'value': [{'token': 'digit', 'value': '55'}]}]}]},
#  {'type': 'Int', 'tokens': [{'token': 'digit', 'value': '62'}]},
#  {'type': 'Num',
#   'tokens': [{'token': ':Int', 'value': [{'token': 'digit', 'value': '62'}]}]},
#  {'type': 'Snum',
#   'tokens': [{'token': ':Num',
#     'value': [{'token': ':Int',
#       'value': [{'token': 'digit', 'value': '62'}]}]}]},
#  {'type': 'Data',
#   'tokens': [{'token': 'DATA', 'value': 'DATA'},
#    {'token': ':Snum',
#     'value': [{'token': ':Num',
#       'value': [{'token': ':Int',
#         'value': [{'token': 'digit', 'value': '53'}]}]}]},
#    {'token': ',', 'value': ','},
#    {'token': ':Snum',
#     'value': [{'token': ':Num',
#       'value': [{'token': ':Int',
#         'value': [{'token': 'digit', 'value': '77'}]}]}]},
#    {'token': ',', 'value': ','},
#    {'token': ':Snum',
#     'value': [{'token': ':Num',
#       'value': [{'token': ':Int',
#         'value': [{'token': 'digit', 'value': '82'}]}]}]},
#    {'token': ',', 'value': ','},
#    {'token': ':Snum',
#     'value': [{'token': ':Num',
#       'value': [{'token': ':Int',
#         'value': [{'token': 'digit', 'value': '12'}]}]}]},
#    {'token': ',', 'value': ','},
#    {'token': ':Snum',
#     'value': [{'token': ':Num',
#       'value': [{'token': ':Int',
#         'value': [{'token': 'digit', 'value': '38'}]}]}]},
#    {'token': ',', 'value': ','},
#    {'token': ':Snum',
#     'value': [{'token': ':Num',
#       'value': [{'token': ':Int',
#         'value': [{'token': 'digit', 'value': '90'}]}]}]},
#    {'token': ',', 'value': ','},
#    {'token': ':Snum',
#     'value': [{'token': ':Num',
#       'value': [{'token': ':Int',
#         'value': [{'token': 'digit', 'value': '16'}]}]}]},
#    {'token': ',', 'value': ','},
#    {'token': ':Snum',
#     'value': [{'token': ':Num',
#       'value': [{'token': ':Int',
#         'value': [{'token': 'digit', 'value': '72'}]}]}]},
#    {'token': ',', 'value': ','},
#    {'token': ':Snum',
#     'value': [{'token': ':Num',
#       'value': [{'token': ':Int',
#         'value': [{'token': 'digit', 'value': '55'}]}]}]},
#    {'token': ',', 'value': ','},
#    {'token': ':Snum',
#     'value': [{'token': ':Num',
#       'value': [{'token': ':Int',
#         'value': [{'token': 'digit', 'value': '62'}]}]}]}]},
#  {'type': 'BStatement',
#   'tokens': [{'token': ':Int', 'value': [{'token': 'digit', 'value': '20'}]},
#    {'token': ':Data',
#     'value': [{'token': 'DATA', 'value': 'DATA'},
#      {'token': ':Snum',
#       'value': [{'token': ':Num',
#         'value': [{'token': ':Int',
#           'value': [{'token': 'digit', 'value': '53'}]}]}]},
#      {'token': ',', 'value': ','},
#      {'token': ':Snum',
#       'value': [{'token': ':Num',
#         'value': [{'token': ':Int',
#           'value': [{'token': 'digit', 'value': '77'}]}]}]},
#      {'token': ',', 'value': ','},
#      {'token': ':Snum',
#       'value': [{'token': ':Num',
#         'value': [{'token': ':Int',
#           'value': [{'token': 'digit', 'value': '82'}]}]}]},
#      {'token': ',', 'value': ','},
#      {'token': ':Snum',
#       'value': [{'token': ':Num',
#         'value': [{'token': ':Int',
#           'value': [{'token': 'digit', 'value': '12'}]}]}]},
#      {'token': ',', 'value': ','},
#      {'token': ':Snum',
#       'value': [{'token': ':Num',
#         'value': [{'token': ':Int',
#           'value': [{'token': 'digit', 'value': '38'}]}]}]},
#      {'token': ',', 'value': ','},
#      {'token': ':Snum',
#       'value': [{'token': ':Num',
#         'value': [{'token': ':Int',
#           'value': [{'token': 'digit', 'value': '90'}]}]}]},
#      {'token': ',', 'value': ','},
#      {'token': ':Snum',
#       'value': [{'token': ':Num',
#         'value': [{'token': ':Int',
#           'value': [{'token': 'digit', 'value': '16'}]}]}]},
#      {'token': ',', 'value': ','},
#      {'token': ':Snum',
#       'value': [{'token': ':Num',
#         'value': [{'token': ':Int',
#           'value': [{'token': 'digit', 'value': '72'}]}]}]},
#      {'token': ',', 'value': ','},
#      {'token': ':Snum',
#       'value': [{'token': ':Num',
#         'value': [{'token': ':Int',
#           'value': [{'token': 'digit', 'value': '55'}]}]}]},
#      {'token': ',', 'value': ','},
#      {'token': ':Snum',
#       'value': [{'token': ':Num',
#         'value': [{'token': ':Int',
#           'value': [{'token': 'digit', 'value': '62'}]}]}]}]}]},
#  {'type': 'Int', 'tokens': [{'token': 'digit', 'value': '30'}]},
#  {'type': 'Int', 'tokens': [{'token': 'digit', 'value': '10'}]},
#  {'type': 'Dim',
#   'tokens': [{'token': 'DIM', 'value': 'DIM'},
#    {'token': 'letter', 'value': 'Z'},
#    {'token': '(', 'value': '('},
#    {'token': ':Int', 'value': [{'token': 'digit', 'value': '10'}]},
#    {'token': ')', 'value': ')'}]},
#  {'type': 'BStatement',
#   'tokens': [{'token': ':Int', 'value': [{'token': 'digit', 'value': '30'}]},
#    {'token': ':Dim',
#     'value': [{'token': 'DIM', 'value': 'DIM'},
#      {'token': 'letter', 'value': 'Z'},
#      {'token': '(', 'value': '('},
#      {'token': ':Int', 'value': [{'token': 'digit', 'value': '10'}]},
#      {'token': ')', 'value': ')'}]}]},
#  {'type': 'Int', 'tokens': [{'token': 'digit', 'value': '35'}]},
#  {'type': 'Int', 'tokens': [{'token': 'digit', 'value': '1000'}]},
#  {'type': 'Dim',
#   'tokens': [{'token': 'DIM', 'value': 'DIM'},
#    {'token': 'letter', 'value': 'S'},
#    {'token': '(', 'value': '('},
#    {'token': ':Int', 'value': [{'token': 'digit', 'value': '1000'}]},
#    {'token': ')', 'value': ')'}]},
#  {'type': 'BStatement',
#   'tokens': [{'token': ':Int', 'value': [{'token': 'digit', 'value': '35'}]},
#    {'token': ':Dim',
#     'value': [{'token': 'DIM', 'value': 'DIM'},
#      {'token': 'letter', 'value': 'S'},
#      {'token': '(', 'value': '('},
#      {'token': ':Int', 'value': [{'token': 'digit', 'value': '1000'}]},
#      {'token': ')', 'value': ')'}]}]},
#  {'type': 'Int', 'tokens': [{'token': 'digit', 'value': '36'}]},
#  {'type': 'Var', 'tokens': [{'token': 'letter', 'value': 'P'}]},
#  {'type': 'Int', 'tokens': [{'token': 'digit', 'value': '1'}]},
#  {'type': 'Num',
#   'tokens': [{'token': ':Int', 'value': [{'token': 'digit', 'value': '1'}]}]},
#  {'type': 'Eb',
#   'tokens': [{'token': ':Num',
#     'value': [{'token': ':Int',
#       'value': [{'token': 'digit', 'value': '1'}]}]}]},
#  {'type': 'Exp',
#   'tokens': [{'token': ':Eb',
#     'value': [{'token': ':Num',
#       'value': [{'token': ':Int',
#         'value': [{'token': 'digit', 'value': '1'}]}]}]}]},
#  {'type': 'Assign',
#   'tokens': [{'token': 'LET', 'value': 'LET'},
#    {'token': ':Var', 'value': [{'token': 'letter', 'value': 'P'}]},
#    {'token': '=', 'value': '='},
#    {'token': ':Exp',
#     'value': [{'token': ':Eb',
#       'value': [{'token': ':Num',
#         'value': [{'token': ':Int',
#           'value': [{'token': 'digit', 'value': '1'}]}]}]}]}]},
#  {'type': 'BStatement',
#   'tokens': [{'token': ':Int', 'value': [{'token': 'digit', 'value': '36'}]},
#    {'token': ':Assign',
#     'value': [{'token': 'LET', 'value': 'LET'},
#      {'token': ':Var', 'value': [{'token': 'letter', 'value': 'P'}]},
#      {'token': '=', 'value': '='},
#      {'token': ':Exp',
#       'value': [{'token': ':Eb',
#         'value': [{'token': ':Num',
#           'value': [{'token': ':Int',
#             'value': [{'token': 'digit', 'value': '1'}]}]}]}]}]}]},
#  {'type': 'Int', 'tokens': [{'token': 'digit', 'value': '40'}]},
#  {'type': 'Int', 'tokens': [{'token': 'digit', 'value': '1'}]},
#  {'type': 'Num',
#   'tokens': [{'token': ':Int', 'value': [{'token': 'digit', 'value': '1'}]}]},
#  {'type': 'Eb',
#   'tokens': [{'token': ':Num',
#     'value': [{'token': ':Int',
#       'value': [{'token': 'digit', 'value': '1'}]}]}]},
#  {'type': 'Exp',
#   'tokens': [{'token': ':Eb',
#     'value': [{'token': ':Num',
#       'value': [{'token': ':Int',
#         'value': [{'token': 'digit', 'value': '1'}]}]}]}]},
#  {'type': 'Var', 'tokens': [{'token': 'letter', 'value': 'N'}]},
#  {'type': 'Eb',
#   'tokens': [{'token': ':Var', 'value': [{'token': 'letter', 'value': 'N'}]}]},
#  {'type': 'Exp',
#   'tokens': [{'token': ':Eb',
#     'value': [{'token': ':Var',
#       'value': [{'token': 'letter', 'value': 'N'}]}]}]},
#  {'type': 'For',
#   'tokens': [{'token': 'FOR', 'value': 'FOR'},
#    {'token': 'letter', 'value': 'I'},
#    {'token': '=', 'value': '='},
#    {'token': ':Exp',
#     'value': [{'token': ':Eb',
#       'value': [{'token': ':Num',
#         'value': [{'token': ':Int',
#           'value': [{'token': 'digit', 'value': '1'}]}]}]}]},
#    {'token': 'TO', 'value': 'TO'},
#    {'token': ':Exp',
#     'value': [{'token': ':Eb',
#       'value': [{'token': ':Var',
#         'value': [{'token': 'letter', 'value': 'N'}]}]}]}]},
#  {'type': 'BStatement',
#   'tokens': [{'token': ':Int', 'value': [{'token': 'digit', 'value': '40'}]},
#    {'token': ':For',
#     'value': [{'token': 'FOR', 'value': 'FOR'},
#      {'token': 'letter', 'value': 'I'},
#      {'token': '=', 'value': '='},
#      {'token': ':Exp',
#       'value': [{'token': ':Eb',
#         'value': [{'token': ':Num',
#           'value': [{'token': ':Int',
#             'value': [{'token': 'digit', 'value': '1'}]}]}]}]},
#      {'token': 'TO', 'value': 'TO'},
#      {'token': ':Exp',
#       'value': [{'token': ':Eb',
#         'value': [{'token': ':Var',
#           'value': [{'token': 'letter', 'value': 'N'}]}]}]}]}]},
#  {'type': 'Int', 'tokens': [{'token': 'digit', 'value': '50'}]},
#  {'type': 'Var', 'tokens': [{'token': 'letter', 'value': 'I'}]},
#  {'type': 'Eb',
#   'tokens': [{'token': ':Var', 'value': [{'token': 'letter', 'value': 'I'}]}]},
#  {'type': 'Exp',
#   'tokens': [{'token': ':Eb',
#     'value': [{'token': ':Var',
#       'value': [{'token': 'letter', 'value': 'I'}]}]}]},
#  {'type': 'Var',
#   'tokens': [{'token': 'letter', 'value': 'Z'},
#    {'token': '(', 'value': '('},
#    {'token': ':Exp',
#     'value': [{'token': ':Eb',
#       'value': [{'token': ':Var',
#         'value': [{'token': 'letter', 'value': 'I'}]}]}]},
#    {'token': ')', 'value': ')'}]},
#  {'type': 'Read',
#   'tokens': [{'token': 'READ', 'value': 'READ'},
#    {'token': ':Var',
#     'value': [{'token': 'letter', 'value': 'Z'},
#      {'token': '(', 'value': '('},
#      {'token': ':Exp',
#       'value': [{'token': ':Eb',
#         'value': [{'token': ':Var',
#           'value': [{'token': 'letter', 'value': 'I'}]}]}]},
#      {'token': ')', 'value': ')'}]}]},
#  {'type': 'BStatement',
#   'tokens': [{'token': ':Int', 'value': [{'token': 'digit', 'value': '50'}]},
#    {'token': ':Read',
#     'value': [{'token': 'READ', 'value': 'READ'},
#      {'token': ':Var',
#       'value': [{'token': 'letter', 'value': 'Z'},
#        {'token': '(', 'value': '('},
#        {'token': ':Exp',
#         'value': [{'token': ':Eb',
#           'value': [{'token': ':Var',
#             'value': [{'token': 'letter', 'value': 'I'}]}]}]},
#        {'token': ')', 'value': ')'}]}]}]},
#  {'type': 'Int', 'tokens': [{'token': 'digit', 'value': '60'}]},
#  {'type': 'Next',
#   'tokens': [{'token': 'NEXT', 'value': 'NEXT'},
#    {'token': 'letter', 'value': 'I'}]},
#  {'type': 'BStatement',
#   'tokens': [{'token': ':Int', 'value': [{'token': 'digit', 'value': '60'}]},
#    {'token': ':Next',
#     'value': [{'token': 'NEXT', 'value': 'NEXT'},
#      {'token': 'letter', 'value': 'I'}]}]},
#  {'type': 'Int', 'tokens': [{'token': 'digit', 'value': '1000'}]},
#  {'type': 'Int', 'tokens': [{'token': 'digit', 'value': '1'}]},
#  {'type': 'Num',
#   'tokens': [{'token': ':Int', 'value': [{'token': 'digit', 'value': '1'}]}]},
#  {'type': 'Eb',
#   'tokens': [{'token': ':Num',
#     'value': [{'token': ':Int',
#       'value': [{'token': 'digit', 'value': '1'}]}]}]},
#  {'type': 'Exp',
#   'tokens': [{'token': ':Eb',
#     'value': [{'token': ':Num',
#       'value': [{'token': ':Int',
#         'value': [{'token': 'digit', 'value': '1'}]}]}]}]},
#  {'type': 'Var', 'tokens': [{'token': 'letter', 'value': 'N'}]},
#  {'type': 'Eb',
#   'tokens': [{'token': ':Var', 'value': [{'token': 'letter', 'value': 'N'}]}]},
#  {'type': 'Exp',
#   'tokens': [{'token': ':Eb',
#     'value': [{'token': ':Var',
#       'value': [{'token': 'letter', 'value': 'N'}]}]}]},
#  {'type': 'For',
#   'tokens': [{'token': 'FOR', 'value': 'FOR'},
#    {'token': 'letter', 'value': 'I'},
#    {'token': '=', 'value': '='},
#    {'token': ':Exp',
#     'value': [{'token': ':Eb',
#       'value': [{'token': ':Num',
#         'value': [{'token': ':Int',
#           'value': [{'token': 'digit', 'value': '1'}]}]}]}]},
#    {'token': 'TO', 'value': 'TO'},
#    {'token': ':Exp',
#     'value': [{'token': ':Eb',
#       'value': [{'token': ':Var',
#         'value': [{'token': 'letter', 'value': 'N'}]}]}]}]},
#  {'type': 'BStatement',
#   'tokens': [{'token': ':Int', 'value': [{'token': 'digit', 'value': '1000'}]},
#    {'token': ':For',
#     'value': [{'token': 'FOR', 'value': 'FOR'},
#      {'token': 'letter', 'value': 'I'},
#      {'token': '=', 'value': '='},
#      {'token': ':Exp',
#       'value': [{'token': ':Eb',
#         'value': [{'token': ':Num',
#           'value': [{'token': ':Int',
#             'value': [{'token': 'digit', 'value': '1'}]}]}]}]},
#      {'token': 'TO', 'value': 'TO'},
#      {'token': ':Exp',
#       'value': [{'token': ':Eb',
#         'value': [{'token': ':Var',
#           'value': [{'token': 'letter', 'value': 'N'}]}]}]}]}]},
#  {'type': 'Int', 'tokens': [{'token': 'digit', 'value': '1500'}]},
#  {'type': 'Var', 'tokens': [{'token': 'letter', 'value': 'I'}]},
#  {'type': 'Eb',
#   'tokens': [{'token': ':Var', 'value': [{'token': 'letter', 'value': 'I'}]}]},
#  {'type': 'Exp',
#   'tokens': [{'token': ':Eb',
#     'value': [{'token': ':Var',
#       'value': [{'token': 'letter', 'value': 'I'}]}]}]},
#  {'type': 'Var', 'tokens': [{'token': 'letter', 'value': 'N'}]},
#  {'type': 'Eb',
#   'tokens': [{'token': ':Var', 'value': [{'token': 'letter', 'value': 'N'}]}]},
#  {'type': 'Exp',
#   'tokens': [{'token': ':Eb',
#     'value': [{'token': ':Var',
#       'value': [{'token': 'letter', 'value': 'N'}]}]}]},
#  {'type': 'For',
#   'tokens': [{'token': 'FOR', 'value': 'FOR'},
#    {'token': 'letter', 'value': 'J'},
#    {'token': '=', 'value': '='},
#    {'token': ':Exp',
#     'value': [{'token': ':Eb',
#       'value': [{'token': ':Var',
#         'value': [{'token': 'letter', 'value': 'I'}]}]}]},
#    {'token': 'TO', 'value': 'TO'},
#    {'token': ':Exp',
#     'value': [{'token': ':Eb',
#       'value': [{'token': ':Var',
#         'value': [{'token': 'letter', 'value': 'N'}]}]}]}]},
#  {'type': 'BStatement',
#   'tokens': [{'token': ':Int', 'value': [{'token': 'digit', 'value': '1500'}]},
#    {'token': ':For',
#     'value': [{'token': 'FOR', 'value': 'FOR'},
#      {'token': 'letter', 'value': 'J'},
#      {'token': '=', 'value': '='},
#      {'token': ':Exp',
#       'value': [{'token': ':Eb',
#         'value': [{'token': ':Var',
#           'value': [{'token': 'letter', 'value': 'I'}]}]}]},
#      {'token': 'TO', 'value': 'TO'},
#      {'token': ':Exp',
#       'value': [{'token': ':Eb',
#         'value': [{'token': ':Var',
#           'value': [{'token': 'letter', 'value': 'N'}]}]}]}]}]},
#  {'type': 'Int', 'tokens': [{'token': 'digit', 'value': '1510'}]},
#  {'type': 'Var', 'tokens': [{'token': 'letter', 'value': 'I'}]},
#  {'type': 'Eb',
#   'tokens': [{'token': ':Var', 'value': [{'token': 'letter', 'value': 'I'}]}]},
#  {'type': 'Exp',
#   'tokens': [{'token': ':Eb',
#     'value': [{'token': ':Var',
#       'value': [{'token': 'letter', 'value': 'I'}]}]}]},
#  {'type': 'Var',
#   'tokens': [{'token': 'letter', 'value': 'Z'},
#    {'token': '(', 'value': '('},
#    {'token': ':Exp',
#     'value': [{'token': ':Eb',
#       'value': [{'token': ':Var',
#         'value': [{'token': 'letter', 'value': 'I'}]}]}]},
#    {'token': ')', 'value': ')'}]},
#  {'type': 'Eb',
#   'tokens': [{'token': ':Var',
#     'value': [{'token': 'letter', 'value': 'Z'},
#      {'token': '(', 'value': '('},
#      {'token': ':Exp',
#       'value': [{'token': ':Eb',
#         'value': [{'token': ':Var',
#           'value': [{'token': 'letter', 'value': 'I'}]}]}]},
#      {'token': ')', 'value': ')'}]}]},
#  {'type': 'Exp',
#   'tokens': [{'token': ':Eb',
#     'value': [{'token': ':Var',
#       'value': [{'token': 'letter', 'value': 'Z'},
#        {'token': '(', 'value': '('},
#        {'token': ':Exp',
#         'value': [{'token': ':Eb',
#           'value': [{'token': ':Var',
#             'value': [{'token': 'letter', 'value': 'I'}]}]}]},
#        {'token': ')', 'value': ')'}]}]}]},
#  {'type': 'Var', 'tokens': [{'token': 'letter', 'value': 'J'}]},
#  {'type': 'Eb',
#   'tokens': [{'token': ':Var', 'value': [{'token': 'letter', 'value': 'J'}]}]},
#  {'type': 'Exp',
#   'tokens': [{'token': ':Eb',
#     'value': [{'token': ':Var',
#       'value': [{'token': 'letter', 'value': 'J'}]}]}]},
#  {'type': 'Var',
#   'tokens': [{'token': 'letter', 'value': 'Z'},
#    {'token': '(', 'value': '('},
#    {'token': ':Exp',
#     'value': [{'token': ':Eb',
#       'value': [{'token': ':Var',
#         'value': [{'token': 'letter', 'value': 'J'}]}]}]},
#    {'token': ')', 'value': ')'}]},
#  {'type': 'Eb',
#   'tokens': [{'token': ':Var',
#     'value': [{'token': 'letter', 'value': 'Z'},
#      {'token': '(', 'value': '('},
#      {'token': ':Exp',
#       'value': [{'token': ':Eb',
#         'value': [{'token': ':Var',
#           'value': [{'token': 'letter', 'value': 'J'}]}]}]},
#      {'token': ')', 'value': ')'}]}]},
#  {'type': 'Exp',
#   'tokens': [{'token': ':Eb',
#     'value': [{'token': ':Var',
#       'value': [{'token': 'letter', 'value': 'Z'},
#        {'token': '(', 'value': '('},
#        {'token': ':Exp',
#         'value': [{'token': ':Eb',
#           'value': [{'token': ':Var',
#             'value': [{'token': 'letter', 'value': 'J'}]}]}]},
#        {'token': ')', 'value': ')'}]}]}]},
#  {'type': 'Int', 'tokens': [{'token': 'digit', 'value': '1800'}]},
#  {'type': 'If',
#   'tokens': [{'token': 'IF', 'value': 'IF'},
#    {'token': ':Exp',
#     'value': [{'token': ':Eb',
#       'value': [{'token': ':Var',
#         'value': [{'token': 'letter', 'value': 'Z'},
#          {'token': '(', 'value': '('},
#          {'token': ':Exp',
#           'value': [{'token': ':Eb',
#             'value': [{'token': ':Var',
#               'value': [{'token': 'letter', 'value': 'I'}]}]}]},
#          {'token': ')', 'value': ')'}]}]}]},
#    {'token': '<=', 'value': '<='},
#    {'token': ':Exp',
#     'value': [{'token': ':Eb',
#       'value': [{'token': ':Var',
#         'value': [{'token': 'letter', 'value': 'Z'},
#          {'token': '(', 'value': '('},
#          {'token': ':Exp',
#           'value': [{'token': ':Eb',
#             'value': [{'token': ':Var',
#               'value': [{'token': 'letter', 'value': 'J'}]}]}]},
#          {'token': ')', 'value': ')'}]}]}]},
#    {'token': 'THEN', 'value': 'THEN'},
#    {'token': ':Int', 'value': [{'token': 'digit', 'value': '1800'}]}]},
#  {'type': 'BStatement',
#   'tokens': [{'token': ':Int', 'value': [{'token': 'digit', 'value': '1510'}]},
#    {'token': ':If',
#     'value': [{'token': 'IF', 'value': 'IF'},
#      {'token': ':Exp',
#       'value': [{'token': ':Eb',
#         'value': [{'token': ':Var',
#           'value': [{'token': 'letter', 'value': 'Z'},
#            {'token': '(', 'value': '('},
#            {'token': ':Exp',
#             'value': [{'token': ':Eb',
#               'value': [{'token': ':Var',
#                 'value': [{'token': 'letter', 'value': 'I'}]}]}]},
#            {'token': ')', 'value': ')'}]}]}]},
#      {'token': '<=', 'value': '<='},
#      {'token': ':Exp',
#       'value': [{'token': ':Eb',
#         'value': [{'token': ':Var',
#           'value': [{'token': 'letter', 'value': 'Z'},
#            {'token': '(', 'value': '('},
#            {'token': ':Exp',
#             'value': [{'token': ':Eb',
#               'value': [{'token': ':Var',
#                 'value': [{'token': 'letter', 'value': 'J'}]}]}]},
#            {'token': ')', 'value': ')'}]}]}]},
#      {'token': 'THEN', 'value': 'THEN'},
#      {'token': ':Int', 'value': [{'token': 'digit', 'value': '1800'}]}]}]},
#  {'type': 'Int', 'tokens': [{'token': 'digit', 'value': '1520'}]},
#  {'type': 'Var', 'tokens': [{'token': 'letter', 'value': 'T'}]},
#  {'type': 'Var', 'tokens': [{'token': 'letter', 'value': 'J'}]},
#  {'type': 'Eb',
#   'tokens': [{'token': ':Var', 'value': [{'token': 'letter', 'value': 'J'}]}]},
#  {'type': 'Exp',
#   'tokens': [{'token': ':Eb',
#     'value': [{'token': ':Var',
#       'value': [{'token': 'letter', 'value': 'J'}]}]}]},
#  {'type': 'Var',
#   'tokens': [{'token': 'letter', 'value': 'Z'},
#    {'token': '(', 'value': '('},
#    {'token': ':Exp',
#     'value': [{'token': ':Eb',
#       'value': [{'token': ':Var',
#         'value': [{'token': 'letter', 'value': 'J'}]}]}]},
#    {'token': ')', 'value': ')'}]},
#  {'type': 'Eb',
#   'tokens': [{'token': ':Var',
#     'value': [{'token': 'letter', 'value': 'Z'},
#      {'token': '(', 'value': '('},
#      {'token': ':Exp',
#       'value': [{'token': ':Eb',
#         'value': [{'token': ':Var',
#           'value': [{'token': 'letter', 'value': 'J'}]}]}]},
#      {'token': ')', 'value': ')'}]}]},
#  {'type': 'Exp',
#   'tokens': [{'token': ':Eb',
#     'value': [{'token': ':Var',
#       'value': [{'token': 'letter', 'value': 'Z'},
#        {'token': '(', 'value': '('},
#        {'token': ':Exp',
#         'value': [{'token': ':Eb',
#           'value': [{'token': ':Var',
#             'value': [{'token': 'letter', 'value': 'J'}]}]}]},
#        {'token': ')', 'value': ')'}]}]}]},
#  {'type': 'Assign',
#   'tokens': [{'token': 'LET', 'value': 'LET'},
#    {'token': ':Var', 'value': [{'token': 'letter', 'value': 'T'}]},
#    {'token': '=', 'value': '='},
#    {'token': ':Exp',
#     'value': [{'token': ':Eb',
#       'value': [{'token': ':Var',
#         'value': [{'token': 'letter', 'value': 'Z'},
#          {'token': '(', 'value': '('},
#          {'token': ':Exp',
#           'value': [{'token': ':Eb',
#             'value': [{'token': ':Var',
#               'value': [{'token': 'letter', 'value': 'J'}]}]}]},
#          {'token': ')', 'value': ')'}]}]}]}]},
#  {'type': 'BStatement',
#   'tokens': [{'token': ':Int', 'value': [{'token': 'digit', 'value': '1520'}]},
#    {'token': ':Assign',
#     'value': [{'token': 'LET', 'value': 'LET'},
#      {'token': ':Var', 'value': [{'token': 'letter', 'value': 'T'}]},
#      {'token': '=', 'value': '='},
#      {'token': ':Exp',
#       'value': [{'token': ':Eb',
#         'value': [{'token': ':Var',
#           'value': [{'token': 'letter', 'value': 'Z'},
#            {'token': '(', 'value': '('},
#            {'token': ':Exp',
#             'value': [{'token': ':Eb',
#               'value': [{'token': ':Var',
#                 'value': [{'token': 'letter', 'value': 'J'}]}]}]},
#            {'token': ')', 'value': ')'}]}]}]}]}]},
#  {'type': 'Int', 'tokens': [{'token': 'digit', 'value': '1530'}]},
#  {'type': 'Var', 'tokens': [{'token': 'letter', 'value': 'J'}]},
#  {'type': 'Eb',
#   'tokens': [{'token': ':Var', 'value': [{'token': 'letter', 'value': 'J'}]}]},
#  {'type': 'Exp',
#   'tokens': [{'token': ':Eb',
#     'value': [{'token': ':Var',
#       'value': [{'token': 'letter', 'value': 'J'}]}]}]},
#  {'type': 'Var',
#   'tokens': [{'token': 'letter', 'value': 'Z'},
#    {'token': '(', 'value': '('},
#    {'token': ':Exp',
#     'value': [{'token': ':Eb',
#       'value': [{'token': ':Var',
#         'value': [{'token': 'letter', 'value': 'J'}]}]}]},
#    {'token': ')', 'value': ')'}]},
#  {'type': 'Var', 'tokens': [{'token': 'letter', 'value': 'I'}]},
#  {'type': 'Eb',
#   'tokens': [{'token': ':Var', 'value': [{'token': 'letter', 'value': 'I'}]}]},
#  {'type': 'Exp',
#   'tokens': [{'token': ':Eb',
#     'value': [{'token': ':Var',
#       'value': [{'token': 'letter', 'value': 'I'}]}]}]},
#  {'type': 'Var',
#   'tokens': [{'token': 'letter', 'value': 'Z'},
#    {'token': '(', 'value': '('},
#    {'token': ':Exp',
#     'value': [{'token': ':Eb',
#       'value': [{'token': ':Var',
#         'value': [{'token': 'letter', 'value': 'I'}]}]}]},
#    {'token': ')', 'value': ')'}]},
#  {'type': 'Eb',
#   'tokens': [{'token': ':Var',
#     'value': [{'token': 'letter', 'value': 'Z'},
#      {'token': '(', 'value': '('},
#      {'token': ':Exp',
#       'value': [{'token': ':Eb',
#         'value': [{'token': ':Var',
#           'value': [{'token': 'letter', 'value': 'I'}]}]}]},
#      {'token': ')', 'value': ')'}]}]},
#  {'type': 'Exp',
#   'tokens': [{'token': ':Eb',
#     'value': [{'token': ':Var',
#       'value': [{'token': 'letter', 'value': 'Z'},
#        {'token': '(', 'value': '('},
#        {'token': ':Exp',
#         'value': [{'token': ':Eb',
#           'value': [{'token': ':Var',
#             'value': [{'token': 'letter', 'value': 'I'}]}]}]},
#        {'token': ')', 'value': ')'}]}]}]},
#  {'type': 'Assign',
#   'tokens': [{'token': 'LET', 'value': 'LET'},
#    {'token': ':Var',
#     'value': [{'token': 'letter', 'value': 'Z'},
#      {'token': '(', 'value': '('},
#      {'token': ':Exp',
#       'value': [{'token': ':Eb',
#         'value': [{'token': ':Var',
#           'value': [{'token': 'letter', 'value': 'J'}]}]}]},
#      {'token': ')', 'value': ')'}]},
#    {'token': '=', 'value': '='},
#    {'token': ':Exp',
#     'value': [{'token': ':Eb',
#       'value': [{'token': ':Var',
#         'value': [{'token': 'letter', 'value': 'Z'},
#          {'token': '(', 'value': '('},
#          {'token': ':Exp',
#           'value': [{'token': ':Eb',
#             'value': [{'token': ':Var',
#               'value': [{'token': 'letter', 'value': 'I'}]}]}]},
#          {'token': ')', 'value': ')'}]}]}]}]},
#  {'type': 'BStatement',
#   'tokens': [{'token': ':Int', 'value': [{'token': 'digit', 'value': '1530'}]},
#    {'token': ':Assign',
#     'value': [{'token': 'LET', 'value': 'LET'},
#      {'token': ':Var',
#       'value': [{'token': 'letter', 'value': 'Z'},
#        {'token': '(', 'value': '('},
#        {'token': ':Exp',
#         'value': [{'token': ':Eb',
#           'value': [{'token': ':Var',
#             'value': [{'token': 'letter', 'value': 'J'}]}]}]},
#        {'token': ')', 'value': ')'}]},
#      {'token': '=', 'value': '='},
#      {'token': ':Exp',
#       'value': [{'token': ':Eb',
#         'value': [{'token': ':Var',
#           'value': [{'token': 'letter', 'value': 'Z'},
#            {'token': '(', 'value': '('},
#            {'token': ':Exp',
#             'value': [{'token': ':Eb',
#               'value': [{'token': ':Var',
#                 'value': [{'token': 'letter', 'value': 'I'}]}]}]},
#            {'token': ')', 'value': ')'}]}]}]}]}]},
#  {'type': 'Int', 'tokens': [{'token': 'digit', 'value': '1540'}]},
#  {'type': 'Var', 'tokens': [{'token': 'letter', 'value': 'I'}]},
#  {'type': 'Eb',
#   'tokens': [{'token': ':Var', 'value': [{'token': 'letter', 'value': 'I'}]}]},
#  {'type': 'Exp',
#   'tokens': [{'token': ':Eb',
#     'value': [{'token': ':Var',
#       'value': [{'token': 'letter', 'value': 'I'}]}]}]},
#  {'type': 'Var',
#   'tokens': [{'token': 'letter', 'value': 'Z'},
#    {'token': '(', 'value': '('},
#    {'token': ':Exp',
#     'value': [{'token': ':Eb',
#       'value': [{'token': ':Var',
#         'value': [{'token': 'letter', 'value': 'I'}]}]}]},
#    {'token': ')', 'value': ')'}]},
#  {'type': 'Var', 'tokens': [{'token': 'letter', 'value': 'T'}]},
#  {'type': 'Eb',
#   'tokens': [{'token': ':Var', 'value': [{'token': 'letter', 'value': 'T'}]}]},
#  {'type': 'Exp',
#   'tokens': [{'token': ':Eb',
#     'value': [{'token': ':Var',
#       'value': [{'token': 'letter', 'value': 'T'}]}]}]},
#  {'type': 'Assign',
#   'tokens': [{'token': 'LET', 'value': 'LET'},
#    {'token': ':Var',
#     'value': [{'token': 'letter', 'value': 'Z'},
#      {'token': '(', 'value': '('},
#      {'token': ':Exp',
#       'value': [{'token': ':Eb',
#         'value': [{'token': ':Var',
#           'value': [{'token': 'letter', 'value': 'I'}]}]}]},
#      {'token': ')', 'value': ')'}]},
#    {'token': '=', 'value': '='},
#    {'token': ':Exp',
#     'value': [{'token': ':Eb',
#       'value': [{'token': ':Var',
#         'value': [{'token': 'letter', 'value': 'T'}]}]}]}]},
#  {'type': 'BStatement',
#   'tokens': [{'token': ':Int', 'value': [{'token': 'digit', 'value': '1540'}]},
#    {'token': ':Assign',
#     'value': [{'token': 'LET', 'value': 'LET'},
#      {'token': ':Var',
#       'value': [{'token': 'letter', 'value': 'Z'},
#        {'token': '(', 'value': '('},
#        {'token': ':Exp',
#         'value': [{'token': ':Eb',
#           'value': [{'token': ':Var',
#             'value': [{'token': 'letter', 'value': 'I'}]}]}]},
#        {'token': ')', 'value': ')'}]},
#      {'token': '=', 'value': '='},
#      {'token': ':Exp',
#       'value': [{'token': ':Eb',
#         'value': [{'token': ':Var',
#           'value': [{'token': 'letter', 'value': 'T'}]}]}]}]}]},
#  {'type': 'Int', 'tokens': [{'token': 'digit', 'value': '1800'}]},
#  {'type': 'Next',
#   'tokens': [{'token': 'NEXT', 'value': 'NEXT'},
#    {'token': 'letter', 'value': 'J'}]},
#  {'type': 'BStatement',
#   'tokens': [{'token': ':Int', 'value': [{'token': 'digit', 'value': '1800'}]},
#    {'token': ':Next',
#     'value': [{'token': 'NEXT', 'value': 'NEXT'},
#      {'token': 'letter', 'value': 'J'}]}]},
#  {'type': 'Int', 'tokens': [{'token': 'digit', 'value': '1810'}]},
#  {'type': 'Next',
#   'tokens': [{'token': 'NEXT', 'value': 'NEXT'},
#    {'token': 'letter', 'value': 'I'}]},
#  {'type': 'BStatement',
#   'tokens': [{'token': ':Int', 'value': [{'token': 'digit', 'value': '1810'}]},
#    {'token': ':Next',
#     'value': [{'token': 'NEXT', 'value': 'NEXT'},
#      {'token': 'letter', 'value': 'I'}]}]},
#  {'type': 'Int', 'tokens': [{'token': 'digit', 'value': '9000'}]},
#  {'type': 'Int', 'tokens': [{'token': 'digit', 'value': '1'}]},
#  {'type': 'Num',
#   'tokens': [{'token': ':Int', 'value': [{'token': 'digit', 'value': '1'}]}]},
#  {'type': 'Eb',
#   'tokens': [{'token': ':Num',
#     'value': [{'token': ':Int',
#       'value': [{'token': 'digit', 'value': '1'}]}]}]},
#  {'type': 'Exp',
#   'tokens': [{'token': ':Eb',
#     'value': [{'token': ':Num',
#       'value': [{'token': ':Int',
#         'value': [{'token': 'digit', 'value': '1'}]}]}]}]},
#  {'type': 'Int', 'tokens': [{'token': 'digit', 'value': '10'}]},
#  {'type': 'Num',
#   'tokens': [{'token': ':Int', 'value': [{'token': 'digit', 'value': '10'}]}]},
#  {'type': 'Eb',
#   'tokens': [{'token': ':Num',
#     'value': [{'token': ':Int',
#       'value': [{'token': 'digit', 'value': '10'}]}]}]},
#  {'type': 'Exp',
#   'tokens': [{'token': ':Eb',
#     'value': [{'token': ':Num',
#       'value': [{'token': ':Int',
#         'value': [{'token': 'digit', 'value': '10'}]}]}]}]},
#  {'type': 'For',
#   'tokens': [{'token': 'FOR', 'value': 'FOR'},
#    {'token': 'letter', 'value': 'I'},
#    {'token': '=', 'value': '='},
#    {'token': ':Exp',
#     'value': [{'token': ':Eb',
#       'value': [{'token': ':Num',
#         'value': [{'token': ':Int',
#           'value': [{'token': 'digit', 'value': '1'}]}]}]}]},
#    {'token': 'TO', 'value': 'TO'},
#    {'token': ':Exp',
#     'value': [{'token': ':Eb',
#       'value': [{'token': ':Num',
#         'value': [{'token': ':Int',
#           'value': [{'token': 'digit', 'value': '10'}]}]}]}]}]},
#  {'type': 'BStatement',
#   'tokens': [{'token': ':Int', 'value': [{'token': 'digit', 'value': '9000'}]},
#    {'token': ':For',
#     'value': [{'token': 'FOR', 'value': 'FOR'},
#      {'token': 'letter', 'value': 'I'},
#      {'token': '=', 'value': '='},
#      {'token': ':Exp',
#       'value': [{'token': ':Eb',
#         'value': [{'token': ':Num',
#           'value': [{'token': ':Int',
#             'value': [{'token': 'digit', 'value': '1'}]}]}]}]},
#      {'token': 'TO', 'value': 'TO'},
#      {'token': ':Exp',
#       'value': [{'token': ':Eb',
#         'value': [{'token': ':Num',
#           'value': [{'token': ':Int',
#             'value': [{'token': 'digit', 'value': '10'}]}]}]}]}]}]},
#  {'type': 'Int', 'tokens': [{'token': 'digit', 'value': '9000'}]},
#  {'type': 'Var', 'tokens': [{'token': 'letter', 'value': 'I'}]},
#  {'type': 'Eb',
#   'tokens': [{'token': ':Var', 'value': [{'token': 'letter', 'value': 'I'}]}]},
#  {'type': 'Exp',
#   'tokens': [{'token': ':Eb',
#     'value': [{'token': ':Var',
#       'value': [{'token': 'letter', 'value': 'I'}]}]}]},
#  {'type': 'Var',
#   'tokens': [{'token': 'letter', 'value': 'Z'},
#    {'token': '(', 'value': '('},
#    {'token': ':Exp',
#     'value': [{'token': ':Eb',
#       'value': [{'token': ':Var',
#         'value': [{'token': 'letter', 'value': 'I'}]}]}]},
#    {'token': ')', 'value': ')'}]},
#  {'type': 'Eb',
#   'tokens': [{'token': ':Var',
#     'value': [{'token': 'letter', 'value': 'Z'},
#      {'token': '(', 'value': '('},
#      {'token': ':Exp',
#       'value': [{'token': ':Eb',
#         'value': [{'token': ':Var',
#           'value': [{'token': 'letter', 'value': 'I'}]}]}]},
#      {'token': ')', 'value': ')'}]}]},
#  {'type': 'Exp',
#   'tokens': [{'token': ':Eb',
#     'value': [{'token': ':Var',
#       'value': [{'token': 'letter', 'value': 'Z'},
#        {'token': '(', 'value': '('},
#        {'token': ':Exp',
#         'value': [{'token': ':Eb',
#           'value': [{'token': ':Var',
#             'value': [{'token': 'letter', 'value': 'I'}]}]}]},
#        {'token': ')', 'value': ')'}]}]}]},
#  {'type': 'Pitem',
#   'tokens': [{'token': ':Exp',
#     'value': [{'token': ':Eb',
#       'value': [{'token': ':Var',
#         'value': [{'token': 'letter', 'value': 'Z'},
#          {'token': '(', 'value': '('},
#          {'token': ':Exp',
#           'value': [{'token': ':Eb',
#             'value': [{'token': ':Var',
#               'value': [{'token': 'letter', 'value': 'I'}]}]}]},
#          {'token': ')', 'value': ')'}]}]}]}]},
#  {'type': 'Print',
#   'tokens': [{'token': 'PRINT', 'value': 'PRINT'},
#    {'token': ':Pitem',
#     'value': [{'token': ':Exp',
#       'value': [{'token': ':Eb',
#         'value': [{'token': ':Var',
#           'value': [{'token': 'letter', 'value': 'Z'},
#            {'token': '(', 'value': '('},
#            {'token': ':Exp',
#             'value': [{'token': ':Eb',
#               'value': [{'token': ':Var',
#                 'value': [{'token': 'letter', 'value': 'I'}]}]}]},
#            {'token': ')', 'value': ')'}]}]}]}]}]},
#  {'type': 'BStatement',
#   'tokens': [{'token': ':Int', 'value': [{'token': 'digit', 'value': '9000'}]},
#    {'token': ':Print',
#     'value': [{'token': 'PRINT', 'value': 'PRINT'},
#      {'token': ':Pitem',
#       'value': [{'token': ':Exp',
#         'value': [{'token': ':Eb',
#           'value': [{'token': ':Var',
#             'value': [{'token': 'letter', 'value': 'Z'},
#              {'token': '(', 'value': '('},
#              {'token': ':Exp',
#               'value': [{'token': ':Eb',
#                 'value': [{'token': ':Var',
#                   'value': [{'token': 'letter', 'value': 'I'}]}]}]},
#              {'token': ')', 'value': ')'}]}]}]}]}]}]},
#  {'type': 'Int', 'tokens': [{'token': 'digit', 'value': '9000'}]}]

# %%
syntatical.list_events()

# %%
'\\n' in ['\\n']
# Out:
# True

# %%
z = [1, 2, 3]
z.pop()
# Out:
# 3

# %%
z
# Out:
# [1, 2]
